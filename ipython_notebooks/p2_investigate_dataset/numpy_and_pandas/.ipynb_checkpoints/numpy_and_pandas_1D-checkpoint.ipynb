# %%
#function to print 5 rows
def five_rows(table):
    count = 0
    
    if type(table) == dict:
        for row in table:
            count += 1 
            print(row,table[row])
            if count == 5:
                break
    else:
        for row in table:
            count += 1 
            print(row)
            if count == 5:
                break
                
def print_line(dot=False):
    if dot == True:
        print('---------------------------')
    else:
        print('___________________________')

# %%
import unicodecsv

def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

employment_above_15 = read_csv('employment_above_15.csv')
female_completion_rate = read_csv('female_completion_rate.csv')
gdp_per_capita = read_csv('gdp_per_capita.csv')
life_expectancy = read_csv('life_expectancy.csv')
male_completion_rate = read_csv('male_completion_rate.csv')

# %%
five_rows(employment_above_15)
print_line(dot=True)
five_rows(female_completion_rate)
print_line(dot=True)
five_rows(male_completion_rate)
print_line(dot=True)
five_rows(life_expectancy)
print_line(dot=True)
five_rows(gdp_per_capita)
# Out:
# {'1996': '56.0999984741', '2003': '54.4000015259', '2004': '56', '1994': '56.2000007629', '1998': '56.2000007629', '2000': '56.0999984741', 'Country': 'Afghanistan', '2001': '56.5', '1995': '56.2000007629', '1991': '56.7000007629', '2002': '56.4000015259', '1992': '56.5', '2007': '55.7000007629', '2005': '54', '1997': '56.2000007629', '1999': '56.0999984741', '1993': '56.5999984741', '2006': '56'}
# {'1996': '52.5999984741', '2003': '51.7999992371', '2004': '51.7000007629', '1994': '52.7000007629', '1998': '52.0999984741', '2000': '51.9000015259', 'Country': 'Albania', '2001': '51.7999992371', '1995': '52.7999992371', '1991': '52.7000007629', '2002': '51.7999992371', '1992': '52.2999992371', '2007': '51.4000015259', '2005': '51.5', '1997': '52.4000015259', '1999': '52.0999984741', '1993': '52.4000015259', '2006': '51.4000015259'}
# ...

# %% [markdown]
# **Research questions based on data descriptions**
# 1. How much does unemployment levels and GDP correlate year over year and per country?
# 2. How much does male and female graduation rates affect unemployment?
# 3. Does one gender's graduation rate matter more than the others?
# 4. Which of the four other variables correlate the most with life expectancy?
# 5. Are the correlation levels uniform for all countries, or do they differ?

# %%
#One-dimensional data import in pandas, 1
import pandas as pd

# %%
#One-dimensional data import in pandas, 2
daily_engagement = pd.read_csv(
'/Users/ggaasemyr/Documents/udacity/ipython_notebooks/p2_investigate_dataset/intro_data_analysis/daily_engagement_full.csv'
)
#it loads much faster than the standard python csv library

# %%
#One-dimensional data import in pandas, 3
len(daily_engagement['acct'].unique())
# Out:
# 1237

# %% [markdown]
# numpy = numerical python
#
# **pandas series** has more features than **numpy arrays**, and are genereally preferred
# - Numpy arrays are simpler
# - Pandas series is built on on numpy arrays
# - It is important to understand numpy arrays when working with series
#
#
# **Numpy arrays**
# - Features sequel of elements
# - Similar to python list
#     - Similarities:
#         - Access elements by position
#         - Access a range of elements(a[1:3])
#         - Use loops (for x in y)
#     - Differences
#         - Each element should have same type (string, int, boolean etc.)
#         - Convenient functions available (mean(), std(), etc.)
#         - Can be multi-dimensional (similar to list of lists)

# %%
#Quiz: numpy arrays
import numpy as np

# First 20 countries with employment data
countries = np.array([
    'Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
    'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
    'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
    'Belize', 'Benin', 'Bhutan', 'Bolivia',
    'Bosnia and Herzegovina'
])

# Employment data in 2007 for those 20 countries
employment = np.array([
    55.70000076,  51.40000153,  50.5       ,  75.69999695,
    58.40000153,  40.09999847,  61.5       ,  57.09999847,
    60.90000153,  66.59999847,  60.40000153,  68.09999847,
    66.90000153,  53.40000153,  48.59999847,  56.79999924,
    71.59999847,  58.40000153,  70.40000153,  41.20000076
])

# Change False to True for each block of code to see what it does

# Accessing elements
if True:
    print(countries[0])
    print(countries[3])

# Slicing
if True:
    print(countries[0:3])
    print(countries[:3])
    print(countries[17:])
    print(countries[:])

# Element types
if True:
    print(countries.dtype)
    print(employment.dtype)
    print(np.array([0, 1, 2, 3]).dtype)
    print(np.array([1.0, 1.5, 2.0, 2.5]).dtype)
    print(np.array([True, False, True]).dtype)
    print(np.array(['AL', 'AK', 'AZ', 'AR', 'CA']).dtype)

# Looping
if True:
    for country in countries:
        print('Examining country {}'.format(country))

    for i in range(len(countries)):
        country = countries[i]
        country_employment = employment[i]
        print('Country {} has employment {}'.format(country,
                country_employment))

# Numpy functions
if True:
    print(employment.mean())
    print(employment.std())
    print(employment.max())
    print(employment.sum())

def max_employment(countries, employment):
    '''
    Fill in this function to return the name of the country
    with the highest employment in the given employment
    data, and the employment in that country.
    '''
    max_value = employment.max()   # Replace this with your code

    count = -1

    for i in employment:
        count += 1
        if i == max_value:
            array_position = count
            break
    
    max_country = countries[array_position]      # Replace this with your code

    return (max_country, max_value)
# Out:
# Afghanistan
# Angola
# ['Afghanistan' 'Albania' 'Algeria']
# ['Afghanistan' 'Albania' 'Algeria']
# ['Bhutan' 'Bolivia' 'Bosnia and Herzegovina']
# ['Afghanistan' 'Albania' 'Algeria' 'Angola' 'Argentina' 'Armenia'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina']
# <U22
# float64
# int64
# float64
# bool
# <U2
# Examining country Afghanistan
# Examining country Albania
# Examining country Algeria
# Examining country Angola
# Examining country Argentina
# Examining country Armenia
# Examining country Australia
# Examining country Austria
# Examining country Azerbaijan
# Examining country Bahamas
# Examining country Bahrain
# Examining country Bangladesh
# Examining country Barbados
# Examining country Belarus
# Examining country Belgium
# Examining country Belize
# Examining country Benin
# Examining country Bhutan
# Examining country Bolivia
# ...

# %%
max_employment(countries,employment)
# Out:
# ('Angola', 75.699996949999999)

# %%
#Solution from video, using python
def max_employment(countries,employment):
    max_country = None
    max_employment = 0
    
    for i in range(len(countries)):
        country = countries[i]
        country_employment = employment[i]
        
        if country_employment > max_employment:
            max_country = country
            max_employment = country_employment
            
    return (max_country, max_employment)

# %%
max_employment(countries,employment)
# Out:
# ('Angola', 75.699996949999999)

# %% [markdown]
# **Tips:** If you can't find a specific numpy function to rely on, you can treat the array like a list

# %%
#Solution from video, using numpy function
def max_employment2(countries, employment):
    i = employment.argmax()
    return (countries[i],employment[i])

# %%
max_employment2(countries,employment)
# Out:
# ('Angola', 75.699996949999999)

# %% [markdown]
# **Vectorized operations**
#
# A **vector** is a list of numbers
#
#
# In linear algebra you can add two vectors of the same length.
# - this is called **vector addition**
# - example: [1,2,3] + [4,5,6] = [5,7,9]
# - this is the python (and numpy) way, but it is not necessarily the same in other languages
#
# Multiplying by a scalar
# - [1,2,3] * 3 = [3,6,9]
#     - This is what numpy does
#     - In python the result would be [1,2,3,1,2,3,1,2,3]
#
#
# - Math vectorized operations
#  - Add: +
#  - Subtract: -
#  - Multiply: \*
#  - Divide: -
#  - Exponentiate: \*\*
#
# - Math logical operations
#  - And: &
#  - Or: |
#  - Not: ~
#  - Make sure you arrays contain booleans!
#
# - Comparison operators
#  - Same as python
#
#  Using vectorized operators makes data analysis code super clean, and is usually faster than doing

# %%
#Quiz: vectorized operations, part 1 (looking at what is returned)

# Change False to True for each block of code to see what it does

# Arithmetic operations between 2 NumPy arrays
if False:
    a = np.array([1, 2, 3, 4])
    b = np.array([1, 2, 1, 2])
    
    print(a + b)
    print(a - b)
    print(a * b)
    print(a / b)
    print(a ** b)
    
    ab = a / b
    print(ab.dtype)
    
# Arithmetic operations between a NumPy array and a single number
if False:
    a = np.array([1, 2, 3, 4])
    b = 2
    
    print(a + b)
    print(a - b)
    print(a * b)
    print(a / b)
    print(a ** b)
    
# Logical operations with NumPy arrays
if False:
    a = np.array([True, True, False, False])
    b = np.array([True, False, True, False])
    
    print(a & b)
    print(a | b)
    print(~a)
    
    print(a & True)
    print(a & False)
    
    print(a | True)
    print(a | False)
    
# Comparison operations between 2 NumPy Arrays
if False:
    a = np.array([1, 2, 3, 4, 5])
    b = np.array([5, 4, 3, 2, 1])
    
    print(a > b)
    print(a >= b)
    print(a < b)
    print(a <= b)
    print(a == b)
    print(a != b)
    
# Comparison operations between a NumPy array and a single number
if False:
    a = np.array([1, 2, 3, 4])
    b = 2
    
    print(a > b)
    print(a >= b)
    print(a < b)
    print(a <= b)
    print(a == b)
    print(a != b)
    
# First 20 countries with school completion data
countries = np.array([
       'Algeria', 'Argentina', 'Armenia', 'Aruba', 'Austria','Azerbaijan',
       'Bahamas', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bolivia',
       'Botswana', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi',
       'Cambodia', 'Cameroon', 'Cape Verde'
])

# Female school completion rate in 2007 for those 20 countries
female_completion = np.array([
    97.35583,  104.62379,  103.02998,   95.14321,  103.69019,
    98.49185,  100.88828,   95.43974,   92.11484,   91.54804,
    95.98029,   98.22902,   96.12179,  119.28105,   97.84627,
    29.07386,   38.41644,   90.70509,   51.7478 ,   95.45072
])

# Male school completion rate in 2007 for those 20 countries
male_completion = np.array([
     95.47622,  100.66476,   99.7926 ,   91.48936,  103.22096,
     97.80458,  103.81398,   88.11736,   93.55611,   87.76347,
    102.45714,   98.73953,   92.22388,  115.3892 ,   98.70502,
     37.00692,   45.39401,   91.22084,   62.42028,   90.66958
])

# %%
#Quiz: vectorized operations, part 2 (writing function)
def overall_completion_rate(female_completion, male_completion):
    '''
    Fill in this function to return a NumPy array containing the overall
    school completion rate for each country. The arguments are NumPy
    arrays giving the female and male completion of each country in
    the same order.
    '''
    overall_completion = np.array(female_completion + male_completion) / 2.0
    return overall_completion

# %%
overall_completion_rate(female_completion,male_completion)
# Out:
# array([  96.416025,  102.644275,  101.41129 ,   93.316285,  103.455575,
#          98.148215,  102.35113 ,   91.77855 ,   92.835475,   89.655755,
#          99.218715,   98.484275,   94.172835,  117.335125,   98.275645,
#          33.04039 ,   41.905225,   90.962965,   57.08404 ,   93.06015 ])

# %%
female_completion[0]  male_completion[0]
# Out:
# 192.83204999999998

# %% [markdown]
# Common question in data analysis: how does a single data point compare to the rest of the data points?
#
# Typical way to answer this question:
# convert each data point to number of standard deviations away from the mean

# %%
#Quiz: Standardizing Data
import numpy as np

# First 20 countries with employment data
countries = np.array([
    'Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
    'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
    'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
    'Belize', 'Benin', 'Bhutan', 'Bolivia',
    'Bosnia and Herzegovina'
])

# Employment data in 2007 for those 20 countries
employment = np.array([
    55.70000076,  51.40000153,  50.5       ,  75.69999695,
    58.40000153,  40.09999847,  61.5       ,  57.09999847,
    60.90000153,  66.59999847,  60.40000153,  68.09999847,
    66.90000153,  53.40000153,  48.59999847,  56.79999924,
    71.59999847,  58.40000153,  70.40000153,  41.20000076
])

# Change this country name to change what country will be printed when you
# click "Test Run". Your function will be called to determine the standardized
# score for this country for each of the given 5 Gapminder variables in 2007.
# The possible country names are available in the Downloadables section.

country_name = 'United States'

def standardize_data(values):
    '''
    Fill in this function to return a standardized version of the given values,
    which will be in a NumPy array. Each value should be translated into the
    number of standard deviations that value is away from the mean of the data.
    (A positive number indicates a value higher than the mean, and a negative
    number indicates a value lower than the mean.)
    '''
    std_dev = values.std()
    average = values.mean()
    
    standarized = (values - average) / float(std_dev)
    
    return standarized

# %%
standardize_data(employment)
# Out:
# array([-0.31965231, -0.780123  , -0.87650077,  1.82207181, -0.03051941,
#        -1.99019768,  0.30144772, -0.16973184,  0.23719615,  0.84758731,
#         0.18365304,  1.00821665,  0.87971351, -0.56595055, -1.07996476,
#        -0.20185762,  1.38301845, -0.03051941,  1.2545153 , -1.87240259])

# %% [markdown]
# Yay! Almost same exact logic and structure solution as the instructor! Instructor skipped setting variables, and did everything in the return statement.

# %% [markdown]
# **Numpy index arrays**
#
# Example:
# ~~~~
# - a = [1,2,3,4,5]
# - b = [False,False,True,True,True] #This is the index array
# - a[b]: [3,4,5]
#     - alternative way1: b = a > 2
#     - alternative way2 (without using b): **a[a > 2]**
#         - instructor seems to recommend this way
#         - **This is not possible with lists, only numpy arrays**
# ~~~~

# %%
#Testing the above
a = np.array([1,2,3,4,5])
b = a[a>2]

print(b)
# Out:
# [3 4 5]

# %%
# NumPy Index Arrays, code examples
import numpy as np

# Change False to True for each block of code to see what it does

# Using index arrays
if False:
    a = np.array([1, 2, 3, 4])
    b = np.array([True, True, False, False])
    
    print(a[b])
    print(a[np.array([True, False, True, False])])
    
# Creating the index array using vectorized operations
if False:
    a = np.array([1, 2, 3, 2, 1])
    b = (a >= 2)
    
    print(a[b])
    print(a[a >= 2])
    
# Creating the index array using vectorized operations on another array
if False:
    a = np.array([1, 2, 3, 4, 5])
    b = np.array([1, 2, 3, 2, 1])
    
    print(b == 2)
    print(a[b == 2])
# Out:
# [False  True False  True False]
# [2 4]

# %%
#Quiz> NumPy Index Arrays
def mean_time_for_paid_students(time_spent, days_to_cancel):
    '''
    Fill in this function to calculate the mean time spent in the classroom
    for students who stayed enrolled at least (greater than or equal to) 7 days.
    Unlike in Lesson 1, you can assume that days_to_cancel will contain only
    integers (there are no students who have not canceled yet).
    
    The arguments are NumPy arrays. time_spent contains the amount of time spent
    in the classroom for each student, and days_to_cancel contains the number
    of days until each student cancel. The data is given in the same order
    in both arrays.
    '''
    stayed_enrolled = (days_to_cancel >= 7)
    
    return time_spent[stayed_enrolled].mean()

# Time spent in the classroom in the first week for 20 students
time_spent = np.array([
       12.89697233,    0.        ,   64.55043217,    0.        ,
       24.2315615 ,   39.991625  ,    0.        ,    0.        ,
      147.20683783,    0.        ,    0.        ,    0.        ,
       45.18261617,  157.60454283,  133.2434615 ,   52.85000767,
        0.        ,   54.9204785 ,   26.78142417,    0.
])

# Days to cancel for 20 students
days_to_cancel = np.array([
      4,   5,  37,   3,  12,   4,  35,  38,   5,  37,   3,   3,  68,
     38,  98,   2, 249,   2, 127,  35
])

mean_time_for_paid_students(time_spent,days_to_cancel)
# Out:
# 41.054003485454537

# %% [markdown]
# Here instructor showed both ways: she first created a variable for paid time, and returned paid_time.mean(). She then showed returning the vectorized instead, without creating variable first. She seems to prefer the second way.

# %% [markdown]
# **+ vs +=**
#
# - += updates the current array, causing the dependent objects to be updated as well
# - = first creates a new array, so dependent objects are not updated
# - see code examples below

# %%
#+, code example
a = np.array([1,2,3,4])
b = a
a += np.array([1,1,1,1])

print(b)
# Out:
# [2 3 4 5]

# %%
#+=, code example
#+, code example
a = np.array([1,2,3,4])
b = a
a + np.array([1,1,1,1])

print(b)
# Out:
# [1 2 3 4]

# %% [markdown]
# **In-place vs not in-place**
# - += operates in-place, while + does not
#     - Operations that are not in place are much easier to think about!

# %%
#In-place vs not in-place, code example

a = np.array([1,2,3,4,5])
slice = a[:3]
slice[0] = 100

print(a)
# Out:
# [100   2   3   4   5]

# %% [markdown]
# This is different than python lists: lists would print 1 2 3 4 5.
#
# - In numpy, slice doesn't actually create a new array, it creates a view instead.
#     - if slice is modified, the original array is modified as well.
#     - this makes slicing in numpy very fast
#         - also means we need to be very careful when modifiing a slice of an array

# %% [markdown]
# **Pandas series**
#
# - Similar to numpy arrays, but with extra functionality
#     - e.g. s.describe()
#     -Similarities:
#         - Accessing elements: s[0], s[3:7]
#         - Looping: for x in s
#         - Convenient functions: s.mean(), s.max()
#         - Vectorized operations: s1 + s2
#         - Implemented in C (fast!)

# %%
#Pandas Series, code examples

import pandas as pd

countries = ['Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda',
             'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
             'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
             'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia']

life_expectancy_values = [74.7,  75. ,  83.4,  57.6,  74.6,  75.4,  72.3,  81.5,  80.2,
                          70.3,  72.1,  76.4,  68.1,  75.2,  69.8,  79.4,  70.8,  62.7,
                          67.3,  70.6]

gdp_values = [ 1681.61390973,   2155.48523109,  21495.80508273,    562.98768478,
              13495.1274663 ,   9388.68852258,   1424.19056199,  24765.54890176,
              27036.48733192,   1945.63754911,  21721.61840978,  13373.21993972,
                483.97086804,   9783.98417323,   2253.46411147,  25034.66692293,
               3680.91642923,    366.04496652,   1175.92638695,   1132.21387981]

# Life expectancy and gdp data in 2007 for 20 countries
life_expectancy = pd.Series(life_expectancy_values)
gdp = pd.Series(gdp_values)

# Change False to True for each block of code to see what it does

# Accessing elements and slicing
if False:
    print(life_expectancy[0])
    print(gdp[3:6])
    
# Looping
if False:
    for country_life_expectancy in life_expectancy:
        print('Examining life expectancy {}'.format(country_life_expectancy))
        
# Pandas functions
if False:
    print(life_expectancy.mean())
    print(life_expectancy.std())
    print(gdp.max())
    print(gdp.sum())

# Vectorized operations and index arrays
if False:
    a = pd.Series([1, 2, 3, 4])
    b = pd.Series([1, 2, 1, 2])
  
    print(a + b)
    print(a * 2)
    print(a >= 3)
    print(a[a >= 3])
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool
# 2    3
# 3    4
# dtype: int64

# %%
#Quiz1: Pandas Series
def variable_correlation(variable1, variable2):
    '''
    Fill in this function to calculate the number of data points for which
    the directions of variable1 and variable2 relative to the mean are the
    same, and the number of data points for which they are different.
    Direction here means whether each value is above or below its mean.
    
    You can classify cases where the value is equal to the mean for one or
    both variables however you like.
    
    Each argument will be a Pandas series.
    
    For example, if the inputs were pd.Series([1, 2, 3, 4]) and
    pd.Series([4, 5, 6, 7]), then the output would be (4, 0).
    This is because 1 and 4 are both below their means, 2 and 5 are both
    below, 3 and 6 are both above, and 3 and 4 are both above.
    
    On the other hand, if the inputs were pd.Series([1, 2, 3, 4]) and
    pd.Series([7, 6, 5, 4]), then the output would be (0, 4).
    This is because 1 is below its mean but 7 is above its mean, and
    so on.
    '''
    
    greater_index = (variable1 > variable1.mean()) & (variable2 > variable2.mean())
    smaller_index = (variable1 > variable1.mean()) & (variable2 > variable2.mean())
    equal_index = (variable1 == variable1.mean()) & (variable2 == variable2.mean())
     
    num_same_direction = greater_index.sum() + smaller_index.sum() + equal_index.sum()

    num_different_direction = len(variable1) - num_same_direction
    
    return (num_same_direction, num_different_direction)

variable1 = pd.Series([1, 2, 1, 4])
variable2 = pd.Series([4, 5, 6, 7])

variable_correlation(variable1,variable2)
# Out:
# (2, 2)

# %%
#Testing correlation function on life expectancy and gdp data

variable_correlation(life_expectancy,gdp)
# Out:
# (16, 4)

# %% [markdown]
# The instructor has mostly the same solution, but she adds another Series, is_same_direction.
# ~~~~
# is_same_direction = both_above | both_below
# num_same_direction = is_same_direction.sum()
# ~~~~
#
# she solved num_different_direction in the same way I did.
#
# First number large, second number small: the variables are positively correlated
# First number small, second number large: the variables are negatively correlated
# Roughly equal: the variables are not correlated

# %% [markdown]
# **Series Indexes**
#
# The main difference between a numpy array and a Pandas series is that series has indexes.
#
# Example of use:
# ~~~~
# #numpy
# countries = np.array(['Albania', 'Algeria', 'Andorra', 'Angola'])
# life_expectancy = np.array([74.7, 75., 83.4, 57.6])
#
# #Pandas
# life_expectancy = pd.Series([74.7, 75., 83.4, 57.6],
#                             index =['Albania',
#                             'Algeria',
#                             'Andorra',
#                             'Angola'])
# ~~~~
# A Pandas series is like a cross between a list and a dictionary
#
# - ways to look up series elements
#     - life_expectancy[0] => 74.7
#     - life_expectancy.loc['Angola'] => 57.6
#     - life_expectancy.iloc[0] => 74.7

# %%
life_expectancy = pd.Series([74.7, 75., 83.4, 57.6],
                            index =['Albania', 
                            'Algeria', 
                            'Andorra', 
                            'Angola'])

life_expectancy.argmax()
# Out:
# 'Andorra'

# %%
#Quiz: Series Indexes

countries = [
    'Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
    'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
    'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
    'Belize', 'Benin', 'Bhutan', 'Bolivia',
    'Bosnia and Herzegovina'
]


employment_values = [
    55.70000076,  51.40000153,  50.5       ,  75.69999695,
    58.40000153,  40.09999847,  61.5       ,  57.09999847,
    60.90000153,  66.59999847,  60.40000153,  68.09999847,
    66.90000153,  53.40000153,  48.59999847,  56.79999924,
    71.59999847,  58.40000153,  70.40000153,  41.20000076
]

# Employment data in 2007 for 20 countries
employment = pd.Series(employment_values, index=countries)

def max_employment(employment):
    '''
    Fill in this function to return the name of the country
    with the highest employment in the given employment
    data, and the employment in that country.
    
    The input will be a Pandas series where the values
    are employment and the index is country names.
    
    Try using the Pandas argmax() function. Documention is
    here: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.argmax.html
    '''
    max_country = employment.argmax()      
    max_value = employment.loc[max_country]   
    
    return (max_country, max_value)

# %%
max_employment(employment)
# Out:
# ('Angola', 75.699996949999999)

# %% [markdown]
# **Vectorized operations and series index**
#
# - Adding two series (s1 +s2):
#     - Added based on index
#     - If index does not occur in both s1 and s2, returns NaN (Not a Number)

# %%
#Vectorized operations and series index, example code
import pandas as pd

# Change False to True for each block of code to see what it does

# Addition when indexes are the same
if False:
    s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
    s2 = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
    print(s1 + s2)

# Indexes have same elements in a different order
if False:
    s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
    s2 = pd.Series([10, 20, 30, 40], index=['b', 'd', 'a', 'c'])
    print(s1 + s2)

# Indexes overlap, but do not have exactly the same elements
if False:
    s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
    s2 = pd.Series([10, 20, 30, 40], index=['c', 'd', 'e', 'f'])
    print(s1 + s2)

# Indexes do not overlap
if False:
    s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
    s2 = pd.Series([10, 20, 30, 40], index=['e', 'f', 'g', 'h'])
    print(s1 + s2)
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# f   NaN
# g   NaN
# h   NaN
# dtype: float64

# %%
#Removing missing values
s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
s2 = pd.Series([10, 20, 30, 40], index=['c', 'd', 'e', 'f'])

print((s1 + s2).dropna())
# Out:
# c    13.0
# d    24.0
# dtype: float64

# %%
#Quiz: Filling missing values

s1 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
s2 = pd.Series([10, 20, 30, 40], index=['c', 'd', 'e', 'f'])

# Try to write code that will add the 2 previous series together,
# but treating missing values from either series as 0. The result
# when printed out should be similar to the following line:
# print pd.Series([1, 2, 13, 24, 30, 40], 
#index=['a', 'b', 'c', 'd', 'e', 'f'])

series_sum = s1.add(s2,fill_value=0)

print(series_sum)
# Out:
# a     1.0
# b     2.0
# c    13.0
# d    24.0
# e    30.0
# f    40.0
# dtype: float64

# %% [markdown]
# **Non built-in calculations**
# Ways to not use built-in functions or (vectorized) operations.
# - Examples
#     - Treat the series as a list (for loops etc)
#     - Use the function apply()
#         - apply() takes a series and a function, and returns a new series
#         - is exactly the same as python's map function
#         - example:
#             - `def add3(x):
#                 `return x+3`
#             - `s.apply(add3) #applies add3 to whole series`
#             - This example could also use vectorized operation s+3
#         - apply() takes another python function as input (without parenthesis)

# %%
# Example pandas apply() usage (although this could have been done
# without apply() using vectorized operations)
s = pd.Series([1, 2, 3, 4, 5])
def add_one(x):
    return x + 1
print(s.apply(add_one))
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
def testiii(x):
    return x.apply(add_one)

testiii(s)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
#Quiz: Pandas Series apply()

names = pd.Series([
    'Andre Agassi',
    'Barry Bonds',
    'Christopher Columbus',
    'Daniel Defoe',
    'Emilio Estevez',
    'Fred Flintstone',
    'Greta Garbo',
    'Humbert Humbert',
    'Ivan Ilych',
    'James Joyce',
    'Keira Knightley',
    'Lois Lane',
    'Mike Myers',
    'Nick Nolte',
    'Ozzy Osbourne',
    'Pablo Picasso',
    'Quirinus Quirrell',
    'Rachael Ray',
    'Susan Sarandon',
    'Tina Turner',
    'Ugueth Urbina',
    'Vince Vaughn',
    'Woodrow Wilson',
    'Yoji Yamada',
    'Zinedine Zidane'
])

def reverse_names(names):
    '''
    Fill in this function to return a new series where each name
    in the input series has been transformed from the format
    "Firstname Lastname" to "Lastname, FirstName".
    
    Try to use the Pandas apply() function rather than a loop.
    '''
    def reverse_name(name):
        
        first_name = name.split()[0]
        last_name = name.split()[1]
        return last_name + ", " + first_name
    
    return names.apply(reverse_name)

# %%
#testing function code from above
names=pd.Series(['Andre Agassi', 'Barry Bonds', 'Christopher Columbus', 'Daniel Defoe'],
                index=[0, 1, 2, 3])
print(names)
print("-----")
print(reverse_names(names))
#names.str.split()
# Out:
# 0            Andre Agassi
# 1             Barry Bonds
# 2    Christopher Columbus
# 3            Daniel Defoe
# dtype: object
# -----
# 0            Agassi, Andre
# 1             Bonds, Barry
# 2    Columbus, Christopher
# 3            Defoe, Daniel
# dtype: object

# %%
#Quiz: Plotting in Pandas
import pandas as pd
import seaborn as sns
# %matplotlib inline


# The following code reads all the Gapminder data into Pandas DataFrames. You'll
# learn about DataFrames next lesson.

employment = pd.read_csv('employment_above_15.csv', index_col='Country')
female_completion = pd.read_csv('female_completion_rate.csv', index_col='Country')
male_completion = pd.read_csv('male_completion_rate.csv', index_col='Country')
life_expectancy = pd.read_csv('life_expectancy.csv', index_col='Country')
gdp = pd.read_csv('gdp_per_capita.csv', index_col='Country')

# The following code creates a Pandas Series for each variable for the United States.
# You can change the string 'United States' to a country of your choice.

employment_us = employment.loc['United States']
female_completion_us = female_completion.loc['United States']
male_completion_us = male_completion.loc['United States']
life_expectancy_us = life_expectancy.loc['United States']
gdp_us = gdp.loc['United States']

# Uncomment the following line of code to see the available country names
# print(employment.index.values)

# Use the Series defined above to create a plot of each variable over time for
# the country of your choice. You will only be able to display one plot at a time
# with each "Test Run".

# %% [markdown]
# **Random/General tips:**
# - You can add booleans in Python!
#     - True + True = 2
# - Pandas documentation is not perfect: sometimes functions that are documented for dataframe will work for series as well.

# %%
employment_norway = employment.loc['Norway']
female_completion_norway = female_completion.loc['Norway']
male_completion_norway = male_completion.loc['Norway']
life_expectancy_norway = life_expectancy.loc['Norway']
gdp_norway = gdp.loc['Norway']

#employment_norway.plot()
#female_completion_norway.plot()
#male_completion_norway.plot()
#life_expectancy_norway.plot()
#gdp_norway.plot()
