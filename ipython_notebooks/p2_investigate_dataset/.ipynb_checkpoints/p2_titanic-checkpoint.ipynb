# %% [markdown]
# In this project I will analyze passenger data from the passenger liner RMS Titanic's tragic mayden voyage in April 1912.

# %% [markdown]
# I will start by doing some exploratory data analysis with the following initial research question in mind:
# - Which factor(s) had the greatest impact on survival rate?

# %% [markdown]
# Laura's question:
# 1st class women who died vs low class women who died

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
from IPython.display import display

# %matplotlib inline

# %%
#loading data

titanic = pd.read_csv('titanic_data.csv')

# %%
#Inital exploration

from IPython.display import display

print(titanic.columns)

print(len(titanic))

display(titanic.head(5))

print(titanic['Age'].describe())

display(titanic[titanic['Age'] == titanic['Age'].min()])

display(titanic['Age'].head(10))

display(titanic.iloc[5])

display(titanic[titanic['Age'] == 32])
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# 891
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       80.000000
# Name: Age, dtype: float64
# /Users/ggaasemyr/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object
#      PassengerId  Survived  Pclass                                Name  \
# 70            71         0       2          Jenkin, Mr. Stephen Curnow
# 74            75         1       3                       Bing, Mr. Lee
# 190          191         1       2                 Pinsky, Mrs. (Rosa)
# 206          207         0       3          Backstrom, Mr. Karl Alfred
# 218          219         1       1               Bazzani, Miss. Albina
# 382          383         0       3                  Tikkanen, Mr. Juho
# 429          430         1       3  Pickard, Mr. Berk (Berk Trembisky)
# 519          520         0       3                 Pavlovic, Mr. Stefo
# 543          544         1       2                   Beane, Mr. Edward
# 569          570         1       3                   Jonsson, Mr. Carl
# 579          580         1       3                 Jussila, Mr. Eiriik
# 632          633         1       1           Stahelin-Maeglin, Dr. Max
# 636          637         0       3          Leinonen, Mr. Antti Gustaf
# 657          658         0       3       Bourke, Mrs. John (Catherine)
# 665          666         0       2                  Hickman, Mr. Lewis
# 769          770         0       3    Gronnestad, Mr. Daniel Danielsen
# 838          839         1       3                     Chip, Mr. Chang
# 890          891         0       3                 Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 70     male  32.0      0      0         C.A. 33111  10.5000   NaN        S
# 74     male  32.0      0      0               1601  56.4958   NaN        S
# 190  female  32.0      0      0             234604  13.0000   NaN        S
# 206    male  32.0      1      0            3101278  15.8500   NaN        S
# 218  female  32.0      0      0              11813  76.2917   D15        C
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 429    male  32.0      0      0  SOTON/O.Q. 392078   8.0500   E10        S
# 519    male  32.0      0      0             349242   7.8958   NaN        S
# 543    male  32.0      1      0               2908  26.0000   NaN        S
# 569    male  32.0      0      0             350417   7.8542   NaN        S
# 579    male  32.0      0      0  STON/O 2. 3101286   7.9250   NaN        S
# 632    male  32.0      0      0              13214  30.5000   B50        C
# 636    male  32.0      0      0  STON/O 2. 3101292   7.9250   NaN        S
# 657  female  32.0      1      1             364849  15.5000   NaN        Q
# 665    male  32.0      2      0       S.O.C. 14879  73.5000   NaN        S
# 769    male  32.0      0      0               8471   8.3625   NaN        S
# 838    male  32.0      0      0               1601  56.4958   NaN        S
# 890    male  32.0      0      0             370376   7.7500   NaN        Q

# %%
#Making 'Sex' numeric to be able to perform mathematical operations using the variable
titanic['is_male'] = np.repeat(np.nan,len(titanic))
titanic['is_female'] = np.repeat(np.nan,len(titanic))

titanic['is_male'][titanic['Sex'] == 'male'] = True
titanic['is_male'][titanic['Sex'] == 'female'] = False
titanic['is_female'][titanic['Sex'] == 'female'] = True
titanic['is_female'][titanic['Sex'] == 'male'] = False

display(titanic.head(5))

display(titanic['is_male'].value_counts())
display(titanic['is_female'].value_counts())
display(titanic['Sex'].value_counts())
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ggaasemyr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ggaasemyr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  is_male  is_female
# 0      0         A/5 21171   7.2500   NaN        S      1.0        0.0
# 1      0          PC 17599  71.2833   C85        C      0.0        1.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.0        1.0
# 3      0            113803  53.1000  C123        S      0.0        1.0
# 4      0            373450   8.0500   NaN        S      1.0        0.0
# 1.0    577
# 0.0    314
# Name: is_male, dtype: int64
# 0.0    577
# 1.0    314
# Name: is_female, dtype: int64
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic['is_male'][titanic['Sex'] == 'male'].head(5)
# Out:
# 0    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# Name: is_male, dtype: float64

# %%
#Looking at survival correlation using the Pandas corr() (Pearson's correlation coefficient) function

survival_correlation = titanic.corr()['Survived']

display(survival_correlation)

survival_correlation.plot()
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# is_male       -0.543351
# is_female      0.543351
# Name: Survived, dtype: float64

# %% [markdown]
# This indicates that gender (being female) and passenger class where the most important factors for survival on the Titanic, with high and medium correlation scores. Ticket price also has a fairly large correlation score (Pearson's correlation coefficient). I suspect this is due to better ticket classes costing more, which I will test for next.

# %%
display(titanic.corr()['Fare'])

display(titanic.groupby('Pclass')['Fare'].describe())
# Out:
# PassengerId    0.012658
# Survived       0.257307
# Pclass        -0.549500
# Age            0.096067
# SibSp          0.159651
# Parch          0.216225
# Fare           1.000000
# is_male       -0.182333
# is_female      0.182333
# Name: Fare, dtype: float64
# Pclass
# 1       count    216.000000
#         mean      84.154687
#         std       78.380373
#         min        0.000000
#         25%       30.923950
#         50%       60.287500
#         75%       93.500000
#         max      512.329200
# 2       count    184.000000
#         mean      20.662183
#         std       13.417399
#         min        0.000000
#         25%       13.000000
#         50%       14.250000
#         75%       26.000000
#         max       73.500000
# 3       count    491.000000
#         mean      13.675550
#         std       11.778142
#         min        0.000000
#         25%        7.750000
#         50%        8.050000
#         75%       15.500000
#         max       69.550000
# Name: Fare, dtype: float64

# %%
#Looking further at the passengers who did not pay for their tickets (ticket price 0)

zero_fare = (titanic[titanic['Fare'] == 0].sort_values('Pclass'))

display(zero_fare)

zero_fare.describe()
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 263          264         0       1             Harrison, Mr. William  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 179          180         0       3               Leonard, Mr. Lionel  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 597          598         0       3               Johnson, Mr. Alfred  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked  is_male  is_female
# 263  40.0      0      0  112059   0.0   B94        S      1.0        0.0
# 633   NaN      0      0  112052   0.0   NaN        S      1.0        0.0
# 806  39.0      0      0  112050   0.0   A36        S      1.0        0.0
# 815   NaN      0      0  112058   0.0  B102        S      1.0        0.0
# 822  38.0      0      0   19972   0.0   NaN        S      1.0        0.0
# 277   NaN      0      0  239853   0.0   NaN        S      1.0        0.0
# 413   NaN      0      0  239853   0.0   NaN        S      1.0        0.0
# 466   NaN      0      0  239853   0.0   NaN        S      1.0        0.0
# 481   NaN      0      0  239854   0.0   NaN        S      1.0        0.0
# 674   NaN      0      0  239856   0.0   NaN        S      1.0        0.0
# 732   NaN      0      0  239855   0.0   NaN        S      1.0        0.0
# 179  36.0      0      0    LINE   0.0   NaN        S      1.0        0.0
# 271  25.0      0      0    LINE   0.0   NaN        S      1.0        0.0
# 302  19.0      0      0    LINE   0.0   NaN        S      1.0        0.0
# 597  49.0      0      0    LINE   0.0   NaN        S      1.0        0.0
# /Users/ggaasemyr/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId   Survived     Pclass        Age  SibSp  Parch  Fare  \
# count    15.000000  15.000000  15.000000   7.000000   15.0   15.0  15.0
# mean    516.400000   0.066667   1.933333  35.142857    0.0    0.0   0.0
# std     225.808958   0.258199   0.798809  10.023781    0.0    0.0   0.0
# min     180.000000   0.000000   1.000000  19.000000    0.0    0.0   0.0
# 25%     290.500000   0.000000   1.000000        NaN    0.0    0.0   0.0
# 50%     482.000000   0.000000   2.000000        NaN    0.0    0.0   0.0
# 75%     704.000000   0.000000   2.500000        NaN    0.0    0.0   0.0
# max     823.000000   1.000000   3.000000  49.000000    0.0    0.0   0.0
#
#        is_male  is_female
# count     15.0       15.0
# mean       1.0        0.0
# std        0.0        0.0
# min        1.0        0.0
# 25%        1.0        0.0
# 50%        1.0        0.0
# 75%        1.0        0.0
# max        1.0        0.0

# %%
#Checking for corelation again, excluding passenger who did not pay for their tickets.

display(titanic[titanic['Fare'] > 0].corr()['Fare'])
# Out:
# PassengerId    0.015861
# Survived       0.252453
# Pclass        -0.561517
# Age            0.098981
# SibSp          0.155240
# Parch          0.212137
# Fare           1.000000
# is_male       -0.175592
# is_female      0.175592
# Name: Fare, dtype: float64

# %% [markdown]
# Since the correlation between ticket class and ticket price is high, I will only look at ticket class as a social class indicator going forward, and I will not look at ticket price again.

# %%
titanic.groupby('Survived').sum()
# Out:
#           PassengerId  Pclass       Age  SibSp  Parch        Fare  is_male  \
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199    468.0
# 1              151974     667   8219.67    162    159  16551.2294    109.0
#
#           is_female
# Survived
# 0              81.0
# 1             233.0

# %% [markdown]
# def proportions(df):
#
#
#     df['proportions'] =  / titanic_count
#
#
# #class_survival_gender['PassengerId'].loc[1,(0,1),'female']

# %%
gb_survival_class_sex = titanic.groupby(['Pclass','Sex']).agg({'Survived': 'sum'})

# %%
tmp_gb = titanic.groupby(['Pclass','Sex','Survived'])#.agg({'Survived':'count'})
display(tmp_gb)

#tmp_gb.loc[(:),'female']

#dfb = df.groupby('cat').get_group('b')

#class_survival_gender['PassengerId'].loc[(1,2),(0,1),'female']

#(tmp_gb.loc[(1,2,3),('female','male'),0]).div(gb_survival_class_gender, level='Survived')

#state_office.div(state, level='state') * 100

tmp_gb.get_group((1,'female',1))

#tmp_gb.groups
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# 88            89         1       1
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 194          195         1       1
# 195          196         1       1
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 275          276         1       1
# 290          291         1       1
# 291          292         1       1
# 299          300         1       1
# 306          307         1       1
# 307          308         1       1
# 309          310         1       1
# 310          311         1       1
# 311          312         1       1
# 318          319         1       1
# ..           ...       ...     ...
# 591          592         1       1
# 609          610         1       1
# 627          628         1       1
# 641          642         1       1
# 669          670         1       1
# 689          690         1       1
# 700          701         1       1
# 708          709         1       1
# 710          711         1       1
# 716          717         1       1
# 730          731         1       1
# 742          743         1       1
# 759          760         1       1
# 763          764         1       1
# 765          766         1       1
# 779          780         1       1
# 781          782         1       1
# 796          797         1       1
# 809          810         1       1
# 820          821         1       1
# 829          830         1       1
# 835          836         1       1
# 842          843         1       1
# 849          850         1       1
# 853          854         1       1
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 136                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  female   NaN      0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# 215                            Newell, Miss. Madeleine  female  31.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 230       Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1
# 256                     Thorne, Mrs. Gertrude Maybelle  female   NaN      0
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 258                                   Ward, Miss. Anna  female  35.0      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 269                             Bissette, Miss. Amelia  female  35.0      0
# 275                  Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 290                       Barber, Miss. Ellen "Nellie"  female  26.0      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 306                            Fleming, Miss. Margaret  female   NaN      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 318                           Wick, Miss. Mary Natalie  female  31.0      0
# ..                                                 ...     ...   ...    ...
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 609                          Shutes, Miss. Elizabeth W  female  40.0      0
# 627                      Longley, Miss. Gretchen Fiske  female  21.0      0
# 641                               Sagesser, Mlle. Emma  female  24.0      0
# 669  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  female   NaN      1
# 689                  Madill, Miss. Georgette Alexandra  female  15.0      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 708                               Cleaver, Miss. Alice  female  22.0      0
# 710   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  female  24.0      0
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
# 730                      Allen, Miss. Elisabeth Walton  female  29.0      0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 796                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 842                            Serepeca, Miss. Augusta  female  30.0      0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare            Cabin Embarked  is_male  is_female
# 1        0  PC 17599   71.2833              C85        C      0.0        1.0
# 3        0    113803   53.1000             C123        S      0.0        1.0
# 11       0    113783   26.5500             C103        S      0.0        1.0
# 31       0  PC 17569  146.5208              B78        C      0.0        1.0
# 52       0  PC 17572   76.7292              D33        C      0.0        1.0
# 61       0    113572   80.0000              B28      NaN      0.0        1.0
# 88       2     19950  263.0000      C23 C25 C27        S      0.0        1.0
# 136      2     11752   26.2833              D47        S      0.0        1.0
# 151      0    113776   66.6000               C2        S      0.0        1.0
# 166      1    113505   55.0000              E33        S      0.0        1.0
# 194      0  PC 17610   27.7208               B4        C      0.0        1.0
# 195      0  PC 17569  146.5208              B80        C      0.0        1.0
# 215      0     35273  113.2750              D36        C      0.0        1.0
# 218      0     11813   76.2917              D15        C      0.0        1.0
# 230      0     36973   83.4750              C83        S      0.0        1.0
# 256      0  PC 17585   79.2000              NaN        C      0.0        1.0
# 257      0    110152   86.5000              B77        S      0.0        1.0
# 258      0  PC 17755  512.3292              NaN        C      0.0        1.0
# 268      1  PC 17582  153.4625             C125        S      0.0        1.0
# 269      0  PC 17760  135.6333              C99        S      0.0        1.0
# 275      0     13502   77.9583               D7        S      0.0        1.0
# 290      0     19877   78.8500              NaN        S      0.0        1.0
# 291      0     11967   91.0792              B49        C      0.0        1.0
# 299      1  PC 17558  247.5208          B58 B60        C      0.0        1.0
# 306      0     17421  110.8833              NaN        C      0.0        1.0
# 307      0  PC 17758  108.9000              C65        C      0.0        1.0
# 309      0  PC 17485   56.9292              E36        C      0.0        1.0
# 310      0     11767   83.1583              C54        C      0.0        1.0
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C      0.0        1.0
# 318      2     36928  164.8667               C7        S      0.0        1.0
# ..     ...       ...       ...              ...      ...      ...        ...
# 591      0     36947   78.2667              D20        C      0.0        1.0
# 609      0  PC 17582  153.4625             C125        S      0.0        1.0
# 627      0     13502   77.9583               D9        S      0.0        1.0
# 641      0  PC 17477   69.3000              B35        C      0.0        1.0
# 669      0     19996   52.0000             C126        S      0.0        1.0
# 689      1     24160  211.3375               B5        S      0.0        1.0
# 700      0  PC 17757  227.5250          C62 C64        C      0.0        1.0
# 708      0    113781  151.5500              NaN        S      0.0        1.0
# 710      0  PC 17482   49.5042              C90        C      0.0        1.0
# 716      0  PC 17757  227.5250              C45        C      0.0        1.0
# 730      0     24160  211.3375               B5        S      0.0        1.0
# 742      2  PC 17608  262.3750  B57 B59 B63 B66        C      0.0        1.0
# 759      0    110152   86.5000              B77        S      0.0        1.0
# 763      2    113760  120.0000          B96 B98        S      0.0        1.0
# 765      0     13502   77.9583              D11        S      0.0        1.0
# 779      1     24160  211.3375               B3        S      0.0        1.0
# 781      0     17474   57.0000              B20        S      0.0        1.0
# 796      0     17465   25.9292              D17        S      0.0        1.0
# 809      0    113806   53.1000               E8        S      0.0        1.0
# 820      1     12749   93.5000              B69        S      0.0        1.0
# 829      0    113572   80.0000              B28      NaN      0.0        1.0
# 835      1  PC 17756   83.1583              E49        C      0.0        1.0
# 842      0    113798   31.0000              NaN        C      0.0        1.0
# 849      0     17453   89.1042              C92        C      0.0        1.0
# 853      1  PC 17592   39.4000              D28        S      0.0        1.0
# 856      1     36928  164.8667              NaN        S      0.0        1.0
# 862      0     17466   25.9292              D17        S      0.0        1.0
# 871      1     11751   52.5542              D35        S      0.0        1.0
# 879      1     11767   83.1583              C50        C      0.0        1.0
# 887      0    112053   30.0000              B42        S      0.0        1.0
#
# [91 rows x 14 columns]

# %%
#counting survivors by ticket class and gender
gb_survival_class_gender = titanic.groupby(['Pclass','Sex'])['Survived'].agg({'Passengers':'count','Survived':'sum'})

#calculating percentage of survivors
gb_survival_class_gender['percent_survived'] = (gb_survival_class_gender['Survived'] / 
                                                gb_survival_class_gender['Passengers']) * 100

#counting survivors by gender
gb_survival_gender = titanic.groupby(['Sex'])['Survived'].agg({'Passengers':'count','Survived':'sum'})

display(gb_survival_class_gender)
display(gb_survival_gender)

gb_survival_class_gender['Survived'].div(gb_survival_gender['Passengers'],level='Sex')
# Out:
#                Passengers  Survived  percent_survived
# Pclass Sex
# 1      female          94        91         96.808511
#        male           122        45         36.885246
# 2      female          76        70         92.105263
#        male           108        17         15.740741
# 3      female         144        72         50.000000
#        male           347        47         13.544669
#         Passengers  Survived
# Sex
# female         314       233
# male           577       109
# Pclass  Sex
# 1       female    0.289809
#         male      0.077990
# 2       female    0.222930
#         male      0.029463
# 3       female    0.229299
#         male      0.081456
# dtype: float64

# %%
titanic.groupby('Sex')['Survived'].agg(['sum','count'])
# Out:
#         sum  count
# Sex
# female  233    314
# male    109    577

# %%
#Looking at effect of ticket class

class_survival_gender = titanic.groupby(['Pclass','Survived','Sex']).agg('count')
display(class_survival_gender)

class_survival = titanic.groupby(['Pclass','Survived']).count()

survival_gender = display(titanic.groupby(['Survived','Sex']).count())
display(survival_gender)

display(titanic.groupby('Pclass').mean())

display(titanic.groupby(['Survived'])['Sex','Pclass'].mean())
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 1      0        female            3     3    3      3      3       3     3
#                 male             77    77   61     77     77      77    77
#        1        female           91    91   82     91     91      91    91
#                 male             45    45   40     45     45      45    45
# 2      0        female            6     6    6      6      6       6     6
#                 male             91    91   84     91     91      91    91
#        1        female           70    70   68     70     70      70    70
#                 male             17    17   15     17     17      17    17
# 3      0        female           72    72   55     72     72      72    72
#                 male            300   300  215    300    300     300   300
#        1        female           72    72   47     72     72      72    72
#                 male             47    47   38     47     47      47    47
#
#                         Cabin  Embarked  is_male  is_female
# Pclass Survived Sex
# 1      0        female      3         3        3          3
#                 male       56        77       77         77
#        1        female     78        89       91         91
#                 male       39        45       45         45
# 2      0        female      1         6        6          6
#                 male        2        91       91         91
#        1        female      9        70       70         70
#                 male        4        17       17         17
# 3      0        female      2        72       72         72
#                 male        4       300      300        300
#        1        female      4        72       72         72
#                 male        2        47       47         47
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Survived Sex
# 0        female           81      81    81   64     81     81      81    81
#          male            468     468   468  360    468    468     468   468
# 1        female          233     233   233  197    233    233     233   233
#          male            109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked  is_male  is_female
# Survived Sex
# 0        female      6        81       81         81
#          male       62       468      468        468
# 1        female     91       231      233        233
#          male       45       109      109        109
# None
#         PassengerId  Survived        Age     SibSp     Parch       Fare  \
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
#
#          is_male  is_female
# Pclass
# 1       0.564815   0.435185
# 2       0.586957   0.413043
# 3       0.706721   0.293279
#             Pclass
# Survived
# 0         2.531876
# 1         1.950292
