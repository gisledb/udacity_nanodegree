# %%
#!/usr/bin/python

import pickle
import sys
import matplotlib.pyplot
# %matplotlib inline
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit

# %%
### read in data dictionary, convert to numpy array
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "rb") )
features = ["salary", "bonus"]
data = featureFormat(data_dict, features)

# %%
def salary_bonus_plot():
    for point in data:
        salary = point[0]
        bonus = point[1]
        matplotlib.pyplot.scatter( salary, bonus )

# %%
### your code below

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(data_dict).transpose()

# %%
# Replacing string Nan with np.nan
df = df.replace('NaN', np.nan)

# %%
data_dict.pop('TOTAL', 0)
# Out:
# {'bonus': 97343619,
#  'deferral_payments': 32083396,
#  'deferred_income': -27992891,
#  'director_fees': 1398517,
#  'email_address': 'NaN',
#  'exercised_stock_options': 311764000,
#  'expenses': 5235198,
#  'from_messages': 'NaN',
#  'from_poi_to_this_person': 'NaN',
#  'from_this_person_to_poi': 'NaN',
#  'loan_advances': 83925000,
#  'long_term_incentive': 48521928,
#  'other': 42667589,
#  'poi': False,
#  'restricted_stock': 130322299,
#  'restricted_stock_deferred': -7576788,
#  'salary': 26704229,
#  'shared_receipt_with_poi': 'NaN',
#  'to_messages': 'NaN',
#  'total_payments': 309886585,
#  'total_stock_value': 434509511}

# %%
data = featureFormat(data_dict, features)

# %%
df.sort_values('bonus', ascending=False).head(5)
# Out:
#                          bonus  deferral_payments  deferred_income  \
# TOTAL               97343619.0         32083396.0      -27992891.0
# LAVORATO JOHN J      8000000.0                NaN              NaN
# LAY KENNETH L        7000000.0           202911.0        -300000.0
# SKILLING JEFFREY K   5600000.0                NaN              NaN
# BELDEN TIMOTHY N     5249999.0          2144013.0       -2334434.0
#
#                     director_fees            email_address  \
# TOTAL                   1398517.0                      NaN
# LAVORATO JOHN J               NaN  john.lavorato@enron.com
# LAY KENNETH L                 NaN    kenneth.lay@enron.com
# SKILLING JEFFREY K            NaN  jeff.skilling@enron.com
# BELDEN TIMOTHY N              NaN     tim.belden@enron.com
#
#                     exercised_stock_options   expenses  from_messages  \
# TOTAL                           311764000.0  5235198.0            NaN
# ...

# %%
salary_bonus_plot()

# %%
# Identify who made more than 5 million in bonuses and 1 million in salaries
df[(df['bonus'] >= 5000000) & (df['salary'] >= 1000000)][['bonus', 'salary']]
# Out:
#                          bonus      salary
# LAY KENNETH L        7000000.0   1072321.0
# SKILLING JEFFREY K   5600000.0   1111258.0
# TOTAL               97343619.0  26704229.0
