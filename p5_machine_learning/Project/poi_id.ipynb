# %%
#!/usr/bin/python

import sys
import pickle
sys.path.append("tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split

from IPython.display import display
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Task 1: Select what features you'll use.
# - features_list is a list of strings, each of which is a feature name.
# - The first feature must be "poi".

# %%
### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".
features_list = ['poi','salary'] # You will need to use more features

### Load the dictionary containing the dataset
with open("final_project_dataset.pkl", "rb") as data_file:
    data_dict = pickle.load(data_file)

# %% [markdown]
# #### Dataset exploration

# %% [markdown]
# ##### Preparing the dataframe

# %%
# Loading the data into a Pandas dataframe
df_people = pd.DataFrame(data_dict).transpose()

# %%
# compare the original dictionary 
# with the dictionary reconstructed from the dataframe:  
print(df_people.to_dict('index') == data_dict)
# Out:
# True

# %%
# Taking a look at the data types
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, ALLEN PHILLIP K to YEAP SOON
# Data columns (total 21 columns):
# bonus                        146 non-null object
# deferral_payments            146 non-null object
# deferred_income              146 non-null object
# director_fees                146 non-null object
# email_address                146 non-null object
# exercised_stock_options      146 non-null object
# expenses                     146 non-null object
# from_messages                146 non-null object
# from_poi_to_this_person      146 non-null object
# from_this_person_to_poi      146 non-null object
# loan_advances                146 non-null object
# long_term_incentive          146 non-null object
# other                        146 non-null object
# poi                          146 non-null object
# restricted_stock             146 non-null object
# restricted_stock_deferred    146 non-null object
# salary                       146 non-null object
# shared_receipt_with_poi      146 non-null object
# to_messages                  146 non-null object
# total_payments               146 non-null object
# total_stock_value            146 non-null object
# dtypes: object(21)
# memory usage: 25.1+ KB

# %% [markdown]
# There are 146 people (rows) and 21 features (columns) in the dataset.
#
# Looks like the data types are not set correctly. I'll have to clean that up before continuing.

# %%
# Taking a look at some records

display(df_people.head())
display(df_people.tail())
# Out:
#                       bonus deferral_payments deferred_income director_fees  \
# ALLEN PHILLIP K     4175000           2869717        -3081055           NaN
# BADUM JAMES P           NaN            178980             NaN           NaN
# BANNANTINE JAMES M      NaN               NaN           -5104           NaN
# BAXTER JOHN C       1200000           1295738        -1386055           NaN
# BAY FRANKLIN R       400000            260455         -201641           NaN
#
#                                  email_address exercised_stock_options  \
# ALLEN PHILLIP K        phillip.allen@enron.com                 1729541
# BADUM JAMES P                              NaN                  257817
# BANNANTINE JAMES M  james.bannantine@enron.com                 4046157
# BAXTER JOHN C                              NaN                 6680544
# BAY FRANKLIN R             frank.bay@enron.com                     NaN
#
#                    expenses from_messages from_poi_to_this_person  \
# ALLEN PHILLIP K       13868          2195                      47
# BADUM JAMES P          3486           NaN                     NaN
# BANNANTINE JAMES M    56301            29                      39
# BAXTER JOHN C         11200           NaN                     NaN
# BAY FRANKLIN R       129142           NaN                     NaN
#
#                    from_this_person_to_poi        ...         \
# ALLEN PHILLIP K                         65        ...
# BADUM JAMES P                          NaN        ...
# BANNANTINE JAMES M                       0        ...
# BAXTER JOHN C                          NaN        ...
# BAY FRANKLIN R                         NaN        ...
#
#                    long_term_incentive    other    poi restricted_stock  \
# ALLEN PHILLIP K                 304805      152  False           126027
# BADUM JAMES P                      NaN      NaN  False              NaN
# BANNANTINE JAMES M                 NaN   864523  False          1757552
# BAXTER JOHN C                  1586055  2660303  False          3942714
# BAY FRANKLIN R                     NaN       69  False           145796
#
#                    restricted_stock_deferred  salary shared_receipt_with_poi  \
# ALLEN PHILLIP K                      -126027  201955                    1407
# BADUM JAMES P                            NaN     NaN                     NaN
# BANNANTINE JAMES M                   -560222     477                     465
# BAXTER JOHN C                            NaN  267102                     NaN
# BAY FRANKLIN R                        -82782  239671                     NaN
#
#                    to_messages total_payments total_stock_value
# ALLEN PHILLIP K           2902        4484442           1729541
# BADUM JAMES P              NaN         182466            257817
# BANNANTINE JAMES M         566         916197           5243487
# BAXTER JOHN C              NaN        5634343          10623258
# BAY FRANKLIN R             NaN         827696             63014
#
# [5 rows x 21 columns]
#                       bonus deferral_payments deferred_income director_fees  \
# WINOKUR JR. HERBERT S   NaN               NaN          -25000        108579
# WODRASKA JOHN           NaN               NaN             NaN           NaN
# WROBEL BRUCE            NaN               NaN             NaN           NaN
# YEAGER F SCOTT          NaN               NaN             NaN           NaN
# YEAP SOON               NaN               NaN             NaN           NaN
#
#                                  email_address exercised_stock_options  \
# WINOKUR JR. HERBERT S                      NaN                     NaN
# WODRASKA JOHN          john.wodraska@enron.com                     NaN
# WROBEL BRUCE                               NaN                  139130
# YEAGER F SCOTT          scott.yeager@enron.com                 8308552
# YEAP SOON                                  NaN                  192758
#
#                       expenses from_messages from_poi_to_this_person  \
# WINOKUR JR. HERBERT S     1413           NaN                     NaN
# WODRASKA JOHN              NaN           NaN                     NaN
# WROBEL BRUCE               NaN           NaN                     NaN
# YEAGER F SCOTT           53947           NaN                     NaN
# YEAP SOON                55097           NaN                     NaN
#
#                       from_this_person_to_poi        ...         \
# WINOKUR JR. HERBERT S                     NaN        ...
# WODRASKA JOHN                             NaN        ...
# WROBEL BRUCE                              NaN        ...
# YEAGER F SCOTT                            NaN        ...
# YEAP SOON                                 NaN        ...
#
#                       long_term_incentive   other    poi restricted_stock  \
# WINOKUR JR. HERBERT S                 NaN     NaN  False              NaN
# WODRASKA JOHN                         NaN  189583  False              NaN
# WROBEL BRUCE                          NaN     NaN  False              NaN
# YEAGER F SCOTT                        NaN  147950   True          3576206
# YEAP SOON                             NaN     NaN  False              NaN
#
#                       restricted_stock_deferred  salary  \
# WINOKUR JR. HERBERT S                       NaN     NaN
# WODRASKA JOHN                               NaN     NaN
# WROBEL BRUCE                                NaN     NaN
# YEAGER F SCOTT                              NaN  158403
# YEAP SOON                                   NaN     NaN
#
#                       shared_receipt_with_poi to_messages total_payments  \
# WINOKUR JR. HERBERT S                     NaN         NaN          84992
# WODRASKA JOHN                             NaN         NaN         189583
# WROBEL BRUCE                              NaN         NaN            NaN
# YEAGER F SCOTT                            NaN         NaN         360300
# YEAP SOON                                 NaN         NaN          55097
#
#                       total_stock_value
# WINOKUR JR. HERBERT S               NaN
# WODRASKA JOHN                       NaN
# WROBEL BRUCE                     139130
# YEAGER F SCOTT                 11884758
# YEAP SOON                        192758
#
# [5 rows x 21 columns]

# %%
# Setting proper NaN values
df_people.replace(to_replace='NaN', value=np.nan, inplace=True)

# %%
# Taking a look at the data types again
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, ALLEN PHILLIP K to YEAP SOON
# Data columns (total 21 columns):
# bonus                        82 non-null float64
# deferral_payments            39 non-null float64
# deferred_income              49 non-null float64
# director_fees                17 non-null float64
# email_address                111 non-null object
# exercised_stock_options      102 non-null float64
# expenses                     95 non-null float64
# from_messages                86 non-null float64
# from_poi_to_this_person      86 non-null float64
# from_this_person_to_poi      86 non-null float64
# loan_advances                4 non-null float64
# long_term_incentive          66 non-null float64
# other                        93 non-null float64
# poi                          146 non-null bool
# restricted_stock             110 non-null float64
# restricted_stock_deferred    18 non-null float64
# salary                       95 non-null float64
# shared_receipt_with_poi      86 non-null float64
# to_messages                  86 non-null float64
# total_payments               125 non-null float64
# total_stock_value            126 non-null float64
# dtypes: bool(1), float64(19), object(1)
# memory usage: 24.1+ KB

# %% [markdown]
# After converting the string value "NaN" to proper numpy format, the data types looks correct now. Email address is object (indicating string values), poi is boolean, and the rest are numeric.

# %% [markdown]
# ##### Taking a closer look at null values

# %%
# Getting counts of NaN values per colum
def nan_counts(columns = df_people.columns):
    nan_counts = df_people[columns].isnull().sum().sort_values(ascending=False).to_frame('count')
    nan_counts['prop'] = round(nan_counts['count'] / 146,4)
    
    return nan_counts

# %%
nan_counts()
# Out:
#                            count    prop
# loan_advances                142  0.9726
# director_fees                129  0.8836
# restricted_stock_deferred    128  0.8767
# deferral_payments            107  0.7329
# deferred_income               97  0.6644
# long_term_incentive           80  0.5479
# bonus                         64  0.4384
# from_this_person_to_poi       60  0.4110
# from_poi_to_this_person       60  0.4110
# from_messages                 60  0.4110
# shared_receipt_with_poi       60  0.4110
# to_messages                   60  0.4110
# other                         53  0.3630
# expenses                      51  0.3493
# salary                        51  0.3493
# exercised_stock_options       44  0.3014
# restricted_stock              36  0.2466
# email_address                 35  0.2397
# total_payments                21  0.1438
# total_stock_value             20  0.1370
# poi                            0  0.0000

# %% [markdown]
# Looks like some features might not be good to use due to lack of data points. I notice that the dataset does not include email address for 23.3% of the people, and seem to lack information about sent and received emails for about 40.4% of the people in the dataset. I might want to try running the ML algorithms both with and without records lacking any email information.

# %%
# Checking if all the users with missing from_messages are the same as the users with missing to_messages, and vice versa.
df_people[df_people['from_messages'].isnull() != df_people['to_messages'].isnull()]
# Out:
# Empty DataFrame
# Columns: [bonus, deferral_payments, deferred_income, director_fees, email_address, exercised_stock_options, expenses, from_messages, from_poi_to_this_person, from_this_person_to_poi, loan_advances, long_term_incentive, other, poi, restricted_stock, restricted_stock_deferred, salary, shared_receipt_with_poi, to_messages, total_payments, total_stock_value]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ##### Getting more info about the features

# %% [markdown]
# Starting with descriptive statistics:

# %%
df_people['poi'].sum()
# Out:
# 18

# %%
display(np.round(df_people.describe(),2))
# Out:
#              bonus  deferral_payments  deferred_income  director_fees  \
# count        82.00              39.00            49.00          17.00
# mean    2374234.61         1642674.15      -1140475.14      166804.88
# std    10713327.97         5161929.97       4025406.38      319891.41
# min       70000.00         -102500.00     -27992891.00        3285.00
# 25%      431250.00           81573.00       -694862.00       98784.00
# 50%      769375.00          227449.00       -159792.00      108579.00
# 75%     1200000.00         1002671.50        -38346.00      113784.00
# max    97343619.00        32083396.00          -833.00     1398517.00
#
#        exercised_stock_options    expenses  from_messages  \
# count             1.020000e+02       95.00          86.00
# mean              5.987054e+06   108728.92         608.79
# std               3.106201e+07   533534.81        1841.03
# min               3.285000e+03      148.00          12.00
# 25%               5.278862e+05    22614.00          22.75
# 50%               1.310814e+06    46950.00          41.00
# 75%               2.547724e+06    79952.50         145.50
# max               3.117640e+08  5235198.00       14368.00
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# count                    86.00                    86.00            4.0
# mean                     64.90                    41.23     41962500.0
# std                      86.98                   100.07     47083208.7
# min                       0.00                     0.00       400000.0
# 25%                      10.00                     1.00      1600000.0
# 50%                      35.00                     8.00     41762500.0
# 75%                      72.25                    24.75     82125000.0
# max                     528.00                   609.00     83925000.0
#
#        long_term_incentive        other  restricted_stock  \
# count                66.00        93.00      1.100000e+02
# mean            1470361.45    919064.97      2.321741e+06
# std             5942759.32   4589252.91      1.251828e+07
# min               69223.00         2.00     -2.604490e+06
# 25%              281250.00      1215.00      2.540180e+05
# 50%              442035.00     52382.00      4.517400e+05
# 75%              938672.00    362096.00      1.002370e+06
# max            48521928.00  42667589.00      1.303223e+08
#
#        restricted_stock_deferred       salary  shared_receipt_with_poi  \
# count                      18.00        95.00                    86.00
# mean                   166410.56    562194.29                  1176.47
# std                   4201494.31   2716369.15                  1178.32
# min                  -7576788.00       477.00                     2.00
# 25%                   -389621.75    211816.00                   249.75
# 50%                   -146975.00    259996.00                   740.50
# 75%                    -75009.75    312117.00                  1888.25
# max                  15456290.00  26704229.00                  5521.00
#
#        to_messages  total_payments  total_stock_value
# count        86.00    1.250000e+02       1.260000e+02
# mean       2073.86    5.081526e+06       6.773957e+06
# std        2582.70    2.906172e+07       3.895777e+07
# min          57.00    1.480000e+02      -4.409300e+04
# 25%         541.25    3.944750e+05       4.945102e+05
# 50%        1211.00    1.101393e+06       1.102872e+06
# 75%        2634.75    2.093263e+06       2.949847e+06
# max       15149.00    3.098866e+08       4.345095e+08

# %%
print("All:")
display(df_people['poi'].value_counts())
print(" ")
(print("Only people with email address:"))
display(df_people[df_people['email_address'].isnull()==False]['poi'].value_counts())
print(" ")
(print("Only people with additional email data:"))
display(df_people[df_people['from_messages'].isnull()==False]['poi'].value_counts())
# Out:
# All:
# False    128
# True      18
# Name: poi, dtype: int64
#
# Only people with email address:
# False    93
# True     18
# Name: poi, dtype: int64
#
# Only people with additional email data:
# False    72
# True     14
# Name: poi, dtype: int64

# %% [markdown]
# The dataset contains 18 known POIs, which is roughly 12% of the people in the dataset. It makes sense to focus on the differences between the POIs and non-POIs for feature selection.
#
# The dataset has email address for all known POIs, and additional email information for roughly 78% of the POIs.

# %%
#Looking for differences between POIs and others
def boxplot_by_poi(features = False):
    
    if features:
        features = features
    else:
        features = ['bonus', 'deferral_payments', 'deferred_income', 'director_fees',
       'exercised_stock_options', 'expenses', 'from_messages',
       'from_poi_to_this_person', 'from_this_person_to_poi', 'loan_advances',
       'long_term_incentive', 'other', 'restricted_stock',
       'restricted_stock_deferred', 'salary', 'shared_receipt_with_poi',
       'to_messages', 'total_payments', 'total_stock_value']
    
    for ind in df_people[features]:
        df_temp = df_people[['poi', ind]].dropna().copy()
        df_grouped = df_temp.groupby('poi')
        display(np.round(df_grouped.describe(),2))

        top_10 = df_people[ind].quantile(.9)
        bottom_10 = df_people[ind].quantile(.1)
        ax = df_temp.boxplot(by = 'poi')
        ax.set_ylim(bottom_10, top_10)
        plt.suptitle('')
        plt.xlabel('POI')
        plt.show()

# %%
boxplot_by_poi()
# Out:
#       bonus                                                          \
#       count        mean          std       min       25%        50%
# poi
# False  66.0  2446776.35  11917761.23   70000.0  400000.0   725000.0
# True   16.0  2074999.94   2047437.32  200000.0  775000.0  1275000.0
#
#
#              75%         max
# poi
# False  1000000.0  97343619.0
# True   2062500.0   7000000.0
#       deferral_payments                                                        \
#                   count        mean         std       min       25%       50%
# poi
# False              34.0  1807788.85  5510228.01 -102500.0  87468.75  382532.5
# True                5.0   519894.20   912889.50   10259.0  27610.00  202911.0
#
#
#               75%         max
# poi
# False  1066353.75  32083396.0
# True    214678.00   2144013.0
#       deferred_income                                                  \
#                 count        mean         std         min         25%
# poi
# False            38.0 -1170916.68  4531596.79 -27992891.0  -581243.75
# True             11.0 -1035313.45  1334971.88  -3504386.0 -1860244.50
#
#
#             50%       75%     max
# poi
# False -123142.0  -37086.0 -1042.0
# True  -262500.0 -122031.0  -833.0
#       director_fees                                                   \
#               count       mean        std     min      25%       50%
# poi
# False          17.0  166804.88  319891.41  3285.0  98784.0  108579.0
#
#
#             75%        max
# poi
# False  113784.0  1398517.0
#       exercised_stock_options                                                 \
#                         count         mean          std       min        25%
# poi
# False                    90.0   5390155.12  32755563.86    3285.0   450758.5
# True                     12.0  10463793.67  12382588.13  384728.0  1456581.0
#
#
#              50%          75%          max
# poi
# False  1043324.5   2204999.25  311764000.0
# True   3914557.0  19386043.75   34348384.0
#       expenses                                                             \
#          count       mean        std      min       25%      50%      75%
# poi
# False     77.0  120149.58  592508.49    148.0  18834.00  46145.0  78552.0
# True      18.0   59873.83   37524.66  16514.0  31323.25  50448.5  84125.0
#
#
#              max
# poi
# False  5235198.0
# True    127017.0
#       from_messages
#               count    mean      std   min   25%   50%    75%      max
# poi
# False          72.0  668.76  1979.00  12.0  20.5  41.0  216.5  14368.0
# True           14.0  300.36   805.84  16.0  33.0  44.5  101.5   3069.0
#       from_poi_to_this_person
#                         count   mean    std   min   25%   50%     75%    max
# poi
# False                    72.0  58.50  88.00   0.0  10.0  26.5   61.75  528.0
# True                     14.0  97.79  76.06  13.0  44.5  62.0  135.75  240.0
#       from_this_person_to_poi
#                         count   mean     std  min   25%   50%    75%    max
# poi
# False                    72.0  36.28   85.14  0.0   0.0   6.0  23.25  411.0
# True                     14.0  66.71  158.29  4.0  12.5  15.5  28.75  609.0
#       loan_advances                                                   \
#               count        mean          std         min         25%
# poi
# False           3.0  28775000.0  47768000.53    400000.0   1200000.0
# True            1.0  81525000.0          NaN  81525000.0  81525000.0
#
#
#               50%         75%         max
# poi
# False   2000000.0  42962500.0  83925000.0
# True   81525000.0  81525000.0  81525000.0
#       long_term_incentive                                              \
#                     count        mean         std      min        25%
# poi
# False                54.0  1529361.24  6564217.09  69223.0  260893.25
# True                 12.0  1204862.42   991658.26  71023.0  368978.00
#
#
#              50%        75%         max
# poi
# False   395480.5   694862.0  48521928.0
# True   1134637.0  1646772.0   3600000.0
#       other                                                            \
#       count       mean         std    min     25%       50%       75%
# poi
# False  75.0  946921.19  4983723.25    2.0   959.5   25553.0  387630.5
# True   18.0  802997.39  2417567.95  486.0  4979.5  149204.0  260772.5
#
#
#               max
# poi
# False  42667589.0
# True   10359729.0
#       restricted_stock                                                \
#                  count        mean          std        min       25%
# poi
# False             93.0  2322311.53  13541935.65 -2604490.0  213063.0
# True              17.0  2318620.76   3620810.58   126027.0  393818.0
#
#
#             50%        75%          max
# poi
# False  417619.0   934065.0  130322299.0
# True   985032.0  2502063.0   14761694.0
#       restricted_stock_deferred                                               \
#                           count       mean         std        min        25%
# poi
# False                      18.0  166410.56  4201494.31 -7576788.0 -389621.75
#
#
#             50%       75%         max
# poi
# False -146975.0 -75009.75  15456290.0
#       salary                                                                   \
#        count       mean         std       min        25%       50%        75%
# poi
# False   78.0  601152.50  2997169.37     477.0  207215.75  254570.0  300229.75
# True    17.0  383444.88   278359.73  158403.0  240189.00  278601.0  415189.00
#
#
#               max
# poi
# False  26704229.0
# True    1111258.0
#       shared_receipt_with_poi                                          \
#                         count     mean     std   min      25%     50%
# poi
# False                    72.0  1058.53  1132.5   2.0   191.50   594.0
# True                     14.0  1783.00  1265.0  91.0  1059.25  1589.0
#
#
#            75%     max
# poi
# False  1635.50  4527.0
# True   2165.25  5521.0
#       to_messages
#             count     mean      std    min      25%     50%      75%      max
# poi
# False        72.0  2007.11  2693.17   57.0   513.75   944.0  2590.75  15149.0
# True         14.0  2417.14  1961.86  225.0  1115.75  1875.0  2969.25   7991.0
#       total_payments                                                          \
#                count        mean          std      min        25%        50%
# poi
# False          107.0  4605104.63  29904851.89    148.0   341018.5  1057548.0
# True            18.0  7913589.78  23965492.21  91093.0  1142396.0  1754027.5
#
#
#               75%          max
# poi
# False  2031214.00  309886585.0
# True   2665344.75  103559793.0
#       total_stock_value                                                 \
#                   count        mean          std       min         25%
# poi
# False             108.0  6375338.54  41730841.58  -44093.0   428217.25
# True               18.0  9165670.94  13841168.37  126027.0  1016450.25
#
#
#              50%          75%          max
# poi
# False  1032337.5   2372703.25  434509511.0
# True   2206835.5  10511334.75   49110078.0

# %% [markdown]
# Based on this *bonus, deferred_income, from_poi_to_this_person, from_this_person_to_poi, long_term_incentive, restricted_stock, salary, shared_receipt_with_poi* and *total_stock_value* looks like the features with the most potential. I will do my first run using these features.
#
# Looking only at the boxplots, loan_advances and deferral_payments also looks like promising features, but closer inspection reveals that most of the POIs are missing data for those features.

# %%
# Making list of features to use
features_to_use = ['bonus', 'deferred_income', 'from_poi_to_this_person', 
                   'from_this_person_to_poi', 'long_term_incentive', 'restricted_stock', 
                   'salary', 'shared_receipt_with_poi', 'total_stock_value']

# %% [markdown]
# ### Task 2: Remove outliers

# %%
# find salary and bonus outliers
plt.scatter(df_people['salary'], df_people['bonus'] )
    
plt.xlabel("salary")
plt.ylabel("bonus")
plt.show()

# %%
df_people[df_people['salary'] == df_people['salary'].max()]
# Out:
#             bonus  deferral_payments  deferred_income  director_fees  \
# TOTAL  97343619.0         32083396.0      -27992891.0      1398517.0
#
#       email_address  exercised_stock_options   expenses  from_messages  \
# TOTAL           NaN              311764000.0  5235198.0            NaN
#
#        from_poi_to_this_person  from_this_person_to_poi        ...          \
# TOTAL                      NaN                      NaN        ...
#
#        long_term_incentive       other    poi  restricted_stock  \
# TOTAL           48521928.0  42667589.0  False       130322299.0
#
#        restricted_stock_deferred      salary  shared_receipt_with_poi  \
# TOTAL                 -7576788.0  26704229.0                      NaN
#
#        to_messages  total_payments  total_stock_value
# TOTAL          NaN     309886585.0        434509511.0
#
# [1 rows x 21 columns]

# %%
df_people = df_people.drop('TOTAL')

# %% [markdown]
# I have remove the column showing total values. Next I'll take a look at the people with the most features with null values.

# %%
missing_feature_counts = df_people.isna().transpose().sum().sort_values(ascending=False)


missing_feature_counts.head(20)
# Out:
# LOCKHART EUGENE E                20
# WROBEL BRUCE                     18
# WHALEY DAVID A                   18
# GRAMM WENDY L                    18
# THE TRAVEL AGENCY IN THE PARK    18
# GILLIS JOHN                      17
# WODRASKA JOHN                    17
# SAVAGE FRANK                     17
# SCRIMSHAW MATTHEW                17
# CLINE KENNETH W                  17
# WAKEHAM JOHN                     17
# CHAN RONNIE                      16
# MENDELSOHN JOHN                  16
# PEREIRA PAULO V. FERRAZ          16
# BLAKE JR. NORMAN P               16
# YEAP SOON                        16
# GATHMANN WILLIAM D               16
# URQUHART JOHN A                  16
# FUGH JOHN L                      16
# LOWRY CHARLES P                  16
# dtype: int64

# %%
# Taking a closer look at the top 5
df_people.loc[missing_feature_counts.head(5).index,:]
# Out:
#                                bonus  deferral_payments  deferred_income  \
# LOCKHART EUGENE E                NaN                NaN              NaN
# WROBEL BRUCE                     NaN                NaN              NaN
# WHALEY DAVID A                   NaN                NaN              NaN
# GRAMM WENDY L                    NaN                NaN              NaN
# THE TRAVEL AGENCY IN THE PARK    NaN                NaN              NaN
#
#                                director_fees email_address  \
# LOCKHART EUGENE E                        NaN           NaN
# WROBEL BRUCE                             NaN           NaN
# WHALEY DAVID A                           NaN           NaN
# GRAMM WENDY L                       119292.0           NaN
# THE TRAVEL AGENCY IN THE PARK            NaN           NaN
#
#                                exercised_stock_options  expenses  \
# LOCKHART EUGENE E                                  NaN       NaN
# WROBEL BRUCE                                  139130.0       NaN
# WHALEY DAVID A                                 98718.0       NaN
# GRAMM WENDY L                                      NaN       NaN
# THE TRAVEL AGENCY IN THE PARK                      NaN       NaN
#
#                                from_messages  from_poi_to_this_person  \
# LOCKHART EUGENE E                        NaN                      NaN
# WROBEL BRUCE                             NaN                      NaN
# WHALEY DAVID A                           NaN                      NaN
# GRAMM WENDY L                            NaN                      NaN
# THE TRAVEL AGENCY IN THE PARK            NaN                      NaN
#
#                                from_this_person_to_poi        ...          \
# LOCKHART EUGENE E                                  NaN        ...
# WROBEL BRUCE                                       NaN        ...
# WHALEY DAVID A                                     NaN        ...
# GRAMM WENDY L                                      NaN        ...
# THE TRAVEL AGENCY IN THE PARK                      NaN        ...
#
#                                long_term_incentive     other    poi  \
# LOCKHART EUGENE E                              NaN       NaN  False
# WROBEL BRUCE                                   NaN       NaN  False
# WHALEY DAVID A                                 NaN       NaN  False
# GRAMM WENDY L                                  NaN       NaN  False
# THE TRAVEL AGENCY IN THE PARK                  NaN  362096.0  False
#
#                                restricted_stock  restricted_stock_deferred  \
# LOCKHART EUGENE E                           NaN                        NaN
# WROBEL BRUCE                                NaN                        NaN
# WHALEY DAVID A                              NaN                        NaN
# GRAMM WENDY L                               NaN                        NaN
# THE TRAVEL AGENCY IN THE PARK               NaN                        NaN
#
#                                salary  shared_receipt_with_poi  to_messages  \
# LOCKHART EUGENE E                 NaN                      NaN          NaN
# WROBEL BRUCE                      NaN                      NaN          NaN
# WHALEY DAVID A                    NaN                      NaN          NaN
# GRAMM WENDY L                     NaN                      NaN          NaN
# THE TRAVEL AGENCY IN THE PARK     NaN                      NaN          NaN
#
#                                total_payments  total_stock_value
# LOCKHART EUGENE E                         NaN                NaN
# WROBEL BRUCE                              NaN           139130.0
# WHALEY DAVID A                            NaN            98718.0
# GRAMM WENDY L                        119292.0                NaN
# THE TRAVEL AGENCY IN THE PARK        362096.0                NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# I'll remove THE TRAVEL AGENCY IN THE PARK based on the name, as it does not appear to be a person. I'll also remove LOCKHART EUGENE E, as the record does not contain any data other than not being a POI.

# %%
df_people = df_people.drop(['THE TRAVEL AGENCY IN THE PARK', 'LOCKHART EUGENE E'])

# %% [markdown]
# ### Task 3: Create new feature(s)
# - Store to my_dataset for easy export below.

# %%
df_people.columns
# Out:
# Index(['bonus', 'deferral_payments', 'deferred_income', 'director_fees',
#        'email_address', 'exercised_stock_options', 'expenses', 'from_messages',
#        'from_poi_to_this_person', 'from_this_person_to_poi', 'loan_advances',
#        'long_term_incentive', 'other', 'poi', 'restricted_stock',
#        'restricted_stock_deferred', 'salary', 'shared_receipt_with_poi',
#        'to_messages', 'total_payments', 'total_stock_value'],
#       dtype='object')

# %%
def fraction_feature(feat_a, feat_b):
    return np.round(
    df_people[feat_a].divide(
        df_people[feat_b], axis='index').fillna(0),4)

# %%
# new feature for fraction of messages sent from person to a poi
df_people['fraction_to_poi'] = fraction_feature('from_this_person_to_poi', 'from_messages')
# new feature for fraction of messages sent to a person from a poi
df_people['fraction_from_poi'] = fraction_feature('from_poi_to_this_person', 'to_messages')
# new feature for fraction of messages sent to a person from a poi
df_people['fraction_shared_with_poi'] = fraction_feature('shared_receipt_with_poi', 'to_messages')
# new feature for bonus to salary ratio
df_people['bonus_to_salary_ratio'] = fraction_feature('bonus', 'salary')

# %%
# Checking potential of new features
new_features = ['fraction_to_poi', 'fraction_from_poi', 
                'fraction_shared_with_poi', 'bonus_to_salary_ratio']

boxplot_by_poi(new_features)
# Out:
#       fraction_to_poi
#                 count  mean   std  min   25%   50%   75%   max
# poi
# False           125.0  0.09  0.17  0.0  0.00  0.00  0.07  1.00
# True             18.0  0.27  0.20  0.0  0.18  0.25  0.37  0.66
#       fraction_from_poi
#                   count  mean   std  min   25%   50%   75%   max
# poi
# False             125.0  0.02  0.04  0.0  0.00  0.00  0.03  0.22
# True               18.0  0.04  0.03  0.0  0.02  0.03  0.05  0.14
#       fraction_shared_with_poi
#                          count  mean   std  min   25%   50%   75%   max
# poi
# False                    125.0  0.33  0.36  0.0  0.00  0.14  0.66  0.97
# True                      18.0  0.61  0.37  0.0  0.44  0.68  0.92  1.00
#       bonus_to_salary_ratio
#                       count  mean   std  min  25%   50%   75%    max
# poi
# False                 125.0  1.79  3.29  0.0  0.0  0.61  2.55  23.58
# True                   18.0  4.78  5.40  0.0  2.3  3.86  5.16  24.53

# %%
# features to use in ML algorithms
features_list = ['poi'] + features_to_use + new_features

# %%
# tmp_list = list(df_people.columns)

# tmp_list.remove('poi')

# features_to_use = ['poi'] + tmp_list

# %%
# Getting counts of missing data for the selected features
nan_counts(features_list)
# Out:
#                           count    prop
# deferred_income              95  0.6507
# long_term_incentive          78  0.5342
# bonus                        62  0.4247
# shared_receipt_with_poi      57  0.3904
# from_this_person_to_poi      57  0.3904
# from_poi_to_this_person      57  0.3904
# salary                       49  0.3356
# restricted_stock             34  0.2329
# total_stock_value            18  0.1233
# bonus_to_salary_ratio         0  0.0000
# fraction_shared_with_poi      0  0.0000
# fraction_from_poi             0  0.0000
# fraction_to_poi               0  0.0000
# poi                           0  0.0000

# %% [markdown]
# #### Preparation

# %%
my_dataset = df_people.fillna('NaN').to_dict(orient='index')
my_dataset_with_email = df_people[
    df_people['from_messages'].isnull()==False].fillna('NaN').to_dict(orient='index')


print("Count of my_dataset:", len(my_dataset))
print("Count excluding people with missing email information:", len(my_dataset_with_email))
# Out:
# Count of my_dataset: 143
# Count excluding people with missing email information: 86

# %%
### Extract features and labels from dataset for local testing

data = featureFormat(my_dataset, features_list, sort_keys = True)
labels, features = targetFeatureSplit(data)

features_train, features_test, labels_train, labels_test = \
train_test_split(features, labels, random_state = 42, test_size = 0.3)

data_email = featureFormat(my_dataset_with_email, features_list, sort_keys = True)
email_labels, email_features = targetFeatureSplit(data_email)

em_features_train, em_features_test, em_labels_train, em_labels_test = \
train_test_split(email_features, email_labels, random_state = 42, test_size = 0.3)

# %%
len(em_features_train)
# Out:
# 60

# %% [markdown]
# #### Transformation and feature scaling

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()

# features_train = scaler.fit_transform(features_train)
# em_features_train = scaler.fit_transform(em_features_train)

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()

# features_train = scaler.fit_transform(features_train)
# em_features_train = scaler.fit_transform(em_features_train)

# %% [markdown]
# The two cells commented out above where tried and abandoned (at least for now). Improved scaling has been implemented in scores_for_classifier() below.

# %% [markdown]
# ### Task 4: Try a varity of classifiers
# - Please name your classifier clf for easy export below.
# - Note that if you want to do PCA or other multi-stage operations, you'll need to use Pipelines.
#     - For more info: http://scikit-learn.org/stable/modules/pipeline.html

# %%
def report_scores(features_test, labels_test, pred):
    
    accuracy = accuracy_score(labels_test, pred)
    precision = precision_score(labels_test, pred)
    recall = recall_score(labels_test, pred)
    f1 = f1_score(labels_test, pred)
    
    cm = confusion_matrix(labels_test, pred)
    cm_index = [np.array(['Actual', 'Actual']),np.array([0, 1])]
    cm_columns = [np.array(['Predicted', 'Predicted']),np.array([0, 1])]

    df_cm = pd.DataFrame(confusion_matrix(labels_test, pred), columns=cm_columns, index=cm_index)
    display(df_cm)
    
    print("Number of people in test set:",len(features_test))
    print("Number of predicted POIs:",sum(pred))
    print("Number of actual POIs in test set:",sum(labels_test))
    print('')
    print("Accuracy score:", round(accuracy, 4))
    print("Precision score:", round(precision, 4))
    print("Recall score:", round(recall, 4))
    print("F1 score:", round(f1,4))

# %%
# Importing classifier algorithms to try
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

# %%
# Provided to give you a starting point. Try a variety of classifiers.
# Naive Bayes: Gaussian

from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# %%
def scores_for_classifier(classifier, email=False, feat_train=features_train,lab_train = labels_train,
                          feat_test = features_test, lab_test = labels_test):
    
    clf = make_pipeline(StandardScaler(), PCA(n_components=2), classifier)
    
    if email:
        feat_train = em_features_train
        lab_train = em_labels_train
        feat_test = em_features_test
        lab_test = em_labels_test
        
    clf.fit(feat_train, lab_train)
    pred = clf.predict(feat_test)
    
    return report_scores(feat_test, lab_test, pred)

# %%
# Running Naive Bayes algorithm for all records
scores_for_classifier(GaussianNB())
# Out:
#          Predicted
#                  0  1
# Actual 0        35  1
#        1         4  2
# Number of people in test set: 42
# Number of predicted POIs: 3.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.881
# Precision score: 0.6667
# Recall score: 0.3333
# F1 score: 0.4444

# %%
# Running Naive Bayes algorithm for records with email info only
scores_for_classifier(GaussianNB(), email=True)
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#          Predicted
#                  0  1
# Actual 0        24  0
#        1         2  0
# Number of people in test set: 26
# Number of predicted POIs: 0.0
# Number of actual POIs in test set: 2.0
#
# Accuracy score: 0.9231
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0

# %%
# Running Decision tree algorithm for all records
scores_for_classifier(DecisionTreeClassifier())
# Out:
#          Predicted
#                  0  1
# Actual 0        34  2
#        1         3  3
# Number of people in test set: 42
# Number of predicted POIs: 5.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.881
# Precision score: 0.6
# Recall score: 0.5
# F1 score: 0.5455

# %%
# Running Decision tree algorithm for records with email info only
scores_for_classifier(DecisionTreeClassifier(), email=True)
# Out:
#          Predicted
#                  0  1
# Actual 0        20  4
#        1         2  0
# Number of people in test set: 26
# Number of predicted POIs: 4.0
# Number of actual POIs in test set: 2.0
#
# Accuracy score: 0.7692
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0

# %%
# tmp_df = pd.DataFrame(np.array([em_labels_test,pred]))

# tmp_df = tmp_df.append(tmp_df.sum(),ignore_index=True).copy().transpose()

# tmp_df = tmp_df.rename(columns={0:'Actual',1:'Predicted',2:'Total'})

# tmp_df[tmp_df['Total'] > 1]

# %%
# Running support vector machine algorithm  with rbf kernel for all records
scores_for_classifier(SVC(C=1, kernel='rbf'))
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#          Predicted
#                  0  1
# Actual 0        36  0
#        1         6  0
# Number of people in test set: 42
# Number of predicted POIs: 0.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.8571
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0

# %%
# Running support vector machine algorithm  with rbf kernel for records with email info only
scores_for_classifier(SVC(C=1, kernel='rbf'), email=True)
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#          Predicted
#                  0  1
# Actual 0        24  0
#        1         2  0
# Number of people in test set: 26
# Number of predicted POIs: 0.0
# Number of actual POIs in test set: 2.0
#
# Accuracy score: 0.9231
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0

# %%
# Running support vector machine algorithm  with linear kernel for all records
scores_for_classifier(LinearSVC(C=1))
# Out:
#          Predicted
#                  0  1
# Actual 0        36  0
#        1         5  1
# Number of people in test set: 42
# Number of predicted POIs: 1.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.881
# Precision score: 1.0
# Recall score: 0.1667
# F1 score: 0.2857

# %%
# Running support vector machine algorithm  with linear kernel for records with email info only
scores_for_classifier(LinearSVC(C=1), email=True)
# Out:
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ggaasemyr/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#          Predicted
#                  0  1
# Actual 0        24  0
#        1         2  0
# Number of people in test set: 26
# Number of predicted POIs: 0.0
# Number of actual POIs in test set: 2.0
#
# Accuracy score: 0.9231
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0

# %%
# Running random forest algorithm for all records
scores_for_classifier(RandomForestClassifier())
# Out:
#          Predicted
#                  0  1
# Actual 0        35  1
#        1         4  2
# Number of people in test set: 42
# Number of predicted POIs: 3.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.881
# Precision score: 0.6667
# Recall score: 0.3333
# F1 score: 0.4444

# %%
# Running random forest algorithm for records with email info only
scores_for_classifier(RandomForestClassifier(), email=True)
# Out:
#          Predicted
#                  0  1
# Actual 0        24  0
#        1         1  1
# Number of people in test set: 26
# Number of predicted POIs: 1.0
# Number of actual POIs in test set: 2.0
#
# Accuracy score: 0.9615
# Precision score: 1.0
# Recall score: 0.5
# F1 score: 0.6667

# %% [markdown]
# Looking at the precision and recall scores for the different classifier algorithms, including all the data (POIs and non-POIs) seems to make most sense. In the next section I will skip excluding non-email records.
#
# Some classifiers do not perform well at all, regardless of whether non-email records are excluded or not. I suspect this might be due to the imbalanced dataset, where the target group (the POIs) are much fewer than the non-target group.

# %%
train_pois = int(sum(labels_train))
test_pois = int(sum(labels_test))
train_non = len(labels_train) - train_pois
test_non = len(labels_test) - test_pois

print("There are {0} known POIs and {1} non-POIs in the training data.".format(train_pois, train_non))
print("There are {0} known POIs and {1} non-POIs in the training data.".format(test_pois, test_non))
# Out:
# There are 12 known POIs and 86 non-POIs in the training data.
# There are 6 known POIs and 36 non-POIs in the training data.

# %% [markdown]
# #### Running the classifiers again with oversampling

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

ft_resampled, lt_resampled = SMOTE(random_state=42).fit_sample(features_train, labels_train)

# %%
# Running Naive Bayes algorithm for all records
scores_for_classifier(GaussianNB(), feat_train=ft_resampled, lab_train=lt_resampled)
# Out:
#          Predicted
#                  0  1
# Actual 0        28  8
#        1         1  5
# Number of people in test set: 42
# Number of predicted POIs: 13.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.7857
# Precision score: 0.3846
# Recall score: 0.8333
# F1 score: 0.5263

# %% [markdown]
# The Gaussian Naive Bayes algorithm produces mixed results after resampling. While it earlier would not predict a few POIs, and miss 5 out of 6, it now correctly predicts 5 out of 6 people as POIs, but also predict many more people incorrectly as POIs.

# %%
# Running Decision tree algorithm for all records
scores_for_classifier(DecisionTreeClassifier(),  feat_train=ft_resampled, lab_train=lt_resampled)
# Out:
#          Predicted
#                  0  1
# Actual 0        28  8
#        1         3  3
# Number of people in test set: 42
# Number of predicted POIs: 11.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.7381
# Precision score: 0.2727
# Recall score: 0.5
# F1 score: 0.3529

# %% [markdown]
# The desicision tree alogorithm performs a little worse after resampling: The recall score stays the same, while the precision score drops from 0.6 to 0.3.

# %%
# Running support vector machine algorithm  with rbf kernel for all records
scores_for_classifier(SVC(C=1, kernel='rbf'),  feat_train=ft_resampled, lab_train=lt_resampled)
# Out:
#          Predicted
#                  0   1
# Actual 0        23  13
#        1         0   6
# Number of people in test set: 42
# Number of predicted POIs: 19.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.6905
# Precision score: 0.3158
# Recall score: 1.0
# F1 score: 0.48

# %% [markdown]
# The support vector classifier with rbf kernel went from not predicting any correct POIs before resampling to predicting correctly all the POIs after resampling, while also incorrectly predicting many other people as POIs.

# %%
# Running support vector machine algorithm  with linear kernel for all records
scores_for_classifier(LinearSVC(C=1),  feat_train=ft_resampled, lab_train=lt_resampled)
# Out:
#          Predicted
#                  0  1
# Actual 0        29  7
#        1         1  5
# Number of people in test set: 42
# Number of predicted POIs: 12.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.8095
# Precision score: 0.4167
# Recall score: 0.8333
# F1 score: 0.5556

# %% [markdown]
# For SVC with linear kernel, the precision score is much worse after resampling, while the recall score is much better.

# %%
# Running random forest algorithm for all records
scores_for_classifier(RandomForestClassifier(),  feat_train=ft_resampled, lab_train=lt_resampled)
# Out:
#          Predicted
#                  0  1
# Actual 0        29  7
#        1         3  3
# Number of people in test set: 42
# Number of predicted POIs: 10.0
# Number of actual POIs in test set: 6.0
#
# Accuracy score: 0.7619
# Precision score: 0.3
# Recall score: 0.5
# F1 score: 0.375

# %% [markdown]
# For Random forest the result is mixed, and probably a little worse, after resampling. The recall score goes up a little, while the precision score is much worse, being perfect before (no incorrectly labeled POIs).

# %% [markdown]
# Based on the F1 scores the random forest and linear SVC classifiers shows the most potential. I will tune the parameters of both in the following section.

# %% [markdown]
# ### Task 5: Tune your classifier
# - Tune your classifier to achieve better than .3 precision and recall using our testing script.
# - Check the tester.py script in the final project folder for details on the evaluation method, especially the test_classifier function.
# - Because of the small size of the dataset, the script uses stratified shuffle split cross validation. For more info:
#     - [scikit-learn documentation](http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.StratifiedShuffleSplit.html)

# %%
# Importing libraries for this section

from sklearn.preprocessing import MinMaxScaler

# from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report

# %%
# Function to format confusion matrix for display
def display_confusion_matrix(labels_test, pred):
    cm = confusion_matrix(labels_test, pred)
    cm_index = [np.array(['Actual', 'Actual']),np.array([0, 1])]
    cm_columns = [np.array(['Predicted', 'Predicted']),np.array([0, 1])]

    df_cm = pd.DataFrame(confusion_matrix(labels_test, pred), columns=cm_columns, index=cm_index)
    display(df_cm)

# %% [markdown]
# #### Tuning Random forest classifier

# %%
# Setting up random forest pipeline
rf_pipeline = Pipeline(steps=[
    ('oversample', SMOTE(random_state=42)),
    ('scaler', StandardScaler()),
    ('reduce_dim', PCA()), 
    ('clf', RandomForestClassifier(criterion='entropy', n_jobs=-1))
])

# %%
# Testing various parameter combinations

# Setting up parameter grid for grid search
# rf_param_grid = [
#     {'oversample': [None, SMOTE(random_state=42)],
#      'scaler': [None, StandardScaler()],
#      'reduce_dim': [None, PCA(2), PCA(5), PCA(10)]}
#      ]

# rf_param_grid = [
#     {'oversample': [None, SMOTE(random_state=42)],    
#      'scaler': [None, StandardScaler(), Normalizer(), MinMaxScaler()],
#      'reduce_dim': [None, PCA(2), PCA(5), PCA(10)],
#      'clf__min_samples_split': [10, 50, 100, 200],
#      'clf__min_samples_leaf': [5, 10, 20],
#     'clf__n_estimators': [5,10,50]},
#      ]

# rf_param_grid = [
#     {'oversample': [None, SMOTE(random_state=42)],    
#      'scaler': [None, StandardScaler(), Normalizer(), MinMaxScaler()],
#      'reduce_dim': [None, PCA(2), PCA(5), PCA(10)],
#      'clf__max_depth': [5, 10],
#      'clf__min_samples_split': [2,5,10],
#     'clf__n_estimators': [10,15,20]},
#      ]

# rf_param_grid = [
#     {'oversample': [None, SMOTE(random_state=42)],    
#      'scaler': [None, StandardScaler(), Normalizer()],
#      'reduce_dim': [None, PCA(5), PCA(10)],
#      'clf__max_depth': [3,5,10,15],
#      'clf__min_samples_split': [2,3,5,10],
#      'clf__min_samples_leaf': [1,5,10,20],
#     'clf__n_estimators': [5,10,20,30,50]},
#      ]

# rf_param_grid = [{
#     'oversample': [None, SMOTE(random_state=42)],    
#     'scaler': [None, StandardScaler(), Normalizer()],
#     'reduce_dim': [None, PCA(5), PCA(10)],
#      'clf__max_features': [3,5,'auto'],
#      'clf__max_depth': [5,10,15],
#      'clf__min_samples_split': [3,5,10],
#      'clf__min_samples_leaf': [1,5,10],
#     'clf__n_estimators': [100]},
#      ]

rf_param_grid = [
    {'oversample': [None, SMOTE(random_state=42)],    
     'scaler': [None, StandardScaler(), Normalizer()],
     'reduce_dim': [None, PCA(5)],
     'clf__max_features': [3,5,'auto'],
     'clf__max_depth': [5,10],
     'clf__min_samples_split': [3,5,10],
     'clf__min_samples_leaf': [1,2,5],
    'clf__n_estimators': [100]},
     ]

# %%
import warnings
warnings.filterwarnings('ignore')

# Setting up grid search 
rf_grid_search = GridSearchCV(estimator=rf_pipeline, param_grid=rf_param_grid, n_jobs=-1, scoring='f1')

rf_grid_search.fit(features_train, labels_train)

warnings.filterwarnings('default')

# %%
rf_grid_search.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('oversample', SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=42, ratio='auto', svm_estimator=None)), ('scaler', Normalizer(copy=True, norm='l2')), ('reduce_dim', None), ('clf', RandomForestClassifier(bootstrap=True, class_weight=N..._jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
rf_grid_search.best_estimator_.named_steps
# Out:
# {'clf': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=5, max_features=3, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=5, min_samples_split=5,
#              min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#     out_step=0.5, random_state=42, ratio='auto', svm_estimator=None),
#  'reduce_dim': None,
#  'scaler': Normalizer(copy=True, norm='l2')}

# %%
feat_imp = rf_grid_search.best_estimator_.named_steps['clf'].feature_importances_

df_feat_imp = pd.DataFrame(feat_imp.round(4),
index=features_list[1:],columns = ['Feature Importance'])

df_feat_imp.sort_values('Feature Importance', ascending=0)
# Out:
#                           Feature Importance
# deferred_income                       0.2103
# from_this_person_to_poi               0.1474
# bonus                                 0.1437
# long_term_incentive                   0.1281
# salary                                0.0991
# from_poi_to_this_person               0.0708
# shared_receipt_with_poi               0.0590
# restricted_stock                      0.0583
# total_stock_value                     0.0436
# bonus_to_salary_ratio                 0.0338
# fraction_shared_with_poi              0.0036
# fraction_to_poi                       0.0022
# fraction_from_poi                     0.0000

# %%
print('Best score for training data:', rf_grid_search.best_score_)
print('')

print(rf_grid_search.best_params_)
print(rf_grid_search.score(features_test, labels_test))

pred = rf_grid_search.predict(features_test)


display_confusion_matrix(labels_test, pred)
print("Accuracy:", accuracy_score(labels_test, pred))
print("Precision:", precision_score(labels_test, pred))
print("Recall:", recall_score(labels_test, pred))
print("F1:", f1_score(labels_test, pred))

print(classification_report(labels_test, pred))
# Out:
# Best score for training data: 0.504761904762
#
# {'clf__max_depth': 5, 'clf__max_features': 3, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 5, 'clf__n_estimators': 100, 'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=42, ratio='auto', svm_estimator=None), 'reduce_dim': None, 'scaler': Normalizer(copy=True, norm='l2')}
# 0.533333333333
#          Predicted
#                  0  1
# Actual 0        31  5
#        1         2  4
# Accuracy: 0.833333333333
# Precision: 0.444444444444
# Recall: 0.666666666667
# F1: 0.533333333333
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.86      0.90        36
#         1.0       0.44      0.67      0.53         6
#
# avg / total       0.87      0.83      0.85        42

# %%
print(rf_grid_search.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('oversample', SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=42, ratio='auto', svm_estimator=None)), ('scaler', Normalizer(copy=True, norm='l2')), ('reduce_dim', None), ('clf', RandomForestClassifier(bootstrap=True, class_weight=N..._jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %% [markdown]
# #### Tuning SVC with linear kernel

# %%
# Setting up pipeline
svc_linear_pipeline = Pipeline(steps=[
    ('oversample', SMOTE(random_state=42)),
    ('scaler', StandardScaler()),
    ('reduce_dim', PCA()), 
    ('clf', LinearSVC(loss='hinge'))
])

# %%
# Testing various parameter combinations

# svc_linear_param_grid = [
#     {'oversample': [None, SMOTE(random_state=42)],    
#      'scaler': [None, StandardScaler(), Normalizer(), MinMaxScaler()],
#      'reduce_dim': [None, PCA(2), PCA(3),PCA(4),PCA(5), PCA(10)],
#      'clf__C': [0.4,0.5,0.6,1,2,10,100,1000]
#     }
# ]

svc_linear_param_grid = [
    {'oversample': [None, SMOTE(random_state=42)],    
     'scaler': [None, StandardScaler(), Normalizer(), MinMaxScaler()],
     'reduce_dim': [None, PCA(2), PCA(3),PCA(4),PCA(5), PCA(10)],
     'clf__C': [1,10,100,1000],
     'clf__loss': ['hinge', 'squared_hinge']
    }
]

# %%
import warnings
warnings.filterwarnings('ignore')

# Setting up grid search
svc_linear_grid_search = GridSearchCV(estimator=svc_linear_pipeline, param_grid=svc_linear_param_grid, n_jobs=-1, scoring='f1')

svc_linear_grid_search.fit(features_train, labels_train)

warnings.filterwarnings('default')

# %%
svc_linear_grid_search.best_estimator_.named_steps
# Out:
# {'clf': LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#       intercept_scaling=1, loss='hinge', max_iter=1000, multi_class='ovr',
#       penalty='l2', random_state=None, tol=0.0001, verbose=0),
#  'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#     out_step=0.5, random_state=42, ratio='auto', svm_estimator=None),
#  'reduce_dim': PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#    svd_solver='auto', tol=0.0, whiten=False),
#  'scaler': StandardScaler(copy=True, with_mean=True, with_std=True)}

# %%
print('Best score for training data:', svc_linear_grid_search.best_score_)
print('')

print(svc_linear_grid_search.best_params_)
print(svc_linear_grid_search.score(features_test, labels_test))

pred = svc_linear_grid_search.predict(features_test)


display_confusion_matrix(labels_test, pred)
print("Accuracy:", accuracy_score(labels_test, pred))
print("Precision:", precision_score(labels_test, pred))
print("Recall:", recall_score(labels_test, pred))
print("F1:", f1_score(labels_test, pred))

print(classification_report(labels_test, pred))
# Out:
# Best score for training data: 0.456392080642
#
# {'clf__C': 1, 'clf__loss': 'hinge', 'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=42, ratio='auto', svm_estimator=None), 'reduce_dim': PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False), 'scaler': StandardScaler(copy=True, with_mean=True, with_std=True)}
# 0.384615384615
#          Predicted
#                  0   1
# Actual 0        21  15
#        1         1   5
# Accuracy: 0.619047619048
# Precision: 0.25
# Recall: 0.833333333333
# F1: 0.384615384615
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.58      0.72        36
#         1.0       0.25      0.83      0.38         6
#
# avg / total       0.85      0.62      0.68        42

# %% [markdown]
# #### Tuning SVC with rbf kernel

# %%
# Setting up pipeline
svc_rbf_pipeline = Pipeline(steps=[
    ('oversample', SMOTE(random_state=42)),
    ('scaler', StandardScaler()),
    ('reduce_dim', PCA()), 
    ('clf', SVC(kernel='rbf'))
])

# %%
# Setting up parameter grid (also experimented with other combinations)
svc_rbf_param_grid = [
    {'oversample': [None, SMOTE(random_state=42)],    
     'scaler': [None, StandardScaler(), MinMaxScaler()],
     'reduce_dim': [None, PCA(5), PCA(10)],
     'clf__C': [1,2,3,4,5,10,100,1000],
     'clf__gamma': [0.1,0.5,1,10,100,1000]
    }
]

# %%
import warnings
warnings.filterwarnings('ignore')

# Setting up grid search
svc_rbf_grid_search = GridSearchCV(estimator=svc_rbf_pipeline, param_grid=svc_rbf_param_grid, n_jobs=-1, scoring='f1')

svc_rbf_grid_search.fit(features_train, labels_train)

warnings.filterwarnings('default')

# %%
svc_rbf_grid_search.best_estimator_.named_steps
# Out:
# {'clf': SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#    max_iter=-1, probability=False, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#     out_step=0.5, random_state=42, ratio='auto', svm_estimator=None),
#  'reduce_dim': PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#    svd_solver='auto', tol=0.0, whiten=False),
#  'scaler': MinMaxScaler(copy=True, feature_range=(0, 1))}

# %%
print('Best score for training data:', svc_rbf_grid_search.best_score_)
print('')

print(svc_rbf_grid_search.best_params_)
print(svc_rbf_grid_search.score(features_test, labels_test))

pred = svc_rbf_grid_search.predict(features_test)


display_confusion_matrix(labels_test, pred)
print("Accuracy:", accuracy_score(labels_test, pred))
print("Precision:", precision_score(labels_test, pred))
print("Recall:", recall_score(labels_test, pred))
print("F1:", f1_score(labels_test, pred))

print(classification_report(labels_test, pred))
# Out:
# Best score for training data: 0.419600807356
#
# {'clf__C': 3, 'clf__gamma': 0.1, 'oversample': SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=42, ratio='auto', svm_estimator=None), 'reduce_dim': PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False), 'scaler': MinMaxScaler(copy=True, feature_range=(0, 1))}
# 0.347826086957
#          Predicted
#                  0   1
# Actual 0        23  13
#        1         2   4
# Accuracy: 0.642857142857
# Precision: 0.235294117647
# Recall: 0.666666666667
# F1: 0.347826086957
#              precision    recall  f1-score   support
#
#         0.0       0.92      0.64      0.75        36
#         1.0       0.24      0.67      0.35         6
#
# avg / total       0.82      0.64      0.70        42

# %% [markdown]
# After parameter tuning the random forest classifier performs the best, and I will use this algorithm in my final model.

# %% [markdown]
# ### Task 6: Prepare files for project submission
# - Dump your classifier, dataset, and features_list so anyone can check your results.
# - You do not need to change anything below, but make sure that the version of poi_id.py that you submit can be run on its own and generates the necessary .pkl files for validating your results.

# %% [markdown]
# #### prep for poi_id.py

# %%
# dump_classifier_and_data(clf, my_dataset, features_list)
