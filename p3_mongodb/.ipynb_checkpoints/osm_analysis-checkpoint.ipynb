# %% [markdown]
# ### Data Wrangling with MongoDB: OpenStreetMap Project
# *by Gisle JT Gaasemyr*

# %% [markdown]
# The primary goal of this analysis is to determine the quality of OpenStreetMap address data in the Bergen, Norway region. The main focus will be on postcode accuracy and duplicate discovery. It is not within the scope of this project to correct any errors, but rather to point out discovered errors and areas which should be investigated further.

# %% [markdown]
# Before performing the analysis below, I cleaned the downloaded data file in preparation for mongodb import. I corrected incorrect postcodes and streetnames, using official government resources for quality control. For complete information about this process, see the notebook osm_data_wrangling.ipynb (html version: osm_data_wrangling.html).

# %%
#importing classes from display and pretty print modules
from pprint import pprint
from IPython.display import HTML
from IPython.display import display
#importing other necessary modules and packages
import pandas as pd
from collections import defaultdict
from pymongo import MongoClient
from operator import itemgetter
import difflib
from fuzzywuzzy import fuzz
from matplotlib import pyplot as plt
import seaborn as sns

#For convenience imports are also included in individual cells where relevant

# %%
#Setting up MongoDB connection
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = client.osm
#Creating db.bergen as a variable for the sake of brevity
bergen = db.bergen

# %%
#Getting an initial overview of the data
display(HTML('<b>Count of documents in database:</b>'),bergen.count())
display(HTML('<b>First record:</b>'))
pprint(bergen.find_one())
display(HTML('<b>Document Types:</b>'))

pipeline = [ 
    { '$group': {'_id': '$type', 'count': { '$sum': 1 } } },
    {'$sort': {'count': -1 } }
]

for res in bergen.aggregate(pipeline):
    print(res['_id'],res['count'])
# Out:
# <b>Count of documents in database:</b>
# 681172
# <b>First record:</b>
# {'_id': ObjectId('591a5d8b49fce35f8f67ccb2'),
#  'created': {'changeset': '6007582',
#              'timestamp': '2010-10-10T22:30:34Z',
#              'uid': '114230',
#              'user': 'danerikk',
#              'version': '2'},
#  'id': '358065',
#  'pos': [60.5320227, 5.2557628],
#  'type': 'node'}
# <b>Document Types:</b>
# node 628779
# way 52393

# %%
#Ensuring no other type records, due to previous import error
bergen.find_one( {'type': {'$nin': ['way','node']} })

# %%
#Creating indexes

from pymongo import ASCENDING

bergen.create_index([('address', ASCENDING),('address.street', ASCENDING),('address.housenumber', ASCENDING)])
# Out:
# 'address_1_address.street_1_address.housenumber_1'

# %%
#Getting count of documents with address field

address_query = { 'address' : {'$exists' : True }}
address_documents = bergen.find(address_query)
address_count = address_documents.count()

display(HTML('<b>Number of addresses in dataset:</b>'),address_count)
# Out:
# <b>Number of addresses in dataset:</b>
# 84625

# %%
#Getting counts for streetnames and addresses

aggregated = bergen.aggregate([  
        {'$match' : {'address': {'$exists' : True } } },
        { "$group" : { 
                "_id" : "$address.street","count" : { "$sum" : 1} } }
    ])

household_count = 0
unique_street_count = 0
addresses_on_street = {}

for doc in aggregated:
    household_count += doc['count']
    unique_street_count += 1
    
    addresses_on_street[doc['_id']] = doc['count']

print("total addresses in Bergen:", household_count)
print("number of streetnames:", unique_street_count)
# Out:
# total addresses in Bergen: 84625
# number of streetnames: 2231

# %% [markdown]
# According to January 2016 data from Statistics Norway (SSB), there are 134,328 households in Bergen. The data used by Statistics Norway is collected from the National Registry, and the data includes unit numbers for a minimum 95% of the addresses where such a number exists. The available OSM data does not contain unit numbers. Several addresses in Bergen contain multiple home units, and although the OSM data also contains non-household addresses (businesses, public institutions etc.) the number of addresses in the OSM data seems reasonable.

# %% [markdown]
# Next I will take a look at the streets with the most addresses on them, to see if any of the top 10 streets are surprising, and if any of the streets have a surprisingly high number of addresses.

# %%
#Taking a look at the streets with the most addresses

from operator import itemgetter

streetnames_sorted_dict = dict(sorted(addresses_on_street.items(), key=lambda x: x[1], reverse=True)[:10])
streetnames_sorted_list = sorted(addresses_on_street.items(), key=lambda x: x[1], reverse=True)


display(HTML("<b>Streets with most addresses on them:</b>"))

for street,count in streetnames_sorted_list[0:10]:
    print(street,count)
# Out:
# <b>Streets with most addresses on them:</b>
# Myrdalskogen 442
# Askvegen 397
# Søråshøgda 377
# Kringlebotn 304
# Flaktveitvegen 293
# Stongafjellsvegen 289
# Hjellestadvegen 277
# Hetlevikåsen 276
# Langarinden 273
# Nipedalen 250

# %% [markdown]
# Based on my local knowledge of the area, the list above is not very surprising. None of the streets have a higher number of addresses than I expected.

# %%
#Ensuring corrected street names in cleaning script are in fact corrected in the database
for street,count in streetnames_sorted_list:
    
    if street is None:
        pass
    
    elif ('Thormøhlens' or 'Smøråshøgda 9' or 'Laguneveien 1' or 'Gate' or '.' or 'Tokanten') in street:
        #expecting 1 result
        print(street,count)
# Out:
# Thormøhlens gate 47

# %%
#Ensuring all postcodes starting with 'NO-' are corrected. Expecting 0 results from query.
for doc in bergen.find( {'address.postcode': {'$regex': 'NO.*'} } ):
    pprint(doc['address'])
    print('----------')

# %% [markdown]
# ### Misspelled street names

# %%
#Checking for potential duplicate data due to misspelled street names

import difflib
from fuzzywuzzy import fuzz

def fuzzy_streets(ratio,house_count):
    
    fuzzy_matches = list()
    compare_count = 0
    
    for k1 in streetnames_sorted_list:

        if k1[0] is None:
            print("Addresses without street name:",k1[1])

        #Only comparing street names with less addresses than house_count
        elif k1[1] <= house_count:
            
            compare_count += 1

            for k2 in streetnames_sorted_list:

                if k2[0] is None:
                    pass

                elif k2[0] == k1[0]:
                    pass

                else:                    
                    
                    fuzz_ratio = fuzz.ratio(k1[0],k2[0])
                    
                    if fuzz_ratio >= ratio:
                        fuzzy_matches.append({k1: k2,"fuzz ratio": fuzz_ratio})

    print("Number of street names compared: {0} of {1}".format(compare_count,len(streetnames_sorted_list)))
    
    return fuzzy_matches

# %%
#Lower than 90 fuzzy ratio gives too many false positives. Same goes for higher than 10 addresses on the street.
potential_misspellings = fuzzy_streets(92,10)
# Out:
# Addresses without street name: 184
# Number of street names compared: 526 of 2231

# %%
potential_misspellings
# Out:
# [{('Dreggsallmenningen', 10): ('Dreggsallmenning', 1), 'fuzz ratio': 94},
#  {('Herman Foss’ gate', 9): ("Herman Foss' gate", 1), 'fuzz ratio': 94},
#  {'fuzz ratio': 95,
#   ('Vilhelm Bjerknesvei', 9): ('Vilhelm Bjerknes’ vei', 111)},
#  {'fuzz ratio': 92, ('Flyplassveien', 7): ('Flyplassvegen', 27)},
#  {('Solhaugveien', 7): ('Solhaugvegen', 22), 'fuzz ratio': 92},
#  {('Haakon Sheteligs plass', 6): ('Haakon Shetelings plass', 2),
#   'fuzz ratio': 98},
#  {'fuzz ratio': 95, ('Austevågen', 5): ('Austrevågen', 21)},
#  {('Vestre Mulelvsmauet', 4): ('Østre Mulelvsmauet', 3), 'fuzz ratio': 92},
#  {('Nesttunveien', 3): ('Nesttunvegen', 59), 'fuzz ratio': 92},
#  {'fuzz ratio': 92, ('Travparkvegen', 3): ('Travparkveien', 1)},
#  {('Østre Mulelvsmauet', 3): ('Vestre Mulelvsmauet', 4), 'fuzz ratio': 92},
#  {('C.Sundtsgate', 2): ('C. Sundts gate', 53), 'fuzz ratio': 92},
#  {('Torgalmenningen', 2): ('Torgallmenningen', 29), 'fuzz ratio': 97},
#  {'fuzz ratio': 98,
#   ('Haakon Shetelings plass', 2): ('Haakon Sheteligs plass', 6)},
#  {('Dreggsallmenning', 1): ('Dreggsallmenningen', 10), 'fuzz ratio': 94},
#  {'fuzz ratio': 94, ("Herman Foss' gate", 1): ('Herman Foss’ gate', 9)},
#  {('Vestre murallmenningen', 1): ('Vestre Murallmenningen', 27),
#   'fuzz ratio': 95},
#  {('Smøråshøgda', 1): ('Søråshøgda', 377), 'fuzz ratio': 95},
#  {('Lars Hillesgate', 1): ('Lars Hilles gate', 26), 'fuzz ratio': 97},
#  {('Siljustølveien', 1): ('Siljustølvegen', 14), 'fuzz ratio': 93},
#  {('Halvardsvegen', 1): ('Hallvardsvegen', 14), 'fuzz ratio': 96},
#  {'fuzz ratio': 92, ('Totlandsveien', 1): ('Totlandsvegen', 211)},
#  {('Espelandsveien', 1): ('Espelandsvegen', 76), 'fuzz ratio': 93},
#  {('Travparkveien', 1): ('Travparkvegen', 3), 'fuzz ratio': 92},
#  {('Børnesskogen', 1): ('Bønesskogen', 222), 'fuzz ratio': 96}]

# %%
#Printing out the potential misspellings
import pandas as pd

df_potential_misspellings = pd.DataFrame(columns = [
        'high_spelling','high_count','low_spelling','low_count','fuzz_ratio'])

#Adding index to make it easier to sort out the items I need to investigate further
count = 0

for spellings in potential_misspellings:
    count += 1
    df_potential_misspellings.loc[count] = None
    for key, val in spellings.items():
        if type(key) == tuple:
            if key[1] > val[1]:
                df_potential_misspellings.loc[count]['high_spelling'] = key[0]
                df_potential_misspellings.loc[count]['low_spelling'] = val[0]
                df_potential_misspellings.loc[count]['high_count'] = key[1]
                df_potential_misspellings.loc[count]['low_count'] = val[1]

            else:
                df_potential_misspellings.loc[count]['high_spelling'] = val[0]
                df_potential_misspellings.loc[count]['low_spelling'] = key[0]
                df_potential_misspellings.loc[count]['high_count'] = val[1]
                df_potential_misspellings.loc[count]['low_count'] = key[1]
        else:
            df_potential_misspellings.loc[count]['fuzz_ratio'] = val

df_potential_misspellings.drop_duplicates().sort_values('high_spelling',ascending=True)
# Out:
#              high_spelling high_count             low_spelling low_count  \
# 7              Austrevågen         21               Austevågen         5
# 25             Bønesskogen        222             Børnesskogen         1
# 12          C. Sundts gate         53             C.Sundtsgate         2
# 1       Dreggsallmenningen         10         Dreggsallmenning         1
# 23          Espelandsvegen         76           Espelandsveien         1
# 4            Flyplassvegen         27            Flyplassveien         7
# 6   Haakon Sheteligs plass          6  Haakon Shetelings plass         2
# 21          Hallvardsvegen         14            Halvardsvegen         1
# 2        Herman Foss’ gate          9        Herman Foss' gate         1
# 19        Lars Hilles gate         26          Lars Hillesgate         1
# 9             Nesttunvegen         59             Nesttunveien         3
# 20          Siljustølvegen         14           Siljustølveien         1
# 5             Solhaugvegen         22             Solhaugveien         7
# 18              Søråshøgda        377              Smøråshøgda         1
# 13        Torgallmenningen         29          Torgalmenningen         2
# 22           Totlandsvegen        211            Totlandsveien         1
# 10           Travparkvegen          3            Travparkveien         1
# 8      Vestre Mulelvsmauet          4       Østre Mulelvsmauet         3
# 17  Vestre Murallmenningen         27   Vestre murallmenningen         1
# 3    Vilhelm Bjerknes’ vei        111      Vilhelm Bjerknesvei         9
#
#    fuzz_ratio
# 7          95
# 25         96
# 12         92
# 1          94
# 23         93
# 4          92
# 6          98
# 21         96
# 2          94
# 19         97
# 9          92
# 20         93
# 5          92
# 18         95
# 13         97
# 22         92
# 10         92
# 8          92
# 17         95
# 3          95

# %%
df_misspelled_streets = df_potential_misspellings.loc[[18,13,1,19,6,17,2,22,9,15,12,23,10,16,3]]
df_misspelled_streets.rename(columns={ 
    'high_spelling': 'correct_name', 'low_spelling': 'wrong_name' }, inplace=True )
df_correct_spellings = df_potential_misspellings.loc[8]
df_spellings_require_research = df_potential_misspellings.loc[[4,7,5,20]]

df_misspelled_streets[['correct_name','wrong_name']].to_csv(
    'data/misspelled_streets.csv',index=False)
df_spellings_require_research.to_csv('data/research_streets_spelling.csv',index=False)

# %%
df_misspelled_streets
# Out:
#               correct_name high_count               wrong_name low_count  \
# 18              Søråshøgda        377              Smøråshøgda         1
# 13        Torgallmenningen         29          Torgalmenningen         2
# 1       Dreggsallmenningen         10         Dreggsallmenning         1
# 19        Lars Hilles gate         26          Lars Hillesgate         1
# 6   Haakon Sheteligs plass          6  Haakon Shetelings plass         2
# 17  Vestre Murallmenningen         27   Vestre murallmenningen         1
# 2        Herman Foss’ gate          9        Herman Foss' gate         1
# 22           Totlandsvegen        211            Totlandsveien         1
# 9             Nesttunvegen         59             Nesttunveien         3
# 15      Dreggsallmenningen         10         Dreggsallmenning         1
# 12          C. Sundts gate         53             C.Sundtsgate         2
# 23          Espelandsvegen         76           Espelandsveien         1
# 10           Travparkvegen          3            Travparkveien         1
# 16       Herman Foss’ gate          9        Herman Foss' gate         1
# 3    Vilhelm Bjerknes’ vei        111      Vilhelm Bjerknesvei         9
#
#    fuzz_ratio
# 18         95
# 13         97
# 1          94
# 19         97
# 6          98
# 17         95
# 2          94
# 22         92
# 9          92
# 15         94
# 12         92
# 23         93
# 10         92
# 16         94
# 3          95

# %%
#Getting counts from db again 
for inx,name in df_misspelled_streets.iterrows():
    print(name[2],bergen.find( { 'address.street': name[2]}).count() )
# Out:
# Smøråshøgda 1
# Torgalmenningen 2
# Dreggsallmenning 1
# Lars Hillesgate 1
# Haakon Shetelings plass 2
# Vestre murallmenningen 1
# Herman Foss' gate 1
# Totlandsveien 1
# Nesttunveien 3
# Dreggsallmenning 1
# C.Sundtsgate 2
# Espelandsveien 1
# Travparkveien 1
# Herman Foss' gate 1
# Vilhelm Bjerknesvei 9

# %%
#Updating records
for inx,name in df_misspelled_streets.iterrows():
    bergen.update_many( { 'address.street': name[2]},
                  { '$set': {'address.street': name[0] } 
                  } )

# %%
#Ensuring all is corrected. All should return count 0
for inx,name in df_misspelled_streets.iterrows():
    print(name[2],bergen.find( { 'address.street': name[2]}).count() )
# Out:
# Smøråshøgda 0
# Torgalmenningen 0
# Dreggsallmenning 0
# Lars Hillesgate 0
# Haakon Shetelings plass 0
# Vestre murallmenningen 0
# Herman Foss' gate 0
# Totlandsveien 0
# Nesttunveien 0
# Dreggsallmenning 0
# C.Sundtsgate 0
# Espelandsveien 0
# Travparkveien 0
# Herman Foss' gate 0
# Vilhelm Bjerknesvei 0

# %% [markdown]
# Above I have performed some QA on the street names from the Bergen OSM dataset. I have taken a closer look at the street names with less than 10 house numbers, and I have compared those street with the other street names to spot potential misspelled and duplicate street names. Based on lingual and local knowledge, I have sorted the potential misspelled streetnames into three categories: actual misspelled names, correctly spelled names and names which require more research. All 3 categories are imported to csv files, and I have corrected the actual misspelled names in the database.

# %% [markdown]
# ### Duplicate addresses

# %%
#Finding duplicate addresses

pipeline = [
    { '$group': { 
            '_id': { 'street': '$address.street', 'housenumber': '$address.housenumber' }, 
                'postcodes': { '$addToSet': '$address.postcode' }, 
            'count': {'$sum': 1 }
            }
        },
    { '$match': {'count': {'$gt': 1} } },
    {'$sort' : {'count' : -1} } ]


duplicate_addresses = []
duplicate_addresses_count = 0

for doc in bergen.aggregate(pipeline):
    duplicate_addresses.append(doc)
    if doc['_id'] != {}:
        duplicate_addresses_count += doc['count']

print("Number of potential duplicate addresses:", len(duplicate_addresses))
print("Documents with potential duplicate addresses:", duplicate_addresses_count)
# Out:
# Number of potential duplicate addresses: 916
# Documents with potential duplicate addresses: 2111

# %%
#Converting result of duplicate address query to Pandas dataframe for easier view

from pandas.io.json import json_normalize

df_duplicate_addresses = json_normalize(duplicate_addresses)

#Changing column names
df_duplicate_addresses.rename(columns={'_id.housenumber': 'housenumber','_id.street':'street'},inplace=True)
#Changing column order
df_duplicate_addresses = df_duplicate_addresses[['street', 'housenumber', 'count', 'postcodes']]

df_duplicate_addresses.head(7)
# Out:
#              street housenumber   count                       postcodes
# 0               NaN         NaN  596731  [5021, 5835, 5281, 5116, 5918]
# 1        Kanalveien          66      13                          [5068]
# 2         Lyngmarka         NaN      12                          [5302]
# 3  Valkendorfsgaten           6      12                          [5012]
# 4       Kalfarveien          37      11                          [5022]
# 5        Kanalveien          64      10                          [5068]
# 6     Sandslihaugen          10      10                          [5254]

# %%
#Getting some information about duplicate addresses with different postcodes

df_different_postcodes = df_duplicate_addresses[df_duplicate_addresses['postcodes'].apply(lambda x: len(x) > 1)]

# Adding column for count of postcodes for the address
df_different_postcodes = df_different_postcodes.assign(postcode_count=df_different_postcodes['postcodes'].str.len())

print('Number of duplicate addresses with different postcodes:',len(df_different_postcodes) )
print('Duplicate addresses where all the duplicates have unique postcodes:',len(
    df_different_postcodes[df_different_postcodes['count'] == df_different_postcodes['postcode_count']]))

df_different_postcodes.sort_values('postcode_count', ascending=False).head(7)
# Out:
# Number of duplicate addresses with different postcodes: 252
# Duplicate addresses where all the duplicates have unique postcodes: 242
#          street housenumber   count                       postcodes  \
# 0           NaN         NaN  596731  [5021, 5835, 5281, 5116, 5918]
# 139    Liavegen          17       3              [5307, 5132, 5378]
# 40     Liavegen          10       4              [5307, 5132, 5378]
# 86      Haugane           4       3              [5307, 5212, 5360]
# 138    Liavegen          12       3              [5307, 5132, 5378]
# 675  Lynghaugen           4       2                    [5038, 5350]
# 671    Liavegen           4       2                    [5307, 5378]
#
#      postcode_count
# 0                 5
# 139               3
# 40                3
# 86                3
# 138               3
# 675               2
# 671               2

# %% [markdown]
# 242 of the 914 potential duplicate addresses are likely not true duplicates, as they have unique postcodes for the address.

# %%
#Function for printing individual address search results

def search_one_address(street, housenumber):
        
    query = { 'address.street': street, 'address.housenumber': {'$in': [str(housenumber),housenumber ] } }
        
    for doc in bergen.find(query):
        pprint(doc)

# %%
#Looking at all documents with the top duplicate address
search_one_address('Kanalveien','66')
# Out:
# {'_id': ObjectId('591a5dad49fce35f8f70eec2'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:13Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196717',
#  'level': '2',
#  'name': 'Bergen Bibelskole',
#  'office': 'yes',
#  'pos': [60.3621861, 5.3469652],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eec4'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:13Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196718',
#  'level': '1',
#  'name': 'Bergen Innredning og Montasje',
#  'office': 'yes',
#  'pos': [60.3620529, 5.3469736],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eec5'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:13Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196720',
#  'level': '3',
#  'name': 'Block Watne',
#  'office': 'yes',
#  'pos': [60.3622241, 5.3469629],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eec6'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:13Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196721',
#  'level': '1',
#  'name': 'Boarding Cognito',
#  'office': 'yes',
#  'pos': [60.362129, 5.3469688],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eec8'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:14Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196723',
#  'level': '3',
#  'name': 'CCT | Schjærven',
#  'office': 'yes',
#  'pos': [60.3622432, 5.3469617],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eeca'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:14Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196725',
#  'level': '1',
#  'name': 'Communication Norge',
#  'office': 'yes',
#  'pos': [60.36211, 5.34697],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eece'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:14Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196729',
#  'level': '1',
#  'name': 'Ellingsen & Alpen',
#  'office': 'yes',
#  'pos': [60.3620909, 5.3469712],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eed0'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:15Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196732',
#  'level': '1',
#  'name': 'Glamox',
#  'office': 'yes',
#  'pos': [60.362148, 5.3469676],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eed3'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:15Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196734',
#  'level': '1',
#  'name': 'Hult IT',
#  'office': 'yes',
#  'pos': [60.3620719, 5.3469724],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eed4'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:15Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196735',
#  'level': '2',
#  'name': 'K66 Kurslokaler',
#  'office': 'yes',
#  'pos': [60.3622051, 5.3469641],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eed7'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:15Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196737',
#  'level': '2',
#  'name': 'Kristent Fellesskap',
#  'office': 'yes',
#  'pos': [60.362167, 5.3469664],
#  'type': 'node'}
# {'_id': ObjectId('591a5dad49fce35f8f70eedc'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:16Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4264196743',
#  'level': '0',
#  'name': 'Studio Sigdal',
#  'operator': 'Sigdal Kjøkken',
#  'pos': [60.3622622, 5.3469605],
#  'shop': 'kitchen',
#  'type': 'node'}
# {'_id': ObjectId('591a5db649fce35f8f7223ef'),
#  'address': {'city': 'Bergen',
#              'housenumber': '66',
#              'postcode': '5068',
#              'street': 'Kanalveien'},
#  'building': 'yes',
#  'created': {'changeset': '40278280',
#              'timestamp': '2016-06-25T09:11:22Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '427177702',
#  'node_refs': ['4264197042',
#                '4264197043',
#                '4264197020',
#                '4264197027',
#                '4264197029',
#                '4264197030',
#                '4264197033',
#                '4264197040',
#                '4264197044',
#                '4264197045',
#                '4264197042'],
#  'type': 'way'}

# %%
#Looking at one of the nodes

bergen.find_one({'id': '4264197029'})
# Out:
# {'_id': ObjectId('591a5dad49fce35f8f70ef97'),
#  'created': {'changeset': '40278280',
#   'timestamp': '2016-06-25T09:11:20Z',
#   'uid': '1965308',
#   'user': 'FredrikLindseth',
#   'version': '1'},
#  'id': '4264197029',
#  'pos': [60.3620325, 5.3469011],
#  'type': 'node'}

# %% [markdown]
# <img src="data/kanalveien_66_duplicates.png" align="right" width="250">
#
# Looking up the address with the most duplicates (13), Kanalveien 66, on the OpenStreetMap.org website, it becomes apparent that at least part of the reason for the many duplicates is that there are multiple business located at that address, and each business seems to have gotten its own address.
#
# According to the [OSM wiki](http://wiki.openstreetmap.org/wiki/Addresses#How_to_map_addresses), the policy on duplicate addresses is unclear in such cases: "However, there is still some debate on that point (see for example Address information in POI *and* building? on help.openstreetmap.org). Also, the community in some countries has established their own rules."

# %%
#Function for checking individual addresses for duplicates

def duplicate_count(street,housenumber, return_list=False):
    display((HTML('<em>{0} {1}</em>'.format(street,housenumber) ) ) )
    query = { 'address.street': street, 'address.housenumber': {'$in': [str(housenumber),housenumber ] } }
    
    count = -1
    re_list = list()
    postcodes = defaultdict(int)
    
    for doc in bergen.find(query):
        count += 1
        postcodes[doc['address']['postcode']] += 1
        if return_list:
            re_list.append(doc)
    
    if count == -1:
        print("Address not found.")
    else:
        print("Duplicate records:", count)
        print("Postcodes:",dict(postcodes))
        if return_list:
            return re_list

# %%
bergen.find_one( {'address.street': 'Smøråshøgda'})

# %%
bergen.find_one( {'id': '334326937'})
# Out:
# {'_id': ObjectId('591a5db049fce35f8f71ab3b'),
#  'address': {'city': 'Rådal',
#   'housenumber': 9,
#   'postcode': '5235',
#   'street': 'Søråshøgda'},
#  'building': 'retail',
#  'created': {'changeset': '29680703',
#   'timestamp': '2015-03-23T14:58:32Z',
#   'uid': '715936',
#   'user': 'Gazer75',
#   'version': '1'},
#  'id': '334326937',
#  'name': 'Kilden Senter',
#  'node_refs': ['3414385236',
#   '3414385217',
#   '3414385201',
#   '3414385189',
#   '3414385186',
#   '3414385188',
#   '3414385190',
#   '3414385192',
#   '3414385209',
#   '3414385212',
#   '3414385214',
#   '3414385220',
#   '3414385223',
#   '3414385236'],
#  'shop': 'mall',
#  'type': 'way',
#  'website': 'http://kilden-senter.no/',
#  'wheelchair': 'yes'}

# %%
'''
Checking for duplicates among the cleaned addresses which had housenumber \
as part of the address name in the pre-cleaned file. 
'''
duplicate_count('Laguneveien',1)
duplicate_count('Smøråshøgda',9)
duplicate_count('Steinsvikvegen',430)

#For Vilhelm Bjerknesvei checking both individual addresses and range housenumber
duplicate_count('Vilhelm Bjerknesvei','4-10')
for i in range(4,11):
    duplicate_count('Vilhelm Bjerknesvei',i)
# Out:
# <em>Laguneveien 1</em>
# Duplicate records: 4
# Postcodes: {'5235': 1, '5239': 4}
# <em>Smøråshøgda 9</em>
# Address not found.
# <em>Steinsvikvegen 430</em>
# Duplicate records: 0
# Postcodes: {'5239': 1}
# <em>Vilhelm Bjerknesvei 4-10</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 4</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 5</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 6</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 7</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 8</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 9</em>
# Address not found.
# <em>Vilhelm Bjerknesvei 10</em>
# Address not found.

# %% [markdown]
# It is not very surprising that Vilhelm Bjerknesvei 4, 6, 7 8, 9 and 10 are missing, as they are probably among the documents which were imported with address Vilhelm Bjerknesvei 4-10. It is however surprising that there are no documents with address Vilhelm Bjerknesvei 4-10 and Smøråshøgda 9. Looking at the identified misspelled street names, I see why this is: they are both among the corrected street names. I will therefore run the queries again with the corrected spellings.

# %%
duplicate_count('Søråshøgda',9)
#For Vilhelm Bjerknes’ vei checking both individual addresses and range housenumber
duplicate_count("Vilhelm Bjerknes’ vei",'4-10')
for i in range(4,11):
    duplicate_count("Vilhelm Bjerknes’ vei",i)
# Out:
# <em>Søråshøgda 9</em>
# Duplicate records: 1
# Postcodes: {'5235': 2}
# <em>Vilhelm Bjerknes’ vei 4-10</em>
# Duplicate records: 6
# Postcodes: {'5081': 7}
# <em>Vilhelm Bjerknes’ vei 4</em>
# Duplicate records: 0
# Postcodes: {'5081': 1}
# <em>Vilhelm Bjerknes’ vei 5</em>
# Address not found.
# <em>Vilhelm Bjerknes’ vei 6</em>
# Address not found.
# <em>Vilhelm Bjerknes’ vei 7</em>
# Address not found.
# <em>Vilhelm Bjerknes’ vei 8</em>
# Address not found.
# <em>Vilhelm Bjerknes’ vei 9</em>
# Address not found.
# <em>Vilhelm Bjerknes’ vei 10</em>
# Duplicate records: 0
# Postcodes: {'5081': 1}

# %% [markdown]
# There are seven documents with address Vilhelm Bjerknes’ vei 4-10, and 2 documents for the individual addresses in the 4-10 range (e.g. Vilhelm Bernesvei 7). While this is a data error, only 2 of the 7 documents with address Vilhelm Bjerknesvei 4-10 are likely to be true duplicates.

# %% [markdown]
# I will take a closer look at the duplicate Laguneveien 1 documents.

# %%
#Searching for duplicates of Laguneveien 1

search_one_address('Laguneveien',1)
# Out:
# {'_id': ObjectId('591a5d9149fce35f8f697dc2'),
#  'address': {'city': 'Rådal',
#              'housenumber': 1,
#              'postcode': '5235',
#              'street': 'Laguneveien'},
#  'amenity': 'restaurant',
#  'created': {'changeset': '39294271',
#              'timestamp': '2016-05-13T14:59:10Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '6'},
#  'id': '1652908136',
#  'name': 'Egon Lagunen',
#  'outdoor_seating': 'yes',
#  'pos': [60.2962144, 5.3301382],
#  'type': 'node',
#  'website': 'http://www.egon.no/',
#  'wheelchair': 'yes'}
# {'_id': ObjectId('591a5d9449fce35f8f6a41fa'),
#  'address': {'city': 'Rådal',
#              'housenumber': '1',
#              'postcode': '5239',
#              'street': 'Laguneveien'},
#  'created': {'changeset': '26026343',
#              'timestamp': '2014-10-12T14:10:49Z',
#              'uid': '103253',
#              'user': 'gormur',
#              'version': '1'},
#  'id': '3125931672',
#  'pos': [60.2968652, 5.3311546],
#  'type': 'node'}
# {'_id': ObjectId('591a5da749fce35f8f6efe30'),
#  'address': {'city': 'Rådal',
#              'floor': '1',
#              'housenumber': '1',
#              'postcode': '5239',
#              'street': 'Laguneveien'},
#  'contact': {'facebook': 'https://www.facebook.com/arnasomogstrikkas'},
#  'craft': 'tailor',
#  'created': {'changeset': '36459796',
#              'timestamp': '2016-01-09T09:12:57Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '3935489347',
#  'name': 'Arna Søm og Strikk',
#  'phone': '55 12 42 45',
#  'pos': [60.2968112, 5.3317375],
#  'shop': 'sewing',
#  'type': 'node',
#  'website': 'http://arnasomogstrikk.no/'}
# {'_id': ObjectId('591a5dac49fce35f8f70b77d'),
#  'address': {'city': 'Rådal',
#              'housenumber': '1',
#              'postcode': '5239',
#              'street': 'Laguneveien'},
#  'amenity': 'restaurant',
#  'created': {'changeset': '39294271',
#              'timestamp': '2016-05-13T14:58:29Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '1'},
#  'id': '4183728796',
#  'name': 'Good',
#  'pos': [60.2961383, 5.3304506],
#  'type': 'node'}
# {'_id': ObjectId('591a5daf49fce35f8f71789c'),
#  'address': {'city': 'Rådal',
#              'housenumber': 1,
#              'postcode': '5239',
#              'street': 'Laguneveien'},
#  'building': 'yes',
#  'created': {'changeset': '29734356',
#              'timestamp': '2015-03-25T18:31:16Z',
#              'uid': '170061',
#              'user': 'frokor',
#              'version': '10'},
#  'id': '27124386',
#  'name': 'Lagunen Storsenter',
#  'node_refs': ['297595267',
#                '3400479104',
#                '297595268',
#                '297595290',
#                '297595289',
#                '297595288',
#                '297595287',
#                '297595269',
#                '3400478963',
#                '3400478964',
#                '3400478962',
#                '297595285',
#                '3398583851',
#                '3398583850',
#                '297595286',
#                '3417936946',
#                '3417936950',
#                '3417936961',
#                '3417936974',
#                '3417936977',
#                '3417936979',
#                '297595349',
#                '3417936986',
#                '3417936987',
#                '2319279407',
#                '2319279409',
#                '297595267'],
#  'shop': 'mall',
#  'type': 'way',
#  'website': 'http://www.thonshopping.no/lagunen',
#  'wheelchair': 'yes'}

# %%
pipeline = [
    { '$match': { 'address.street': 'Laguneveien' } },
    { '$group': { 
            '_id': '$address.postcode', 'count' : {'$sum': 1 } 
        } 
    },
    {'$sort' : {'count' : -1} }
    
]

for doc in bergen.aggregate(pipeline):
    pprint(doc)
# Out:
# {'_id': '5239', 'count': 19}
# {'_id': '5235', 'count': 1}

# %%
query = { 'address.street': 'Laguneveien', 'address.postcode': '5235', 'address.housenumber': 1 }

for doc in bergen.find(query):
    pprint(doc)
# Out:
# {'_id': ObjectId('591a5d9149fce35f8f697dc2'),
#  'address': {'city': 'Rådal',
#              'housenumber': 1,
#              'postcode': '5235',
#              'street': 'Laguneveien'},
#  'amenity': 'restaurant',
#  'created': {'changeset': '39294271',
#              'timestamp': '2016-05-13T14:59:10Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '6'},
#  'id': '1652908136',
#  'name': 'Egon Lagunen',
#  'outdoor_seating': 'yes',
#  'pos': [60.2962144, 5.3301382],
#  'type': 'node',
#  'website': 'http://www.egon.no/',
#  'wheelchair': 'yes'}

# %% [markdown]
# According to The Norwegian Mapping Authority, the correct postal code for Laguneveien is 5239. The postcode for the 5235 document is incorrect.

# %% [markdown]
# ### Contributors

# %%
from collections import defaultdict

user_count_query = bergen.aggregate( [
   {
     '$group': {
        '_id' : { 'uid': '$created.uid', 'username': '$created.user' }
           }
        },
   {
     '$group': {
        '_id': 'null',
        'count': { '$sum': 1 }
     }
   }
] )

for doc in user_count_query:
    user_count = doc['count']

average_contributions = bergen.aggregate( [
   {
          '$group': 
            {
                '_id' : 
                { 'uid': '$created.uid', 'username': '$created.user' },
                'count': { '$sum': 1 } 
            } 
    },
    { 
            '$group': 
            {
                '_id': 'null',
                'avg': { '$avg': '$count' } 
            }
    }
] )

for doc in average_contributions:
    user_average = round(doc['avg'],2)
    
grouped_users = list(bergen.aggregate([  
        { 
            "$group" : 
            { 
                "_id" : { "uid": "$created.uid", "username": "$created.user" },
                "count" : { "$sum" : 1} 
            } 
        },
        { "$sort" : { "count" : 1 } }
        ]))

user_no = 0
halfway = round(user_count / 2)
mode_dict = defaultdict(int)

for doc in grouped_users:
        user_no += 1
        val = doc['count']
        if user_no == halfway:
            user_median = val
        
        mode_dict[val] += 1


        
user_mode = max(mode_dict.items(), key=lambda a: a[1])
mode_percentage = round((user_mode[1] / user_count) * 100,2)
            
print("Total user count:",user_count)
print("Average contributions per user:",user_average)
print("Median contributions per user:",user_median)
print("Mode of contribution count: {0} contributors ({1}%) submitted {2} edit.".format(
    user_mode[1],mode_percentage,user_mode[0] ) )
# Out:
# Total user count: 399
# Average contributions per user: 1707.2
# Median contributions per user: 11
# Mode of contribution count: 76 contributors (19.05%) submitted 1 edit.

# %% [markdown]
# Based on the difference between the median and the average I suspect that the OSM comunity has a few heavy contributors working on the Bergen data. To further investigate this, I will plot the data.

# %%
#Creating dataframe and bins for bar chart

df_mode_dict = pd.DataFrame(pd.Series(mode_dict),columns=['count'])
df_mode_dict['contributions'] = df_mode_dict.index
df_mode_dict = df_mode_dict[['contributions','count']]

#Creating bins of various lengths
bins = list(range(0,100,10) ) + \
list(range(100,1000,100) ) + list(range(1000,10000,5000) ) + \
list(range(10000,50000,20000) ) + list(range(50000,151000,50000) )

#Generating labels for the bins
bracket_names = list()
for item in bins:
    if item != bins[-1]:
#         if item < 10:
#             bracket_names.append(str(item+1)) 
#         else:
        start = item + 1
        next = bins[bins.index(item) + 1]
        if start > 1000:
            start = str(start)[:-3] + 'K'
            next = str(next)[:-3] + 'K'
        bracket_names.append('{0} to {1}'.format(start,next))

#Assigning the bins to dataframe
categories = pd.Series(pd.cut(df_mode_dict['contributions'], bins ,
                              labels=bracket_names, include_lowest=True ) )
df_mode_dict['bracket'] = categories

display(df_mode_dict.head(3))
display(df_mode_dict.tail(3))
# Out:
#    contributions  count  bracket
# 1              1     76  1 to 10
# 2              2     30  1 to 10
# 3              3     23  1 to 10
#         contributions  count       bracket
# 80243           80243      1   50K to 100K
# 133655         133655      1  100K to 150K
# 140794         140794      1  100K to 150K

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

for_plot = df_mode_dict.groupby('bracket')['count'].agg('sum')

fig = plt.figure(figsize=(10,4))
ax = plt.subplot(1,1,1)

#all passengers plot
rects = for_plot.plot(kind='bar',ax=ax,color='g')
ax.set_title('Contributions per user',fontsize='large',fontweight='bold')
ax.set_xlabel('Number of contributions (uneven bin sizes)',fontsize='medium')
ax.set_ylabel('User count',fontsize='medium')
ax.set_xticklabels(for_plot.index.values,rotation='70',fontsize='small')

plt.show()

# %%
total_contributions = 0

for doc in grouped_users:
    try:
        total_contributions += int(doc['count'])
    except TypeError:
        pprint(doc)

# %%
# Looking at top 10 contributors

top_users = list(bergen.aggregate([  
        { "$group" : { 
                "_id" : { "uid": "$created.uid", "username": "$created.user" },"count" : { "$sum" : 1} } },
        { "$sort" : { "count" : -1 } },
         { "$limit" : 10 }
#         { "$project" : { "_id": 0, "user": "$created.user" } } 
    ]))

for doc in top_users:
    print(doc)
    
#Calculating total user contributions for comparison
total_contributions = 0
for doc in grouped_users:
    try:
        total_contributions += int(doc['count'])
    except TypeError:
        pprint('TYPE ERROR:',doc['count'])
print('----')
print('Total contributors:',total_contributions)

total_top_10 = 0
for doc in top_users:
    total_top_10 += doc['count']

top_10_percentage = round((total_top_10/total_contributions)*100,2)

print('Total contributions by top 10 contributors: {0}, {1}%'.format(total_top_10,top_10_percentage))
# Out:
# {'_id': {'username': 'FredrikLindseth_import', 'uid': '2114448'}, 'count': 140794}
# {'_id': {'username': 'frokor_import', 'uid': '2836853'}, 'count': 133655}
# {'_id': {'username': 'gormur', 'uid': '103253'}, 'count': 80243}
# {'_id': {'username': 'Christian Madsen', 'uid': '992708'}, 'count': 39789}
# {'_id': {'username': 'daviesp12', 'uid': '722193'}, 'count': 36440}
# {'_id': {'username': 'frokor', 'uid': '170061'}, 'count': 31427}
# {'_id': {'username': 'FredrikLindseth', 'uid': '1965308'}, 'count': 29969}
# {'_id': {'username': 'Gazer75', 'uid': '715936'}, 'count': 22168}
# {'_id': {'username': 'cmeeren_import', 'uid': '3119148'}, 'count': 19287}
# {'_id': {'username': 'gisle', 'uid': '8313'}, 'count': 16081}
# ----
# Total contributors: 681172
# Total contributions by top 10 contributors: 549853, 80.72%

# %% [markdown]
# We see here that the large majority of contributions are made by a tiny portion (2.5%) of the contributing users. It seems like a lot of the contributions are automated in some way, as 3 of the top 10 usernames end in "\_import". Any potential contribution patterns these few users have is likely to heavily impact the Bergen OSM data.

# %% [markdown]
# According to the address page of the OSM wiki, in mid-2014 all Norwegian official addresses were released to the public. Efforts are being made by OSM volunteers to include the released data in OSM, and the progress is being tracked using a tool called [Beebeetle](http://osm.beebeetle.com/addrnodeimportstatus.php). As of March 4, 2017, the Bergen import is listed as 99.83% complete. 1 known address duplicate is listed on the site.

# %% [markdown]
# ### Other Features

# %% [markdown]
# Before summing up my findings related to addresses, street names and users contributions, I'd like to take a look at the distribution of other features in the dataset.
#
# Since mongodb is schemaless, I'll have to come up with a way to show all available variables. Since documents with types 'node and 'way' are so different from eachother, I will aggregate them separately.

# %%
node_features = defaultdict(int)
node_count = 0

for doc in bergen.find({'type': 'node'}):    

    node_count += 1
    for k,v in doc.items():

        try:
            for key,val in v.items():
#             tmp_set.add(k+'_'+key)
                node_features[k+'.'+key] += 1
#         else:
        except AttributeError:
            if type(v) == list:
                for item in v:
                    if type(item) == dict:
                        for key,val in item.items():
                            node_features[k+'.'+key] += 1
                    else:
                        node_features[k] += 1
                
            elif type(v) == str:
                node_features[k] += 1
                    
print("number of node documents:",node_count)
print("Number of node feature types:",len(node_features))
# Out:
# number of node documents: 628779
# Number of node feature types: 490

# %%
way_count = 0
way_features = defaultdict(int)

for doc in bergen.find( {'type': 'way'}):    

    way_count += 1
    for k,v in doc.items():

        try:
            for key,val in v.items():
#             tmp_set.add(k+'_'+key)
                way_features[k+'.'+key] += 1
#         else:
        except AttributeError:
            if type(v) == list:
                for item in v:
                    if type(item) == dict:
                        for key,val in item.items():
                            way_features[k+'.'+key] += 1
                    else:
                        way_features[k] += 1
                
            elif type(v) == str:
                way_features[k] += 1

print("number of way documents:",way_count)
print("Number of way feature types:",len(way_features))
# Out:
# number of way documents: 52393
# Number of way feature types: 358

# %%
# #Commented out as it is not needed
# pipeline = [
#     {'$match': {'_type': {'$exists':1 } } },
#     {'$group': {'_id': {'type': '$type', 'feature_type':'$_type'}, 'count': {'$sum': 1 } } },
#     {'$sort': {'count': -1}}
# ]
    
# for doc in bergen.aggregate(pipeline):
#     print(doc)

# %%
pprint(way_features)
# Out:
# defaultdict(<class 'int'>,
#             {'FIXME': 26,
#              '_type': 14,
#              'abandoned': 4,
#              'abandoned.building': 3,
#              'abutters': 91,
#              'access': 334,
#              'access.conditional': 1,
#              'access.lanes': 4,
#              'access:lanes:backward': 1,
#              'address.city': 602,
#              'address.country': 53,
#              'address.floor': 2,
#              'address.housename': 12,
#              'address.housenumber': 599,
#              'address.postcode': 600,
#              'address.street': 620,
#              'admin_level': 50,
#              'aerialway': 19,
#              'aeroway': 35,
#              'alcohol': 1,
#              'alt_name': 44,
#              'amenity': 1013,
#              'aquaculture': 1,
#              'architect': 10,
#              'area': 53,
#              'artist_name': 12,
#              'artwork_type': 12,
#              'backrest': 28,
#              'barbecue': 1,
#              'barrier': 616,
#              'bench': 27,
#              'bicycle': 886,
#              'bicycle_parking': 11,
#              'boat': 18,
#              'boundary': 50,
#              'brand': 6,
#              'bridge': 461,
#              'bridge.name': 2,
#              'bridge.structure': 4,
#              'bridge.support': 4,
#              'building': 11422,
#              'building.colour': 61,
#              'building.height': 2,
#              'building.levels': 227,
#              'building.material': 29,
#              'building.min_level': 1,
#              'building.part': 7,
#              'building.use': 1,
#              'building:roof:colour': 1,
#              'bunker_type': 3,
#              'bus': 44,
#              'bus.lanes': 1,
#              'busway': 3,
#              'busway.left': 3,
#              'busway.right': 9,
#              'cables': 69,
#              'canoe': 17,
#              'capacity': 86,
#              'capacity.disabled': 15,
#              'capacity.psv': 1,
#              'charge': 4,
#              'circuits': 63,
#              'class': 1,
#              'colour': 60,
#              'construction': 104,
#              'contact.email': 16,
#              'contact.facebook': 4,
#              'contact.phone': 17,
#              'contact.website': 2,
#              'covered': 30,
#              'craft_beer': 1,
#              'created.changeset': 52393,
#              'created.timestamp': 52393,
#              'created.uid': 52393,
#              'created.user': 52393,
#              'created.version': 52393,
#              'created_by': 621,
#              'crossing': 12,
#              'cuisine': 5,
#              'cutting': 8,
#              'cycle': 1,
#              'cycleway': 145,
#              'cycleway.left': 15,
#              'cycleway.right': 32,
#              'cycleway.width': 3,
#              'delivery': 1,
#              'denomination': 38,
#              'depot.type': 1,
#              'depth': 1,
#              'description': 21,
#              'description.en': 10,
#              'description.no': 5,
#              'designation': 9,
#              'destination': 8,
#              'destination.lanes': 22,
#              'destination.ref': 15,
#              'direction': 1,
#              'disused': 4,
#              'disused.route': 1,
#              'duration': 5,
#              'ele': 25,
#              'electrified': 218,
#              'email': 30,
#              'embankment': 4,
#              'emergency': 14,
#              'end_date': 1,
#              'est_width': 12,
#              'except': 1,
#              'fee': 59,
#              'fence_type': 12,
#              'ferry': 5,
#              'fixme': 121,
#              'fixme.motor_vehicle': 1,
#              'floating': 67,
#              'foot': 2199,
#              'footway': 137,
#              'footway.width': 3,
#              'ford': 1,
#              'franchise': 1,
#              'frequency': 187,
#              'fuel:octane_95': 1,
#              'gauge': 216,
#              'golf': 38,
#              'goods': 5,
#              'handrail': 10,
#              'handrail.left': 1,
#              'handrail.right': 2,
#              'height': 143,
#              'hgv': 10,
#              'highway': 24686,
#              'hiking': 3,
#              'historic': 8,
#              'history': 4,
#              'horse': 56,
#              'icn_ref': 1,
#              'id': 52393,
#              'image': 1,
#              'incline': 129,
#              'indoor': 3,
#              'information': 2,
#              'inscription': 1,
#              'inscription.en': 1,
#              'int_name': 5,
#              'int_ref': 258,
#              'intermittent': 1,
#              'internet_access': 2,
#              'isced.level': 3,
#              'isps': 12,
#              'junction': 100,
#              'kindergarten': 1,
#              'landcover': 10,
#              'landuse': 626,
#              'lanes': 817,
#              'lanes.backward': 9,
#              'lanes.forward': 10,
#              'lanes.psv': 13,
#              'lanes:psv:backward': 1,
#              'layer': 965,
#              'lcn_ref': 20,
#              'leaf_cycle': 4,
#              'leaf_type': 34,
#              'leisure': 448,
#              'length': 9,
#              'level': 91,
#              'line': 56,
#              'lit': 524,
#              'loc_name': 24,
#              'location': 11,
#              'lottery': 1,
#              'man_made': 447,
#              'material': 97,
#              'max_age': 16,
#              'maxaxleload': 2,
#              'maxheight': 35,
#              'maxlength': 4,
#              'maxspeed': 4982,
#              'maxstay': 11,
#              'maxweight': 6,
#              'maxwidth': 9,
#              'military': 9,
#              'min_age': 16,
#              'mooring': 6,
#              'moped': 8,
#              'motor_vehicle': 156,
#              'motorboat': 17,
#              'motorcar': 118,
#              'motorcycle': 14,
#              'motorroad': 58,
#              'mtb.name': 1,
#              'mtb.scale': 8,
#              'name': 14293,
#              'name.da': 1,
#              'name.de': 1,
#              'name.en': 165,
#              'name.es': 1,
#              'name.fr': 1,
#              'name.nb': 9,
#              'name.nl': 1,
#              'name.nn': 2,
#              'name.no': 2,
#              'name.uk': 1,
#              'nat_name': 1,
#              'natural': 2942,
#              'natural.no': 2,
#              'ncn_ref': 28,
#              'no-barnehage:nsrid': 15,
#              'no-bergen-playgrounds:id': 9,
#              'no-kartverket-ssr:url': 1,
#              'node_refs': 636272,
#              'noexit': 1,
#              'note': 217,
#              'note.artwork': 1,
#              'note.en': 1,
#              'note.maxspeed': 4,
#              'note.no': 8,
#              'note.speed': 33,
#              'nvdb.date': 6182,
#              'nvdb.id': 6077,
#              'nvdb:id:part': 49,
#              'office': 1,
#              'official_name': 1,
#              'old_name': 36,
#              'oneway': 1925,
#              'oneway.bicycle': 2,
#              'opening_hours': 31,
#              'operator': 171,
#              'operator.en': 43,
#              'operator.type': 16,
#              'outdoor_seating': 4,
#              'park_ride': 19,
#              'parking': 156,
#              'passing_places': 2,
#              'path': 1,
#              'phone': 52,
#              'piste.type': 2,
#              'place': 30,
#              'place_numbers': 3,
#              'placement': 2,
#              'playground': 5,
#              'playground.playhouse': 1,
#              'playground.sandpit': 1,
#              'playground.seesaw': 1,
#              'postal_code': 1,
#              'power': 193,
#              'private': 3,
#              'proposed': 44,
#              'psv': 101,
#              'psv.lanes': 24,
#              'psv:lanes:backward': 1,
#              'psv:lanes:forward': 1,
#              'public_transport': 45,
#              'railway': 456,
#              'railway.historic': 1,
#              'ramp': 1,
#              'ramp.stroller': 4,
#              'recycling.paper': 1,
#              'recycling_type': 1,
#              'ref': 1997,
#              'ref.lanes': 11,
#              'religion': 51,
#              'restriction': 1,
#              'roof.colour': 60,
#              'roof.levels': 23,
#              'roof.material': 24,
#              'roof.shape': 49,
#              'route': 21,
#              'ruins': 7,
#              'sac_scale': 511,
#              'salt': 1,
#              'seamark.type': 1,
#              'seamark:bridge:category': 1,
#              'seamark:bridge:clearance_height_closed': 1,
#              'seamark:bridge:clearance_height_open': 1,
#              'seamark:bridge:clearance_width': 1,
#              'seasonal': 1,
#              'sec_level': 1,
#              'segregated': 272,
#              'service': 777,
#              'service_times': 3,
#              'shared_with': 1,
#              'shelter': 18,
#              'shelter_type': 3,
#              'ship': 17,
#              'shop': 52,
#              'short_name': 5,
#              'sidewalk': 84,
#              'ski': 5,
#              'smoking': 6,
#              'smoothness': 55,
#              'snowmobile': 5,
#              'social_facility': 2,
#              'social_facility.for': 2,
#              'sou': 1,
#              'source': 11920,
#              'source.correction': 1,
#              'source.date': 10677,
#              'source.highway': 4,
#              'source.name': 1,
#              'source.outline': 1,
#              'source.position': 7,
#              'source.waterway': 2,
#              'species': 19,
#              'sport': 187,
#              'stars': 1,
#              'start_date': 46,
#              'step_count': 21,
#              'subject': 3,
#              'substation': 1,
#              'supervised': 5,
#              'surface': 1277,
#              'tactile': 1,
#              'tactile_paving': 13,
#              'takeaway': 1,
#              'taxi': 9,
#              'tee': 19,
#              'theatre.type': 1,
#              'tidal': 1,
#              'toilets.wheelchair': 9,
#              'toll': 9,
#              'toll.backward': 9,
#              'toll.forward': 9,
#              'tourism': 56,
#              'tower.type': 3,
#              'track_visibility': 1,
#              'tracks': 20,
#              'tracktype': 61,
#              'tractor': 2,
#              'trail_visibility': 75,
#              'trailblazed': 1,
#              'tram': 16,
#              'trolley_wire': 10,
#              'tunnel': 400,
#              'tunnel.name': 7,
#              'turn.lanes': 84,
#              'turn:lanes:forward': 4,
#              'type': 52393,
#              'underground': 2,
#              'unisex': 1,
#              'url': 1,
#              'usage': 23,
#              'vehicle': 2,
#              'via': 1,
#              'voltage': 310,
#              'wall': 23,
#              'water': 61,
#              'waterway': 1000,
#              'website': 131,
#              'website.en': 1,
#              'wetland': 417,
#              'wheelchair': 172,
#              'wheelchair.description': 2,
#              'whitewater.grade': 1,
#              'width': 65,
#              'wikidata': 84,
#              'wikipedia': 91,
#              'wikipedia.en': 1,
#              'wikipedia.no': 1,
#              'wires': 5})

# %%
#Listing the way features sorted by count

for key in sorted(way_features,key=way_features.get,reverse=True):
    print(key,way_features[key])
# Out:
# node_refs 636272
# type 52393
# created.changeset 52393
# created.user 52393
# id 52393
# created.timestamp 52393
# created.uid 52393
# created.version 52393
# highway 24686
# name 14293
# source 11920
# building 11422
# source.date 10677
# nvdb.date 6182
# nvdb.id 6077
# maxspeed 4982
# natural 2942
# foot 2199
# ref 1997
# oneway 1925
# surface 1277
# amenity 1013
# waterway 1000
# layer 965
# bicycle 886
# lanes 817
# service 777
# landuse 626
# created_by 621
# address.street 620
# barrier 616
# address.city 602
# address.postcode 600
# address.housenumber 599
# lit 524
# sac_scale 511
# bridge 461
# railway 456
# leisure 448
# man_made 447
# wetland 417
# tunnel 400
# access 334
# voltage 310
# segregated 272
# int_ref 258
# building.levels 227
# electrified 218
# note 217
# gauge 216
# power 193
# frequency 187
# sport 187
# wheelchair 172
# operator 171
# name.en 165
# parking 156
# motor_vehicle 156
# cycleway 145
# height 143
# footway 137
# website 131
# incline 129
# fixme 121
# motorcar 118
# construction 104
# psv 101
# junction 100
# material 97
# wikipedia 91
# level 91
# abutters 91
# capacity 86
# turn.lanes 84
# wikidata 84
# sidewalk 84
# trail_visibility 75
# cables 69
# floating 67
# width 65
# circuits 63
# tracktype 61
# building.colour 61
# water 61
# colour 60
# roof.colour 60
# fee 59
# motorroad 58
# tourism 56
# horse 56
# line 56
# smoothness 55
# area 53
# address.country 53
# phone 52
# shop 52
# religion 51
# boundary 50
# admin_level 50
# roof.shape 49
# nvdb:id:part 49
# start_date 46
# public_transport 45
# proposed 44
# bus 44
# alt_name 44
# operator.en 43
# golf 38
# denomination 38
# old_name 36
# maxheight 35
# aeroway 35
# leaf_type 34
# note.speed 33
# cycleway.right 32
# opening_hours 31
# place 30
# email 30
# covered 30
# building.material 29
# ncn_ref 28
# backrest 28
# bench 27
# FIXME 26
# ele 25
# psv.lanes 24
# loc_name 24
# roof.material 24
# wall 23
# usage 23
# roof.levels 23
# destination.lanes 22
# step_count 21
# route 21
# description 21
# tracks 20
# lcn_ref 20
# tee 19
# park_ride 19
# aerialway 19
# species 19
# boat 18
# shelter 18
# canoe 17
# motorboat 17
# contact.phone 17
# ship 17
# max_age 16
# operator.type 16
# tram 16
# contact.email 16
# min_age 16
# destination.ref 15
# cycleway.left 15
# capacity.disabled 15
# no-barnehage:nsrid 15
# motorcycle 14
# emergency 14
# _type 14
# tactile_paving 13
# lanes.psv 13
# artwork_type 12
# artist_name 12
# crossing 12
# est_width 12
# isps 12
# fence_type 12
# address.housename 12
# bicycle_parking 11
# maxstay 11
# location 11
# ref.lanes 11
# hgv 10
# landcover 10
# lanes.forward 10
# description.en 10
# handrail 10
# architect 10
# trolley_wire 10
# no-bergen-playgrounds:id 9
# maxwidth 9
# designation 9
# name.nb 9
# toilets.wheelchair 9
# taxi 9
# toll 9
# busway.right 9
# lanes.backward 9
# toll.backward 9
# length 9
# toll.forward 9
# military 9
# note.no 8
# mtb.scale 8
# destination 8
# historic 8
# cutting 8
# moped 8
# ruins 7
# source.position 7
# building.part 7
# tunnel.name 7
# maxweight 6
# brand 6
# smoking 6
# mooring 6
# playground 5
# snowmobile 5
# duration 5
# ski 5
# description.no 5
# int_name 5
# supervised 5
# wires 5
# cuisine 5
# goods 5
# ferry 5
# short_name 5
# maxlength 4
# leaf_cycle 4
# disused 4
# note.maxspeed 4
# turn:lanes:forward 4
# embankment 4
# outdoor_seating 4
# history 4
# bridge.structure 4
# access.lanes 4
# bridge.support 4
# source.highway 4
# ramp.stroller 4
# contact.facebook 4
# abandoned 4
# charge 4
# place_numbers 3
# indoor 3
# service_times 3
# isced.level 3
# private 3
# busway 3
# cycleway.width 3
# busway.left 3
# hiking 3
# tower.type 3
# abandoned.building 3
# subject 3
# shelter_type 3
# footway.width 3
# bunker_type 3
# building.height 2
# name.nn 2
# vehicle 2
# maxaxleload 2
# handrail.right 2
# address.floor 2
# wheelchair.description 2
# oneway.bicycle 2
# underground 2
# natural.no 2
# bridge.name 2
# contact.website 2
# information 2
# placement 2
# social_facility.for 2
# social_facility 2
# internet_access 2
# tractor 2
# passing_places 2
# piste.type 2
# source.waterway 2
# name.no 2
# substation 1
# website.en 1
# track_visibility 1
# depth 1
# fuel:octane_95 1
# takeaway 1
# direction 1
# note.en 1
# mtb.name 1
# playground.sandpit 1
# inscription 1
# lottery 1
# bus.lanes 1
# seamark:bridge:clearance_width 1
# cycle 1
# name.nl 1
# access:lanes:backward 1
# building.use 1
# lanes:psv:backward 1
# nat_name 1
# wikipedia.no 1
# path 1
# psv:lanes:backward 1
# whitewater.grade 1
# wikipedia.en 1
# access.conditional 1
# salt 1
# source.outline 1
# capacity.psv 1
# postal_code 1
# recycling_type 1
# stars 1
# official_name 1
# ford 1
# playground.playhouse 1
# name.fr 1
# craft_beer 1
# sou 1
# unisex 1
# building.min_level 1
# note.artwork 1
# except 1
# shared_with 1
# name.uk 1
# seamark:bridge:category 1
# tidal 1
# seamark:bridge:clearance_height_closed 1
# barbecue 1
# intermittent 1
# seamark.type 1
# franchise 1
# psv:lanes:forward 1
# name.es 1
# name.de 1
# restriction 1
# tactile 1
# aquaculture 1
# delivery 1
# railway.historic 1
# building:roof:colour 1
# icn_ref 1
# source.name 1
# seamark:bridge:clearance_height_open 1
# name.da 1
# trailblazed 1
# ramp 1
# url 1
# seasonal 1
# playground.seesaw 1
# no-kartverket-ssr:url 1
# sec_level 1
# class 1
# image 1
# recycling.paper 1
# source.correction 1
# kindergarten 1
# handrail.left 1
# noexit 1
# disused.route 1
# end_date 1
# depot.type 1
# theatre.type 1
# office 1
# alcohol 1
# inscription.en 1
# via 1
# fixme.motor_vehicle 1

# %%
pprint(node_features)
# Out:
# defaultdict(<class 'int'>,
#             {'FIXME': 4,
#              'IATAKODE': 2,
#              'ICAOKODE': 2,
#              'LUFTHAVNTYPE': 2,
#              'TODO': 1,
#              '_type': 25,
#              'abandoned.building': 6,
#              'access': 243,
#              'address.city': 83784,
#              'address.country': 92,
#              'address.floor': 317,
#              'address.full': 2,
#              'address.housename': 5,
#              'address.housenumber': 83778,
#              'address.postcode': 83790,
#              'address.street': 83821,
#              'advertising': 6,
#              'aerialway': 2,
#              'aeroway': 23,
#              'alt_name': 60,
#              'amenity': 2410,
#              'amenity.no': 1,
#              'amperage': 3,
#              'artist_name': 128,
#              'artwork_subject': 44,
#              'artwork_type': 178,
#              'atm': 11,
#              'authentication.none': 1,
#              'automatic': 1,
#              'backrest': 525,
#              'barrier': 595,
#              'bench': 59,
#              'bicycle': 108,
#              'bicycle_parking': 79,
#              'board_type': 6,
#              'bollard': 1,
#              'branch.type': 2,
#              'brand': 21,
#              'brewery': 40,
#              'building': 41,
#              'bunker_type': 6,
#              'bus': 241,
#              'button_operated': 1,
#              'bys': 1,
#              'cabins': 1,
#              'camera.mount': 6,
#              'camera.type': 6,
#              'canoe_rental': 1,
#              'capacity': 131,
#              'capacity.disabled': 1,
#              'car': 4,
#              'caravans': 3,
#              'changing_table': 5,
#              'charge': 13,
#              'climbing.boulder': 1,
#              'club': 4,
#              'collection_times': 1,
#              'college': 1,
#              'colour': 269,
#              'comment': 2,
#              'communication': 1,
#              'contact.email': 26,
#              'contact.facebook': 124,
#              'contact.fax': 4,
#              'contact.instagram': 4,
#              'contact.phone': 23,
#              'contact.twitter': 3,
#              'contact.webcam': 1,
#              'contact.website': 9,
#              'covered': 53,
#              'craft': 42,
#              'craft_beer': 7,
#              'created.changeset': 628779,
#              'created.timestamp': 628779,
#              'created.uid': 628779,
#              'created.user': 628779,
#              'created.version': 628779,
#              'created_by': 7918,
#              'crossing': 598,
#              'crossing.bell': 2,
#              'crossing.light': 12,
#              'crossing_ref': 100,
#              'cuisine': 194,
#              'cycleway': 1,
#              'dance.teaching': 1,
#              'delivery': 1,
#              'denomination': 6,
#              'denotation': 6,
#              'description': 130,
#              'description.en': 16,
#              'description.no': 2,
#              'design': 84,
#              'designation': 6,
#              'destination': 1,
#              'diameter_crown': 14,
#              'diaper': 5,
#              'diet.vegetarian': 9,
#              'direction': 9,
#              'dispensing': 3,
#              'display': 5,
#              'disused': 4,
#              'drink.beer': 1,
#              'drink.soda': 1,
#              'drinking_water': 2,
#              'drive_through': 1,
#              'duration': 1,
#              'ele': 196,
#              'email': 288,
#              'emergency': 15,
#              'entrance': 381,
#              'fax': 5,
#              'fee': 48,
#              'fee.car': 22,
#              'fee.hgv': 22,
#              'female': 17,
#              'ferry': 5,
#              'fire_hydrant.type': 2,
#              'fireplace': 2,
#              'fixme': 114,
#              'foot': 102,
#              'franchise': 7,
#              'fuel.diesel': 5,
#              'fuel.lpg': 4,
#              'fuel:HGV_diesel': 3,
#              'fuel:octane_100': 1,
#              'fuel:octane_95': 5,
#              'fuel:octane_98': 3,
#              'gambling': 1,
#              'gay': 1,
#              'gender': 26,
#              'generator.source': 1,
#              'hazard': 2,
#              'health_facility.type': 5,
#              'health_food': 1,
#              'health_specialty.acupuncture': 1,
#              'health_specialty.alternative_medicine': 2,
#              'health_specialty.paediatric_orthopaedics': 1,
#              'health_specialty.physiotherapy': 8,
#              'health_specialty.radiology': 1,
#              'healthcare': 4,
#              'healthcare.speciality': 1,
#              'height': 30,
#              'heritage': 1,
#              'heritage.operator': 1,
#              'heritage.website': 1,
#              'highway': 2528,
#              'hiking': 10,
#              'historic': 49,
#              'horse': 10,
#              'id': 628779,
#              'image': 1,
#              'indoor': 1,
#              'industrial': 1,
#              'information': 56,
#              'inscription': 49,
#              'int_name': 3,
#              'internet_access': 26,
#              'internet_access.fee': 7,
#              'internet_access.ssid': 8,
#              'internet_access.type': 1,
#              'is_in.continent': 1,
#              'is_in.country': 1,
#              'is_in.country_code': 1,
#              'isced.level': 1,
#              'junction': 2,
#              'karaoke': 1,
#              'kayak_rental': 1,
#              'kitchen_hours': 1,
#              'landuse': 2,
#              'lanes': 1,
#              'layer': 4,
#              'leaf_type': 1953,
#              'leisure': 364,
#              'level': 367,
#              'lit': 2,
#              'loc_name': 9,
#              'local_ref': 1,
#              'location': 150,
#              'location.transition': 4,
#              'lottery': 24,
#              'male': 17,
#              'man_made': 193,
#              'map_size': 4,
#              'map_type': 5,
#              'massage': 11,
#              'material': 795,
#              'max_age': 24,
#              'maxheight': 20,
#              'maxspeed': 11,
#              'maxspeed.backward': 1,
#              'maxspeed.forward': 1,
#              'maxstay': 1,
#              'maxweight': 4,
#              'maxwidth': 1,
#              'medical_system.western': 8,
#              'memorial': 7,
#              'microbrewery': 3,
#              'military': 17,
#              'min_age': 24,
#              'monitoring.bicycle': 1,
#              'motor_vehicle': 8,
#              'motorcar': 16,
#              'motorcycle': 16,
#              'music': 1,
#              'music_type.en': 2,
#              'music_type.no': 2,
#              'musical_instrument': 3,
#              'name': 3861,
#              'name.cn': 2,
#              'name.da': 1,
#              'name.de': 1,
#              'name.en': 24,
#              'name.fr': 1,
#              'name.he': 1,
#              'name.hu': 1,
#              'name.ja': 1,
#              'name.lv': 1,
#              'name.nn': 1,
#              'name.no': 2,
#              'name.ru': 2,
#              'name.zh': 1,
#              'name_1': 1,
#              'name_2': 1,
#              'nat_name': 3,
#              'natural': 2164,
#              'no-barnehage:nsrid': 24,
#              'no-bergen-playgrounds:id': 118,
#              'noexit': 8,
#              'note': 166,
#              'note.no': 7,
#              'odbl': 1,
#              'office': 259,
#              'official_name': 8,
#              'old_name': 12,
#              'opening_date': 1,
#              'opening_hours': 475,
#              'operator': 548,
#              'operator.type': 24,
#              'organic': 2,
#              'outdoor': 1,
#              'outdoor_seating': 109,
#              'parking': 29,
#              'payment.bitcoin': 2,
#              'payment.cash': 2,
#              'payment.coins': 2,
#              'payment.credit_cards': 3,
#              'payment.debit_cards': 2,
#              'payment.notes': 1,
#              'phone': 517,
#              'place': 250,
#              'playground': 36,
#              'playground.theme': 1,
#              'population': 2,
#              'population.date': 1,
#              'population.source': 1,
#              'population_precision': 1,
#              'pos': 1257558,
#              'postal_code': 1,
#              'power': 564,
#              'public_transport': 498,
#              'railway': 165,
#              'recycling.aluminium': 1,
#              'recycling.batteries': 2,
#              'recycling.beverage_cartons': 1,
#              'recycling.books': 2,
#              'recycling.cans': 1,
#              'recycling.cardboard': 88,
#              'recycling.cartons': 3,
#              'recycling.chipboard': 1,
#              'recycling.christmas_trees': 1,
#              'recycling.clothes': 31,
#              'recycling.cooking_oil': 1,
#              'recycling.cork': 1,
#              'recycling.electrical_appliances': 1,
#              'recycling.engine_oil': 1,
#              'recycling.flat_glass': 1,
#              'recycling.fluorescent_tubes': 1,
#              'recycling.foil': 1,
#              'recycling.fridge_and_freezer': 1,
#              'recycling.garden_waste': 1,
#              'recycling.glass': 84,
#              'recycling.glass_bottles': 9,
#              'recycling.green_waste': 1,
#              'recycling.hardcode': 1,
#              'recycling.light_bulbs': 1,
#              'recycling.low_energy_bulbs': 1,
#              'recycling.magazines': 1,
#              'recycling.metal': 84,
#              'recycling.mobile_phones': 1,
#              'recycling.music': 1,
#              'recycling.newspaper': 1,
#              'recycling.paper': 88,
#              'recycling.paper_packaging': 1,
#              'recycling.plasterboard': 1,
#              'recycling.plastic_bags': 1,
#              'recycling.plastic_bottles': 1,
#              'recycling.plastic_packaging': 57,
#              'recycling.polyester': 1,
#              'recycling.printer_cartridges': 1,
#              'recycling.sheet_metal': 1,
#              'recycling.shoes': 1,
#              'recycling.small_appliances': 2,
#              'recycling.tv_monitor': 1,
#              'recycling.tyres': 1,
#              'recycling.waste': 45,
#              'recycling.waste_oil': 1,
#              'recycling.white_goods': 1,
#              'recycling.wood': 2,
#              'recycling_type': 162,
#              'ref': 68,
#              'ref.whc': 1,
#              'religion': 18,
#              'repair': 1,
#              'ruins': 13,
#              'seamark.information': 6,
#              'seamark.name': 34,
#              'seamark.type': 186,
#              'seamark:light:10:character': 1,
#              'seamark:light:10:colour': 1,
#              'seamark:light:10:group': 1,
#              'seamark:light:10:height': 1,
#              'seamark:light:10:period': 1,
#              'seamark:light:10:range': 1,
#              'seamark:light:10:sector_end': 1,
#              'seamark:light:10:sector_start': 1,
#              'seamark:light:1:character': 19,
#              'seamark:light:1:colour': 19,
#              'seamark:light:1:group': 8,
#              'seamark:light:1:height': 19,
#              'seamark:light:1:period': 18,
#              'seamark:light:1:range': 19,
#              'seamark:light:1:sector_end': 18,
#              'seamark:light:1:sector_start': 17,
#              'seamark:light:2:character': 19,
#              'seamark:light:2:colour': 19,
#              'seamark:light:2:group': 8,
#              'seamark:light:2:height': 19,
#              'seamark:light:2:period': 18,
#              'seamark:light:2:range': 19,
#              'seamark:light:2:sector_end': 17,
#              'seamark:light:2:sector_start': 17,
#              'seamark:light:3:character': 19,
#              'seamark:light:3:colour': 19,
#              'seamark:light:3:group': 8,
#              'seamark:light:3:height': 19,
#              'seamark:light:3:period': 18,
#              'seamark:light:3:range': 19,
#              'seamark:light:3:sector_end': 17,
#              'seamark:light:3:sector_start': 17,
#              'seamark:light:4:character': 14,
#              'seamark:light:4:colour': 14,
#              'seamark:light:4:group': 6,
#              'seamark:light:4:height': 14,
#              'seamark:light:4:period': 13,
#              'seamark:light:4:range': 14,
#              'seamark:light:4:sector_end': 14,
#              'seamark:light:4:sector_start': 14,
#              'seamark:light:5:character': 14,
#              'seamark:light:5:colour': 14,
#              'seamark:light:5:group': 6,
#              'seamark:light:5:height': 14,
#              'seamark:light:5:period': 13,
#              'seamark:light:5:range': 14,
#              'seamark:light:5:sector_end': 14,
#              'seamark:light:5:sector_start': 14,
#              'seamark:light:6:character': 9,
#              'seamark:light:6:colour': 9,
#              'seamark:light:6:group': 3,
#              'seamark:light:6:height': 9,
#              'seamark:light:6:period': 8,
#              'seamark:light:6:range': 9,
#              'seamark:light:6:sector_end': 7,
#              'seamark:light:6:sector_start': 9,
#              'seamark:light:7:character': 3,
#              'seamark:light:7:colour': 3,
#              'seamark:light:7:group': 1,
#              'seamark:light:7:height': 3,
#              'seamark:light:7:period': 2,
#              'seamark:light:7:range': 3,
#              'seamark:light:7:sector_end': 2,
#              'seamark:light:7:sector_start': 3,
#              'seamark:light:8:character': 2,
#              'seamark:light:8:colour': 2,
#              'seamark:light:8:group': 1,
#              'seamark:light:8:height': 2,
#              'seamark:light:8:period': 2,
#              'seamark:light:8:range': 2,
#              'seamark:light:8:sector_end': 2,
#              'seamark:light:8:sector_start': 2,
#              'seamark:light:9:character': 1,
#              'seamark:light:9:colour': 1,
#              'seamark:light:9:group': 1,
#              'seamark:light:9:height': 1,
#              'seamark:light:9:period': 1,
#              'seamark:light:9:range': 1,
#              'seamark:light:9:sector_end': 1,
#              'seamark:light:9:sector_start': 1,
#              'seamark:light:category': 1,
#              'seamark:light:character': 16,
#              'seamark:light:colour': 16,
#              'seamark:light:height': 10,
#              'seamark:light:period': 9,
#              'seamark:light:range': 15,
#              'seamark:light:reference': 34,
#              'seamark:light:sequence': 2,
#              'seamark:radar_transponder:category': 1,
#              'seamark:radar_transponder:group': 1,
#              'seamark:radar_transponder:period': 1,
#              'seats': 8,
#              'second_hand': 7,
#              'service': 1,
#              'service_times': 1,
#              'sex': 2,
#              'shelter': 97,
#              'shelter_type': 13,
#              'shop': 1112,
#              'short_name': 7,
#              'side': 1,
#              'site_type': 1,
#              'smoking': 9,
#              'socket.chademo': 2,
#              'socket.schuko': 4,
#              'socket.tesla_supercharger': 1,
#              'socket:chademo:amperage': 1,
#              'socket:combo2': 1,
#              'socket:type1': 1,
#              'socket:type1:amperage': 1,
#              'socket:type2': 2,
#              'socket:type2:amperage': 1,
#              'socket:type2:voltage': 1,
#              'source': 6537,
#              'source.amenity': 3,
#              'source.date': 2634,
#              'source.note': 1,
#              'source.position': 1,
#              'source.ref': 67,
#              'source.shop': 1,
#              'source.url': 10,
#              'species': 226,
#              'species.en': 1,
#              'species.no': 17,
#              'sport': 34,
#              'stars': 3,
#              'start_date': 165,
#              'structure': 51,
#              'subject': 11,
#              'subject.en': 1,
#              'supervised': 26,
#              'support': 6,
#              'surface': 5,
#              'surveillance': 25,
#              'surveillance.type': 10,
#              'swing_gate.type': 5,
#              'tactile_paving': 63,
#              'takeaway': 14,
#              'telephone': 1,
#              'time': 120,
#              'toilets': 6,
#              'toilets.disposal': 2,
#              'toilets.position': 2,
#              'toilets.wheelchair': 32,
#              'tourism': 446,
#              'tower.type': 60,
#              'tower_type': 1,
#              'traffic_calming': 103,
#              'traffic_sign': 1,
#              'tram': 16,
#              'transformer': 12,
#              'trolleybus': 40,
#              'tunnel': 3,
#              'type': 628779,
#              'underground': 1,
#              'unisex': 1,
#              'url': 11,
#              'vehicle': 4,
#              'vending': 41,
#              'visibility': 5,
#              'voltage': 9,
#              'waterway': 6,
#              'website': 739,
#              'website.en': 4,
#              'whc.criteria': 1,
#              'whc.inscription_date': 1,
#              'wheelchair': 534,
#              'wheelchair.description': 7,
#              'wholesale': 2,
#              'wifi': 2,
#              'wikidata': 19,
#              'wikipedia': 47,
#              'wires': 1})

# %%
#Listing the node features sorted by count

for key in sorted(node_features,key=node_features.get,reverse=True):
    print(key,node_features[key])
# Out:
# pos 1257558
# type 628779
# created.changeset 628779
# created.user 628779
# created.version 628779
# id 628779
# created.timestamp 628779
# created.uid 628779
# address.street 83821
# address.postcode 83790
# address.city 83784
# address.housenumber 83778
# created_by 7918
# source 6537
# name 3861
# source.date 2634
# highway 2528
# amenity 2410
# natural 2164
# leaf_type 1953
# shop 1112
# material 795
# website 739
# crossing 598
# barrier 595
# power 564
# operator 548
# wheelchair 534
# backrest 525
# phone 517
# public_transport 498
# opening_hours 475
# tourism 446
# entrance 381
# level 367
# leisure 364
# address.floor 317
# email 288
# colour 269
# office 259
# place 250
# access 243
# bus 241
# species 226
# ele 196
# cuisine 194
# man_made 193
# seamark.type 186
# artwork_type 178
# note 166
# start_date 165
# railway 165
# recycling_type 162
# location 150
# capacity 131
# description 130
# artist_name 128
# contact.facebook 124
# time 120
# no-bergen-playgrounds:id 118
# fixme 114
# outdoor_seating 109
# bicycle 108
# traffic_calming 103
# foot 102
# crossing_ref 100
# shelter 97
# address.country 92
# recycling.cardboard 88
# recycling.paper 88
# design 84
# recycling.metal 84
# recycling.glass 84
# bicycle_parking 79
# ref 68
# source.ref 67
# tactile_paving 63
# tower.type 60
# alt_name 60
# bench 59
# recycling.plastic_packaging 57
# information 56
# covered 53
# structure 51
# inscription 49
# historic 49
# fee 48
# wikipedia 47
# recycling.waste 45
# artwork_subject 44
# craft 42
# vending 41
# building 41
# brewery 40
# trolleybus 40
# playground 36
# seamark:light:reference 34
# seamark.name 34
# sport 34
# toilets.wheelchair 32
# recycling.clothes 31
# height 30
# parking 29
# internet_access 26
# supervised 26
# gender 26
# contact.email 26
# surveillance 25
# _type 25
# max_age 24
# lottery 24
# operator.type 24
# name.en 24
# min_age 24
# no-barnehage:nsrid 24
# contact.phone 23
# aeroway 23
# fee.car 22
# fee.hgv 22
# brand 21
# maxheight 20
# seamark:light:1:character 19
# seamark:light:3:height 19
# seamark:light:1:height 19
# seamark:light:2:colour 19
# seamark:light:2:character 19
# seamark:light:3:colour 19
# seamark:light:2:range 19
# seamark:light:3:character 19
# seamark:light:3:range 19
# wikidata 19
# seamark:light:1:range 19
# seamark:light:1:colour 19
# seamark:light:2:height 19
# seamark:light:1:period 18
# seamark:light:2:period 18
# seamark:light:3:period 18
# religion 18
# seamark:light:1:sector_end 18
# military 17
# seamark:light:3:sector_end 17
# male 17
# female 17
# seamark:light:2:sector_start 17
# seamark:light:3:sector_start 17
# seamark:light:2:sector_end 17
# species.no 17
# seamark:light:1:sector_start 17
# seamark:light:character 16
# motorcycle 16
# description.en 16
# tram 16
# motorcar 16
# seamark:light:colour 16
# emergency 15
# seamark:light:range 15
# seamark:light:5:height 14
# seamark:light:5:character 14
# takeaway 14
# seamark:light:5:range 14
# seamark:light:4:character 14
# seamark:light:5:sector_end 14
# seamark:light:4:range 14
# seamark:light:4:sector_start 14
# seamark:light:4:colour 14
# seamark:light:5:sector_start 14
# seamark:light:4:sector_end 14
# diameter_crown 14
# seamark:light:5:colour 14
# seamark:light:4:height 14
# ruins 13
# seamark:light:4:period 13
# charge 13
# shelter_type 13
# seamark:light:5:period 13
# transformer 12
# crossing.light 12
# old_name 12
# atm 11
# maxspeed 11
# massage 11
# url 11
# subject 11
# source.url 10
# horse 10
# surveillance.type 10
# hiking 10
# seamark:light:height 10
# seamark:light:6:range 9
# voltage 9
# diet.vegetarian 9
# contact.website 9
# seamark:light:6:character 9
# smoking 9
# direction 9
# recycling.glass_bottles 9
# seamark:light:6:colour 9
# seamark:light:6:height 9
# loc_name 9
# seamark:light:6:sector_start 9
# seamark:light:period 9
# medical_system.western 8
# seamark:light:6:period 8
# seamark:light:1:group 8
# internet_access.ssid 8
# official_name 8
# health_specialty.physiotherapy 8
# motor_vehicle 8
# seamark:light:2:group 8
# seamark:light:3:group 8
# seats 8
# noexit 8
# note.no 7
# second_hand 7
# wheelchair.description 7
# craft_beer 7
# internet_access.fee 7
# franchise 7
# short_name 7
# memorial 7
# seamark:light:6:sector_end 7
# toilets 6
# abandoned.building 6
# denomination 6
# designation 6
# support 6
# board_type 6
# seamark:light:4:group 6
# bunker_type 6
# denotation 6
# seamark:light:5:group 6
# advertising 6
# camera.mount 6
# camera.type 6
# waterway 6
# seamark.information 6
# fax 5
# swing_gate.type 5
# fuel:octane_95 5
# diaper 5
# surface 5
# display 5
# changing_table 5
# ferry 5
# fuel.diesel 5
# health_facility.type 5
# visibility 5
# address.housename 5
# map_type 5
# layer 4
# vehicle 4
# maxweight 4
# disused 4
# socket.schuko 4
# contact.instagram 4
# fuel.lpg 4
# FIXME 4
# location.transition 4
# contact.fax 4
# website.en 4
# map_size 4
# club 4
# car 4
# healthcare 4
# tunnel 3
# payment.credit_cards 3
# contact.twitter 3
# seamark:light:7:character 3
# musical_instrument 3
# stars 3
# seamark:light:7:colour 3
# fuel:octane_98 3
# seamark:light:6:group 3
# int_name 3
# seamark:light:7:sector_start 3
# seamark:light:7:range 3
# source.amenity 3
# caravans 3
# dispensing 3
# seamark:light:7:height 3
# fuel:HGV_diesel 3
# microbrewery 3
# amperage 3
# nat_name 3
# recycling.cartons 3
# recycling.batteries 2
# name.no 2
# drinking_water 2
# fire_hydrant.type 2
# music_type.en 2
# socket:type2 2
# recycling.books 2
# music_type.no 2
# aerialway 2
# socket.chademo 2
# seamark:light:8:character 2
# seamark:light:8:colour 2
# seamark:light:8:sector_end 2
# recycling.wood 2
# population 2
# seamark:light:8:period 2
# seamark:light:7:sector_end 2
# description.no 2
# branch.type 2
# seamark:light:sequence 2
# landuse 2
# seamark:light:8:range 2
# hazard 2
# organic 2
# crossing.bell 2
# fireplace 2
# wifi 2
# payment.bitcoin 2
# health_specialty.alternative_medicine 2
# name.cn 2
# recycling.small_appliances 2
# junction 2
# payment.coins 2
# lit 2
# name.ru 2
# wholesale 2
# payment.cash 2
# toilets.position 2
# seamark:light:8:height 2
# sex 2
# LUFTHAVNTYPE 2
# payment.debit_cards 2
# address.full 2
# toilets.disposal 2
# ICAOKODE 2
# IATAKODE 2
# seamark:light:8:sector_start 2
# comment 2
# seamark:light:7:period 2
# canoe_rental 1
# bys 1
# internet_access.type 1
# button_operated 1
# is_in.country 1
# maxwidth 1
# recycling.flat_glass 1
# recycling.plasterboard 1
# name.nn 1
# duration 1
# music 1
# seamark:light:9:group 1
# heritage.website 1
# health_specialty.paediatric_orthopaedics 1
# authentication.none 1
# seamark:light:9:sector_start 1
# source.position 1
# seamark:light:9:height 1
# side 1
# wires 1
# socket:type1:amperage 1
# name.hu 1
# species.en 1
# name.zh 1
# recycling.printer_cartridges 1
# traffic_sign 1
# recycling.polyester 1
# indoor 1
# recycling.mobile_phones 1
# heritage 1
# recycling.newspaper 1
# recycling.music 1
# name.lv 1
# name_2 1
# service_times 1
# recycling.green_waste 1
# automatic 1
# lanes 1
# is_in.continent 1
# communication 1
# kayak_rental 1
# seamark:light:10:colour 1
# socket.tesla_supercharger 1
# cabins 1
# delivery 1
# local_ref 1
# recycling.cooking_oil 1
# recycling.shoes 1
# repair 1
# recycling.garden_waste 1
# industrial 1
# seamark:radar_transponder:category 1
# seamark:light:10:sector_end 1
# name_1 1
# recycling.cans 1
# isced.level 1
# maxspeed.forward 1
# seamark:light:9:period 1
# recycling.foil 1
# opening_date 1
# postal_code 1
# name.ja 1
# recycling.waste_oil 1
# whc.inscription_date 1
# seamark:light:10:group 1
# recycling.magazines 1
# climbing.boulder 1
# recycling.hardcode 1
# recycling.cork 1
# is_in.country_code 1
# college 1
# seamark:radar_transponder:period 1
# odbl 1
# underground 1
# population.source 1
# collection_times 1
# payment.notes 1
# seamark:light:10:height 1
# TODO 1
# health_specialty.radiology 1
# ref.whc 1
# source.note 1
# seamark:light:10:period 1
# amenity.no 1
# population.date 1
# name.de 1
# tower_type 1
# contact.webcam 1
# name.fr 1
# seamark:light:9:sector_end 1
# recycling.engine_oil 1
# health_specialty.acupuncture 1
# seamark:light:10:sector_start 1
# heritage.operator 1
# health_food 1
# recycling.christmas_trees 1
# socket:combo2 1
# recycling.plastic_bottles 1
# socket:type2:voltage 1
# kitchen_hours 1
# name.da 1
# maxstay 1
# recycling.paper_packaging 1
# karaoke 1
# drink.beer 1
# recycling.low_energy_bulbs 1
# seamark:light:9:colour 1
# socket:type2:amperage 1
# recycling.sheet_metal 1
# playground.theme 1
# subject.en 1
# recycling.tyres 1
# capacity.disabled 1
# socket:type1 1
# site_type 1
# recycling.chipboard 1
# cycleway 1
# seamark:light:10:character 1
# healthcare.speciality 1
# recycling.beverage_cartons 1
# recycling.electrical_appliances 1
# seamark:light:8:group 1
# seamark:light:9:character 1
# recycling.plastic_bags 1
# whc.criteria 1
# source.shop 1
# recycling.aluminium 1
# fuel:octane_100 1
# socket:chademo:amperage 1
# destination 1
# seamark:light:9:range 1
# generator.source 1
# seamark:light:7:group 1
# recycling.light_bulbs 1
# drive_through 1
# recycling.fridge_and_freezer 1
# image 1
# name.he 1
# dance.teaching 1
# bollard 1
# seamark:light:10:range 1
# telephone 1
# gay 1
# monitoring.bicycle 1
# recycling.fluorescent_tubes 1
# seamark:radar_transponder:group 1
# maxspeed.backward 1
# population_precision 1
# gambling 1
# seamark:light:category 1
# drink.soda 1
# service 1
# outdoor 1
# recycling.white_goods 1
# unisex 1
# recycling.tv_monitor 1

# %% [markdown]
# Looking at the counts of features I notice quite a few inconsistencies. For instance, I see multiple instances of website categories.

# %%
print("way website features:")
for key in way_features:
    if 'url' in key or 'website' in key:
        print(key,way_features[key])
print()
print("node website features:")
for key in node_features:
    if 'url' in key or 'website' in key:
        print(key,node_features[key])
# Out:
# way website features:
# website.en 1
# website 131
# contact.website 2
# url 1
# no-kartverket-ssr:url 1
#
# node website features:
# heritage.website 1
# source.url 10
# website 739
# contact.website 9
# url 11
# website.en 4

# %% [markdown]
# Here at least 'website', and 'url' can probably be merged into one category. It would be beneficial to the data quality if community efforts are made to clean up inconsistent category use.

# %%
#Looking for potential duplicate email feature types
print("way email features:")
for key in way_features:
    if 'email' in key:
        print(key,way_features[key])
print()
print("node email features:")
for key in node_features:
    if 'email' in key:
        print(key,node_features[key])
# Out:
# way email features:
# email 30
# contact.email 16
#
# node email features:
# email 288
# contact.email 26

# %%
#Ensuring there is no good reason to use 2 separate feature types for email
query = {'email': {'$exists': 1}, 'contact.email': {'$exists': 1} }

for doc in bergen.find(query):
    print(doc)
# Out:
# {'lottery': 'yes', 'address': {'postcode': '5096', 'street': 'Lægdesvingen', 'city': 'Bergen', 'housenumber': '61', 'country': 'NO'}, 'pos': [60.3712379, 5.3677984], 'operator': 'Bunnpris', '_id': ObjectId('591a5d8e49fce35f8f6889f6'), 'email': 'bpmontana@bunnpris.no', 'created': {'user': 'FredrikLindseth', 'timestamp': '2016-01-06T17:08:58Z', 'changeset': '36408353', 'uid': '1965308', 'version': '4'}, 'name': 'Bunnpris Montana', 'website': 'http://bunnpris.no/butikker/bunnpris-montana', 'shop': 'convenience', 'opening_hours': 'Mo-Fr 09:00-21:00; Sa 09:00-20:00', 'contact': [{'phone': '+4755296634'}, {'email': 'bpmontana@bunnpris.no'}, {'fax': '+4755295025'}], 'type': 'node', 'id': '299508269'}
# {'amenity': 'kindergarten', 'opening_hours': 'Mo-Fr 07:30-16:30', 'operator': ['Studentsamskipnaden i Bergen', {'type': 'private'}], '_id': ObjectId('591a5dac49fce35f8f70b5f3'), 'email': 'jekteviken.barnehage@sib.no', 'created': {'user': 'taule', 'timestamp': '2016-06-21T19:19:16Z', 'changeset': '40188612', 'uid': '2155734', 'version': '2'}, 'start_date': '1965-12-31', 'name': 'Jekteviken barnehage', 'type': 'node', 'no-barnehage:nsrid': '1015505', 'pos': [60.3894431, 5.3151187], 'contact': [{'phone': '55 90 19 64'}, {'email': 'oystein.bekken@sib.no'}], 'min_age': '1', 'capacity': '61', 'max_age': '5', 'id': '4183213790'}

# %% [markdown]
# Of the two documents which actually have both email and contact.email fields, one of them also have different email addresses listed in the different fields. Although rare, this indicates there is some value in keeping both feature types.

# %% [markdown]
# ### Cuisine and eatery types

# %%
#Most common food served at eatiries in Bergen

#Counts of different type of eateries
pipeline = [ 
    {'$match': {'cuisine': { '$exists': 1 } } },
    { '$group': { 
        '_id': {'cuisine': '$cuisine' }, 
        'count': {'$sum': 1 } } 
    },
    { '$sort': {'count': -1 } },
    { '$limit': 10 }
]

print("Cuisine, all eateries")
for doc in bergen.aggregate(pipeline):
    print(doc)


pipeline = [ 
    {'$match': {'amenity': 'restaurant', 'cuisine': {'$exists': 1} } },
    { '$group': { 
        '_id': {'cuisine': '$cuisine' }, 
        'count': {'$sum': 1 } } 
    },
    { '$sort': {'count': -1 } },
    { '$limit': 10 }
]
print('    ')
print("Cuisine, restaurants only")
for doc in bergen.aggregate(pipeline):
    print(doc)
# Out:
# Cuisine, all eateries
# {'_id': {'cuisine': 'coffee_shop'}, 'count': 54}
# {'_id': {'cuisine': 'burger'}, 'count': 19}
# {'_id': {'cuisine': 'pizza'}, 'count': 17}
# {'_id': {'cuisine': 'sushi'}, 'count': 14}
# {'_id': {'cuisine': 'kebab'}, 'count': 13}
# {'_id': {'cuisine': 'chinese'}, 'count': 10}
# {'_id': {'cuisine': 'italian'}, 'count': 9}
# {'_id': {'cuisine': 'thai'}, 'count': 9}
# {'_id': {'cuisine': 'mexican'}, 'count': 6}
# {'_id': {'cuisine': 'asian'}, 'count': 5}
#
# Cuisine, restaurants only
# {'_id': {'cuisine': 'pizza'}, 'count': 14}
# {'_id': {'cuisine': 'sushi'}, 'count': 12}
# {'_id': {'cuisine': 'chinese'}, 'count': 10}
# {'_id': {'cuisine': 'thai'}, 'count': 9}
# {'_id': {'cuisine': 'italian'}, 'count': 8}
# {'_id': {'cuisine': 'mexican'}, 'count': 6}
# {'_id': {'cuisine': 'burger'}, 'count': 4}
# {'_id': {'cuisine': 'tapas'}, 'count': 3}
# {'_id': {'cuisine': 'persian'}, 'count': 3}
# {'_id': {'cuisine': 'indian'}, 'count': 3}

# %% [markdown]
# We see here that in Bergen restaurants pizza, sushi and chinese food are the top cuisines. Among all eateries with cuisine information, if we exclude coffee_shop, the top 3 cuisines are burger, pizza and sushi.

# %%
#Counts of different type of eateries
pipeline = [ 
    {'$match': {'cuisine': { '$exists': 1 } } },
    { '$group': { 
        '_id': {'eatery_type': '$amenity' }, 
        'count': {'$sum': 1 } } 
    },
    {'$sort': {'count': -1 } }
]

for doc in bergen.aggregate(pipeline):
    print(doc)
# Out:
# {'_id': {'eatery_type': 'restaurant'}, 'count': 94}
# {'_id': {'eatery_type': 'cafe'}, 'count': 56}
# {'_id': {'eatery_type': 'fast_food'}, 'count': 37}
# {'_id': {'eatery_type': None}, 'count': 8}
# {'_id': {'eatery_type': 'bar'}, 'count': 1}
# {'_id': {'eatery_type': 'pub'}, 'count': 1}
# {'_id': {'eatery_type': 'fuel'}, 'count': 1}
# {'_id': {'eatery_type': 'marketplace'}, 'count': 1}

# %% [markdown]
# The majority of eateries with cuisine information are restaurants, cafés and fast food places.
# Interestingly enough, 8 of the documents with cuisine information are not defined as amenities. I will take a closer look at these documents next.

# %%
for doc in bergen.find({'amenity': {'$exists': 0}, 'cuisine': {'$exists': 1} } ):
    pprint(doc)
    print('   ')
# Out:
# {'_id': ObjectId('591a5d9149fce35f8f69723a'),
#  'address': {'city': 'Bergen',
#              'country': 'NO',
#              'housenumber': '12',
#              'postcode': '5017',
#              'street': 'Nedre Korskirkeallmenningen'},
#  'created': {'changeset': '37058789',
#              'timestamp': '2016-02-07T12:47:26Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '6'},
#  'cuisine': 'coffee_shop',
#  'email': 'korskirken@godtbrod.no',
#  'id': '1388471862',
#  'name': 'Godt Brød Korskirken',
#  'operator': 'Godt Brød',
#  'outdoor_seating': 'yes',
#  'pos': [60.3946396, 5.3270844],
#  'shop': 'bakery',
#  'smoking': 'no',
#  'type': 'node',
#  'website': 'http://www.godtbrod.no/Bakeverksted/Korskirken'}
#
# {'_id': ObjectId('591a5d9149fce35f8f69723d'),
#  'address': {'city': 'Bergen',
#              'housenumber': '2',
#              'postcode': '5015',
#              'street': 'Vestre Torggaten'},
#  'created': {'changeset': '36570200',
#              'timestamp': '2016-01-14T13:22:02Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '4'},
#  'cuisine': 'coffee_shop',
#  'email': 'vestretorggaten@godtbrod.no',
#  'id': '1388471864',
#  'name': 'Godt brød Vestre Torggaten',
#  'opening_hours': 'Mo-Fr 07:00-18:00; Sa 08:00-18:00; Su 09:00-17:00',
#  'operator': 'Godt Brød',
#  'outdoor_seating': 'yes',
#  'phone': '55 56 33 10',
#  'pos': [60.3907321, 5.3221295],
#  'shop': 'bakery',
#  'smoking': 'no',
#  'type': 'node',
#  'website': 'http://www.godtbrod.no/Bakeverksted/Floyen',
#  'wheelchair': 'yes'}
#
# {'_id': ObjectId('591a5d9149fce35f8f69723e'),
#  'address': {'city': 'Bergen',
#              'floor': '0',
#              'housenumber': '19',
#              'postcode': '5014',
#              'street': 'Vetrlidsallmenningen'},
#  'created': {'changeset': '42563970',
#              'timestamp': '2016-10-01T14:26:41Z',
#              'uid': '673287',
#              'user': 'Mariast',
#              'version': '5'},
#  'cuisine': 'coffee_shop',
#  'email': 'floyen@godtbrod.no',
#  'id': '1388471863',
#  'name': 'Godt Brød Fløyen',
#  'opening_hours': 'Mo-Fr 07:00-18:00; Sa 08:00-17:00; Su 09:00-17:00',
#  'operator': 'Godt Brød',
#  'outdoor_seating': 'yes',
#  'pos': [60.3960783, 5.3282669],
#  'shop': 'bakery',
#  'smoking': 'no',
#  'type': 'node',
#  'website': 'http://www.godtbrod.no/Bakeverksted/Floyen',
#  'wheelchair': 'no'}
#
# {'_id': ObjectId('591a5d9149fce35f8f697dc4'),
#  'address': {'city': 'Bergen',
#              'housenumber': '1',
#              'postcode': '5008',
#              'street': 'Vestre Strømkaien'},
#  'created': {'changeset': '42277189',
#              'timestamp': '2016-09-19T18:31:42Z',
#              'uid': '673287',
#              'user': 'Mariast',
#              'version': '5'},
#  'cuisine': 'international',
#  'id': '1652908193',
#  'name': 'Global Food',
#  'opening_hours': 'Mo-Fr 10:00-20:00; Sa 10:00-19:00',
#  'phone': '+47 55 55 86 00',
#  'pos': [60.3891027, 5.3309696],
#  'shop': 'convenience',
#  'toilets': {'wheelchair': 'no'},
#  'type': 'node',
#  'wheelchair': 'yes'}
#
# {'_id': ObjectId('591a5d9149fce35f8f698716'),
#  'address': {'city': 'Bergen',
#              'country': 'NO',
#              'housenumber': '76A',
#              'postcode': '5094',
#              'street': 'Nattlandsveien'},
#  'created': {'changeset': '30024209',
#              'timestamp': '2015-04-06T19:24:35Z',
#              'uid': '7645',
#              'user': 'Karl Ove Hufthammer',
#              'version': '3'},
#  'cuisine': 'turkish',
#  'id': '1730271678',
#  'name': 'Zeugma minimarket',
#  'official_name': 'Zegma AS',
#  'pos': [60.3614171, 5.3681003],
#  'shop': 'convenience',
#  'type': 'node'}
#
# {'_id': ObjectId('591a5da749fce35f8f6f25f8'),
#  'address': {'city': 'Bergen',
#              'country': 'NO',
#              'housenumber': '1',
#              'postcode': '5017',
#              'street': 'Marken'},
#  'created': {'changeset': '36741428',
#              'timestamp': '2016-01-22T15:36:06Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '2'},
#  'cuisine': 'coffee_shop',
#  'email': 'marken@godtbrod.no',
#  'id': '3938141623',
#  'name': 'Godt Brød Marken',
#  'operator': 'Godt Brød',
#  'outdoor_seating': 'yes',
#  'phone': '55 10 20 22',
#  'pos': [60.3922138, 5.3299663],
#  'shop': 'bakery',
#  'smoking': 'no',
#  'type': 'node',
#  'website': 'http://www.godtbrod.no/Bakeverksted/Marken'}
#
# {'_id': ObjectId('591a5da849fce35f8f6f74c8'),
#  'address': {'city': 'Bergen',
#              'housenumber': '4A',
#              'postcode': '5012',
#              'street': 'Markeveien'},
#  'created': {'changeset': '37097944',
#              'timestamp': '2016-02-09T10:20:29Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '2'},
#  'cuisine': 'mediterranean',
#  'id': '3966051497',
#  'name': 'Olivers & Co',
#  'pos': [60.39274, 5.322214],
#  'shop': 'convenience',
#  'type': 'node',
#  'website': 'https://www.oliviers-co.no/'}
#
# {'_id': ObjectId('591a5dad49fce35f8f70f291'),
#  'created': {'changeset': '40399466',
#              'timestamp': '2016-06-30T18:29:31Z',
#              'uid': '1965308',
#              'user': 'FredrikLindseth',
#              'version': '2'},
#  'cuisine': 'asian',
#  'email': 'post@asiatenmat.no',
#  'id': '4273619538',
#  'level': '0',
#  'name': 'Asiaten Mat',
#  'phone': '+47 55 93 21 00',
#  'pos': [60.3718268, 5.1800824],
#  'shop': 'convenience',
#  'type': 'node',
#  'website': 'http://www.asiatenmat.no/'}

# %%
#Grouping documents above on shop and cuisine
pipeline = [
    { '$match': {'amenity': {'$exists': 0}, 'cuisine': {'$exists': 1} } },
    { '$group': {'_id': {'cuisine': '$cuisine', 'shop type': '$shop'}, 
                'count': {'$sum': 1 } } }
]

for res in bergen.aggregate(pipeline):
    print(res)
# Out:
# {'_id': {'shop type': 'convenience', 'cuisine': 'turkish'}, 'count': 1}
# {'_id': {'shop type': 'convenience', 'cuisine': 'international'}, 'count': 1}
# {'_id': {'shop type': 'convenience', 'cuisine': 'asian'}, 'count': 1}
# {'_id': {'shop type': 'convenience', 'cuisine': 'mediterranean'}, 'count': 1}
# {'_id': {'shop type': 'bakery', 'cuisine': 'coffee_shop'}, 'count': 4}

# %% [markdown]
# All 8 of these non-eatery documents are considered shops, where 4 are bakeries and 4 are convenience shops.
#
# Last in this section, I will generate counts of restaurants, cafės and fast food restaurants with missing cuisine information.

# %%
#Counts of eatery types with cuisine information
pipeline = [ 
    {'$match': {'cuisine':{ '$exists': 1 }, 'amenity': {'$in': ['cafe','restaurant', 'fast_food'] } } },
    { '$group': { 
        '_id': {'eatery_type': '$amenity' }, 
        'count': {'$sum': 1 } } 
    },
    {'$sort': {'count': -1 } }
]

print('Eateries with cuisine information')
for doc in bergen.aggregate(pipeline):
    print(doc)

print('    ')
#Counts of eatery types without cuisine information
pipeline = [ 
    {'$match': {'cuisine':{ '$exists': 0 }, 'amenity': {'$in': ['cafe','restaurant', 'fast_food'] } } },
    { '$group': { 
        '_id': {'eatery_type': '$amenity' }, 
        'count': {'$sum': 1 } } 
    },
    {'$sort': {'count': -1 } }
]

print('Eateries missing cuisine information')
for doc in bergen.aggregate(pipeline):
    print(doc)
# Out:
# Eateries with cuisine information
# {'_id': {'eatery_type': 'restaurant'}, 'count': 94}
# {'_id': {'eatery_type': 'cafe'}, 'count': 56}
# {'_id': {'eatery_type': 'fast_food'}, 'count': 37}
#
# Eateries missing cuisine information
# {'_id': {'eatery_type': 'restaurant'}, 'count': 95}
# {'_id': {'eatery_type': 'cafe'}, 'count': 31}
# {'_id': {'eatery_type': 'fast_food'}, 'count': 11}

# %% [markdown]
# Quite a few restaurants, cafés, and fast food places lack cuisine information. Community efforts should be made to improve this.

# %% [markdown]
# ### Final Thoughts and summary
#
# There are 184 address documents without street names in the dataset. Further investigation into those documents is recommended.
#
# To address the duplicate issue in detail, I suggest following up by looking at the individual duplicate addresses. You could for example start by looking at the three streets with the most individual duplicate addresses to see if there are any useful patterns to be found. Since a few users are very heavy contributors to the Bergen OSM data, it might also be worth searching for user patterns regarding the duplicate addresses.
#
# I would also recommend correcting the misspelled street names, which are stored in data/misspelled_streets.csv, and conduct online research for the street names in data/research_streets_spelling.csv.
#
# There appear to be quite a few potential duplicate fields/feature types in the dataset. Although outside the scope of this project, it would be useful to conduct further analysis and cleanup efforts of duplicate feature types.
#
# About half of the restaurants in the dataset lack cuisine information. This could be a minimal effort task with a high yield result for the active Bergen OSM contributors.
